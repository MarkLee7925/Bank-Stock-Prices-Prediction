# %% [markdown]
# # RBC - Stock Prices Prediction

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas_datareader as webreader
import pandas as pd
import tensorflow as tf
import seaborn as sns
import datetime as dt
import pandas_datareader as webreader
from datetime import date, timedelta, datetime

# %% [markdown]
# ## 2. Load Data

# %%
# Import dataset
df = pd.read_csv('RBC_StockPrices_2016-2021.csv')

# today = date.today()
# date_today = today.strftime("%Y-%m-%d")
# date_start = '2016-01-01'

# # Read stock quotes from Yahoo Finance
# df = webreader.DataReader('CM-PQ', data_source='yahoo', start=date_start, end=date_today)

# Input data of np array - Closing price
dataset = df.iloc[:, 4:5].values

print(dataset.shape)
# Out:
# (1254, 1)

# %%
df
# Out:
#             Date        Open        High  ...       Close   Adj Close   Volume
# 0     2016-09-13   80.190002   80.379997  ...   80.180000   65.923744  2335400
# 1     2016-09-14   79.980003   80.500000  ...   80.110001   65.866173  1481100
# 2     2016-09-15   80.169998   81.489998  ...   81.360001   66.893951  1777800
# 3     2016-09-16   81.190002   81.190002  ...   80.760002   66.400620  5653300
# 4     2016-09-19   81.000000   81.339996  ...   80.760002   66.400620  1582300
# ...          ...         ...         ...  ...         ...         ...      ...
# 1249  2021-09-03  129.750000  129.830002  ...  129.479996  129.479996  1150600
# 1250  2021-09-07  129.699997  130.710007  ...  129.949997  129.949997  1522600
# 1251  2021-09-08  130.000000  130.580002  ...  129.440002  129.440002  1349400
# 1252  2021-09-09  129.330002  130.429993  ...  129.839996  129.839996  1292900
# 1253  2021-09-10  130.169998  130.190002  ...  129.630005  129.630005  1433600
#
# [1254 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1254 entries, 0 to 1253
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1254 non-null   object
#  1   Open       1254 non-null   float64
#  2   High       1254 non-null   float64
#  3   Low        1254 non-null   float64
#  4   Close      1254 non-null   float64
#  5   Adj Close  1254 non-null   float64
#  6   Volume     1254 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.7+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# from sklearn.impute import SimpleImputer

# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# imputer.fit_transform(dataset)
# dataset = imputer.transform(dataset)
# df.dropna(inplace=True)

# %% [markdown]
# ## 3. Visualize Data

# %%
# Plot each data column
df.plot(subplots=True, figsize=(12,20), sharex=False, cmap='rainbow')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff97e7d3210>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff97e7a9750>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff97e761dd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff97e723410>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff97e6d8a90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff97e69a150>],
#       dtype=object)

# %%
# Pariwise relationship between features
sns.pairplot(df)

# %%
# Correlation Map
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(method='pearson'), annot=True, cmap='hot', fmt='.2f')
plt.title('Correlation Map')
plt.xticks(rotation=60)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5]),
#  <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# ## 4. Data Preprocessing and Feature Engineering

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Normalize data
sc = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = sc.fit_transform(dataset)

# %%
dataset_scaled
# Out:
# array([[0.13021348],
#        [0.12906407],
#        [0.14958952],
#        ...,
#        [0.93908059],
#        [0.94564863],
#        [0.9422005 ]])

# %%
# Split dataset into training set and test set (80/20 split)
training_size = int(len(df)*0.8)
dataset_train = dataset_scaled[:training_size]
dataset_test = dataset_scaled[training_size:]

print('Training set shape: ' + str(dataset_train.shape))
print('Test set shape: ' + str(dataset_test.shape))
# Out:
# Training set shape: (1003, 1)
# Test set shape: (251, 1)

# %% [markdown]
# #### Create a data structure with 60 timesteps and 1 output

# %%
# Predict stock price results using 60 timesteps (60 business days)
timesteps = 60

def define_training_data(timesteps, dataset):
  ''' 
  Define number of timesteps and features needed for training and 
  validating RNN model 
  '''

  # X - number of timesteps, y - indicators (features) used for training
  X, y = [], []
  for i in range(timesteps, dataset.shape[0]):
    X.append(dataset[i-timesteps:i, 0])
    y.append(dataset[i, 0])
  X, y = np.array(X), np.array(y)
  return X, y

X_train, y_train = define_training_data(timesteps, dataset_train)
print(X_train.shape, y_train.shape)
# Out:
# (943, 60) (943,)

# %% [markdown]
# #### Reshaping

# %%
# Reshape(number of rows, number of timesteps (columns), number of predictors)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train
# Out:
# array([[[0.13021348],
#         [0.12906407],
#         [0.14958952],
#         ...,
#         [0.25418727],
#         [0.25730705],
#         [0.25894907]],
#
#        [[0.12906407],
#         [0.14958952],
#         [0.13973732],
#         ...,
#         [0.25730705],
#         [0.25894907],
#         [0.26403947]],
#
#        [[0.14958952],
#         [0.13973732],
#         [0.13973732],
#         ...,
#         [0.25894907],
#         [0.26403947],
#         [0.28210183]],
#
#        ...,
#
#        [[0.28965518],
#         [0.3136289 ],
#         [0.31395739],
#         ...,
#         [0.44154354],
#         [0.42019702],
#         [0.40492621]],
#
#        [[0.3136289 ],
#         [0.31395739],
#         [0.33661744],
#         ...,
#         [0.42019702],
#         [0.40492621],
#         [0.39474554]],
#
#        [[0.31395739],
#         [0.33661744],
#         [0.32873562],
#         ...,
#         [0.40492621],
#         [0.39474554],
#         [0.41461416]]])

# %%
X_train.shape
# Out:
# (943, 60, 1)

# %% [markdown]
# ## 5. Define LSTM model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define model
reg = Sequential()

# LSTM layers
reg.add(LSTM(units=60, return_sequences=True, 
             input_shape=(X_train.shape[1], X_train.shape[2])))
reg.add(Dropout(0.2))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.2))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.2))
reg.add(LSTM(units=50, return_sequences=False))
reg.add(Dropout(0.1))

# Output layer
reg.add(Dense(units=X_train.shape[2]))

# Compile model
reg.compile(optimizer='adam', loss='mean_squared_error')

# Train (fit) model
history = reg.fit(X_train, y_train, batch_size=32, epochs=100)

# Plot loss during training
plt.plot(history.history['loss'], 'g', label='loss')
plt.title('Training Curve')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1/100
# 30/30 [==============================] - 10s 133ms/step - loss: 0.0246
# Epoch 2/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.0056
# Epoch 3/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0049
# Epoch 4/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0046
# Epoch 5/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0039
# Epoch 6/100
# 30/30 [==============================] - 4s 141ms/step - loss: 0.0040
# Epoch 7/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0038
# Epoch 8/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0038
# Epoch 9/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0031
# Epoch 10/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0029
# Epoch 11/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0034
# Epoch 12/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0029
# Epoch 13/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0025
# Epoch 14/100
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0027
# Epoch 15/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0024
# Epoch 16/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0024
# Epoch 17/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0025
# Epoch 18/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0022
# Epoch 19/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0022
# Epoch 20/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0020
# Epoch 21/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0022
# Epoch 22/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0023
# Epoch 23/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0019
# Epoch 24/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.0018
# Epoch 25/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0018
# Epoch 26/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0016
# Epoch 27/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0018
# Epoch 28/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0017
# Epoch 29/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.0018
# Epoch 30/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0016
# Epoch 31/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0017
# Epoch 32/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0017
# Epoch 33/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0016
# Epoch 34/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0015
# Epoch 35/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0015
# Epoch 36/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0016
# Epoch 37/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.0015
# Epoch 38/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.0014
# Epoch 39/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0014
# Epoch 40/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0018
# Epoch 41/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0016
# Epoch 42/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.0013
# Epoch 43/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.0013
# Epoch 44/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0014
# Epoch 45/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0015
# Epoch 46/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0013
# Epoch 47/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0012
# Epoch 48/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0013
# Epoch 49/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0011
# Epoch 50/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0012
# Epoch 51/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0013
# Epoch 52/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0012
# Epoch 53/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0012
# Epoch 54/100
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0012
# Epoch 55/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0011
# Epoch 56/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0012
# Epoch 57/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0014
# Epoch 58/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.0013
# Epoch 59/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0012
# Epoch 60/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0010
# Epoch 61/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0010
# Epoch 62/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.0010
# Epoch 63/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0011
# Epoch 64/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0011
# Epoch 65/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0011
# Epoch 66/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0011
# Epoch 67/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0012
# Epoch 68/100
# 30/30 [==============================] - 4s 143ms/step - loss: 0.0011
# Epoch 69/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.0010
# Epoch 70/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0011
# Epoch 71/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.0010
# Epoch 72/100
# 30/30 [==============================] - 4s 139ms/step - loss: 9.5872e-04
# Epoch 73/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0012
# Epoch 74/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0011
# Epoch 75/100
# 30/30 [==============================] - 4s 139ms/step - loss: 9.4576e-04
# Epoch 76/100
# 30/30 [==============================] - 4s 134ms/step - loss: 9.6884e-04
# Epoch 77/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0011
# Epoch 78/100
# 30/30 [==============================] - 4s 141ms/step - loss: 9.0753e-04
# Epoch 79/100
# 30/30 [==============================] - 4s 142ms/step - loss: 0.0010
# Epoch 80/100
# 30/30 [==============================] - 4s 132ms/step - loss: 9.5176e-04
# Epoch 81/100
# 30/30 [==============================] - 4s 134ms/step - loss: 9.6195e-04
# Epoch 82/100
# 30/30 [==============================] - 4s 134ms/step - loss: 9.5691e-04
# Epoch 83/100
# 30/30 [==============================] - 4s 143ms/step - loss: 9.3739e-04
# Epoch 84/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0010
# Epoch 85/100
# 30/30 [==============================] - 4s 131ms/step - loss: 9.3026e-04
# Epoch 86/100
# 30/30 [==============================] - 4s 133ms/step - loss: 8.9899e-04
# Epoch 87/100
# 30/30 [==============================] - 4s 139ms/step - loss: 9.2203e-04
# Epoch 88/100
# 30/30 [==============================] - 4s 139ms/step - loss: 9.1639e-04
# Epoch 89/100
# 30/30 [==============================] - 4s 141ms/step - loss: 9.6234e-04
# Epoch 90/100
# 30/30 [==============================] - 4s 143ms/step - loss: 8.3480e-04
# Epoch 91/100
# 30/30 [==============================] - 4s 141ms/step - loss: 8.7148e-04
# Epoch 92/100
# 30/30 [==============================] - 4s 142ms/step - loss: 8.3861e-04
# Epoch 93/100
# 30/30 [==============================] - 4s 135ms/step - loss: 8.3082e-04
# Epoch 94/100
# 30/30 [==============================] - 4s 135ms/step - loss: 8.1831e-04
# Epoch 95/100
# 30/30 [==============================] - 4s 140ms/step - loss: 8.6305e-04
# Epoch 96/100
# 30/30 [==============================] - 4s 140ms/step - loss: 9.4129e-04
# Epoch 97/100
# 30/30 [==============================] - 4s 136ms/step - loss: 8.8464e-04
# Epoch 98/100
# 30/30 [==============================] - 4s 133ms/step - loss: 8.3129e-04
# Epoch 99/100
# 30/30 [==============================] - 4s 132ms/step - loss: 7.8064e-04
# Epoch 100/100
# 30/30 [==============================] - 4s 134ms/step - loss: 8.0268e-04

# %% [markdown]
# ## 6. Evalutate model

# %% [markdown]
# #### Make predictions

# %%
# Get 60 previous stock prices for predicting
inputs = dataset[len(dataset)-len(dataset_test) - timesteps:]
# Reshape input values
inputs = inputs.reshape(-1, 1)
# Scale input values, directly apply transformations (already fitted)
inputs = sc.transform(inputs)

# Define test set structure
X_test = []
# For the entire test set
for i in range(timesteps, timesteps + len(dataset_test)):
  # Range of values from i-60 to i, first column
  X_test.append(inputs[i-timesteps:i, 0])
X_test = np.array(X_test)

# Obtain 3D structure of the test set
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Predict the test set results
predicted_stock_price = reg.predict(X_test)
# Apply inverse transformations
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
real_stock_price = sc.inverse_transform(dataset_test)

# Print predicted and real stock prices side-by-side
print(np.concatenate((predicted_stock_price.reshape(len(predicted_stock_price), 1), 
                      real_stock_price.reshape(len(real_stock_price), 1)), 1 ))

# Print Scores
print('')
print('--- Prediction Scores ---')
print('')
mae = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: ' + str(mae))
mse = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: ' + str(mse))
rmse = np.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+ str(rmse))
r2 = r2_score(real_stock_price, predicted_stock_price)
print('R^2 Score: '+ str(r2))
# Out:
# [[ 96.75524139  97.18      ]
#  [ 96.84043121  97.870003  ]
#  [ 97.21234131  98.129997  ]
#  [ 97.68598175  96.669998  ]
#  [ 97.64342499  96.529999  ]
#  [ 97.28012848  95.470001  ]
#  [ 96.61930084  94.349998  ]
#  [ 95.71443176  94.32      ]
#  [ 94.94605255  93.629997  ]
#  [ 94.31344604  94.190002  ]
#  [ 94.04771423  94.489998  ]
#  [ 94.12762451  95.559998  ]
#  [ 94.61382294  93.910004  ]
#  [ 94.75799561  93.489998  ]
#  [ 94.50241089  93.559998  ]
#  [ 94.14990234  94.269997  ]
#  [ 94.05841064  95.519997  ]
#  [ 94.46607971  95.639999  ]
#  [ 95.06203461  97.669998  ]
#  [ 96.06591797  97.709999  ]
#  [ 97.04342651  97.349998  ]
#  [ 97.59122467  97.300003  ]
#  [ 97.73957062  97.080002  ]
#  [ 97.6204071   97.07      ]
#  [ 97.42922974  97.339996  ]
#  [ 97.35427856  96.150002  ]
#  [ 97.04841614  95.900002  ]
#  [ 96.61696625  96.730003  ]
#  [ 96.48704529  97.349998  ]
#  [ 96.74408722  96.290001  ]
#  [ 96.82272339  94.5       ]
#  [ 96.25393677  92.910004  ]
#  [ 95.09298706  91.190002  ]
#  [ 93.55930328  92.889999  ]
#  [ 92.68848419  93.160004  ]
#  [ 92.53979492  93.290001  ]
#  [ 92.79508972  94.940002  ]
#  [ 93.53066254  97.230003  ]
#  [ 94.89850616  96.269997  ]
#  [ 95.99681854  96.739998  ]
#  [ 96.67318726  97.669998  ]
#  [ 97.21633911  99.400002  ]
#  [ 98.06137085 100.139999  ]
#  [ 99.06996155 100.290001  ]
#  [ 99.89077759 100.400002  ]
#  [100.39022827 101.75      ]
#  [101.0011673  103.459999  ]
#  [102.05306244 104.080002  ]
#  [103.19955444 103.970001  ]
#  [103.95510864 104.330002  ]
#  [104.38917542 105.599998  ]
#  [104.99206543 107.709999  ]
#  [106.23403931 107.709999  ]
#  [107.33169556 108.25      ]
#  [108.12407684 108.160004  ]
#  [108.47088623 106.059998  ]
#  [107.71933746 107.040001  ]
#  [107.17284393 106.389999  ]
#  [106.71773529 105.839996  ]
#  [106.23879242 105.150002  ]
#  [105.65694427 105.730003  ]
#  [105.44947052 105.809998  ]
#  [105.5083313  106.25      ]
#  [105.79384613 106.440002  ]
#  [106.12536621 106.370003  ]
#  [106.31345367 104.860001  ]
#  [105.81053162 104.419998  ]
#  [105.03643799 104.760002  ]
#  [104.58112335 104.43      ]
#  [104.32337189 104.050003  ]
#  [104.08952332 103.720001  ]
#  [103.82460022 103.480003  ]
#  [103.55858612 104.860001  ]
#  [103.86865234 104.910004  ]
#  [104.36276245 105.199997  ]
#  [104.83480835 104.82      ]
#  [104.99351501 104.589996  ]
#  [104.88051605 104.68      ]
#  [104.74111938 105.349998  ]
#  [104.89493561 106.879997  ]
#  [105.67919922 108.07      ]
#  [106.89319611 107.980003  ]
#  [107.7934494  107.839996  ]
#  [108.15188599 108.459999  ]
#  [108.40632629 108.559998  ]
#  [108.58997345 108.18      ]
#  [108.52819824 108.400002  ]
#  [108.47549438 108.300003  ]
#  [108.41722107 107.800003  ]
#  [108.17848969 108.07      ]
#  [108.05873108 107.839996  ]
#  [107.94733429 107.360001  ]
#  [107.68209839 106.290001  ]
#  [107.03515625 105.989998  ]
#  [106.36103821 104.080002  ]
#  [105.22661591 105.169998  ]
#  [104.70348358 103.5       ]
#  [104.05381775 104.519997  ]
#  [103.89810944 105.660004  ]
#  [104.4371109  105.540001  ]
#  [105.03040314 106.300003  ]
#  [105.66883087 106.68      ]
#  [106.24430084 107.129997  ]
#  [106.75283051 107.07      ]
#  [107.03436279 105.93      ]
#  [106.69947052 105.809998  ]
#  [106.19645691 106.199997  ]
#  [105.98783875 106.459999  ]
#  [106.09049988 107.370003  ]
#  [106.61623383 109.110001  ]
#  [107.78076172 109.769997  ]
#  [109.02819061 111.07      ]
#  [110.32035065 112.169998  ]
#  [111.57810974 111.879997  ]
#  [112.19692993 110.349998  ]
#  [111.6685791  108.360001  ]
#  [110.11381531 109.739998  ]
#  [109.40348053 109.699997  ]
#  [109.30956268 109.760002  ]
#  [109.47756958 109.879997  ]
#  [109.70498657 112.57      ]
#  [110.97563171 114.489998  ]
#  [112.96485901 114.300003  ]
#  [114.2707901  115.940002  ]
#  [115.47264099 116.220001  ]
#  [116.25540924 116.449997  ]
#  [116.64022827 115.919998  ]
#  [116.45839691 115.989998  ]
#  [116.20552826 116.410004  ]
#  [116.25160217 117.040001  ]
#  [116.67630768 116.540001  ]
#  [116.76390076 115.980003  ]
#  [116.40907288 115.839996  ]
#  [116.00104523 115.959999  ]
#  [115.811203   116.290001  ]
#  [115.92198944 117.059998  ]
#  [116.43832397 117.120003  ]
#  [116.85301971 117.139999  ]
#  [117.02881622 115.870003  ]
#  [116.39646149 116.        ]
#  [115.86323547 116.5       ]
#  [115.85691833 116.489998  ]
#  [116.00621796 116.550003  ]
#  [116.15579224 116.800003  ]
#  [116.35900116 117.110001  ]
#  [116.63877869 117.589996  ]
#  [117.05020905 117.18      ]
#  [117.09776306 117.339996  ]
#  [117.08678436 118.019997  ]
#  [117.41210938 118.489998  ]
#  [117.92614746 117.949997  ]
#  [117.96724701 116.599998  ]
#  [117.14883423 116.040001  ]
#  [116.18402863 115.849998  ]
#  [115.54158783 116.559998  ]
#  [115.65560913 116.75      ]
#  [116.04889679 117.110001  ]
#  [116.5200882  117.739998  ]
#  [117.11011505 118.110001  ]
#  [117.64254761 117.309998  ]
#  [117.48695374 118.089996  ]
#  [117.58931732 117.919998  ]
#  [117.63721466 119.040001  ]
#  [118.22005463 119.57      ]
#  [118.96330261 120.260002  ]
#  [119.75273132 120.379997  ]
#  [120.22699738 119.410004  ]
#  [119.84307098 119.940002  ]
#  [119.68997955 121.139999  ]
#  [120.3276825  121.860001  ]
#  [121.25417328 122.290001  ]
#  [122.01622772 123.139999  ]
#  [122.80791473 122.839996  ]
#  [122.99850464 122.970001  ]
#  [122.98225403 123.470001  ]
#  [123.18781281 123.459999  ]
#  [123.30878448 124.449997  ]
#  [123.91088867 126.        ]
#  [125.21770477 125.620003  ]
#  [125.71911621 124.209999  ]
#  [124.85569763 125.849998  ]
#  [125.13035583 125.980003  ]
#  [125.5509491  126.120003  ]
#  [125.83643341 126.209999  ]
#  [125.96323395 126.029999  ]
#  [125.83850861 125.68      ]
#  [125.47621155 124.919998  ]
#  [124.75971222 124.699997  ]
#  [124.20839691 126.099998  ]
#  [124.859375   126.410004  ]
#  [125.60299683 127.330002  ]
#  [126.52062988 127.68      ]
#  [127.15273285 127.080002  ]
#  [126.93958282 125.959999  ]
#  [125.91643524 126.260002  ]
#  [125.47663116 125.839996  ]
#  [125.13331604 125.639999  ]
#  [124.89234924 125.709999  ]
#  [124.86601257 126.169998  ]
#  [125.19855499 125.529999  ]
#  [125.01868439 125.660004  ]
#  [124.90489197 125.589996  ]
#  [124.81481171 126.029999  ]
#  [125.05215454 126.379997  ]
#  [125.44813538 125.980003  ]
#  [125.40389252 125.949997  ]
#  [125.26829529 125.779999  ]
#  [125.07875061 126.370003  ]
#  [125.35964966 127.720001  ]
#  [126.45059967 127.980003  ]
#  [127.26990509 128.740005  ]
#  [128.05038452 129.309998  ]
#  [128.72302246 127.540001  ]
#  [127.77983856 125.540001  ]
#  [125.74436188 125.989998  ]
#  [124.94791412 126.300003  ]
#  [125.0701828  125.860001  ]
#  [125.07387543 125.32      ]
#  [124.72971344 125.860001  ]
#  [124.84455109 126.540001  ]
#  [125.41370392 126.639999  ]
#  [125.81455231 127.        ]
#  [126.1679306  126.18      ]
#  [125.76979065 126.279999  ]
#  [125.49092102 127.199997  ]
#  [125.97904205 127.919998  ]
#  [126.82673645 129.139999  ]
#  [128.07067871 129.350006  ]
#  [128.80978394 130.360001  ]
#  [129.6714325  130.960007  ]
#  [130.41903687 131.080002  ]
#  [130.74687195 131.059998  ]
#  [130.7543335  131.179993  ]
#  [130.75509644 130.75      ]
#  [130.42909241 130.660004  ]
#  [130.16941833 130.350006  ]
#  [129.84541321 131.720001  ]
#  [130.65830994 131.740005  ]
#  [131.15800476 132.050003  ]
#  [131.48573303 133.149994  ]
#  [132.31005859 132.570007  ]
#  [132.21723938 132.279999  ]
#  [131.77308655 131.070007  ]
#  [130.62521362 129.600006  ]
#  [129.01148987 129.490005  ]
#  [128.23905945 129.649994  ]
#  [128.2154541  129.479996  ]
#  [128.25898743 129.949997  ]
#  [128.63059998 129.440002  ]
#  [128.48181152 129.839996  ]
#  [128.58755493 129.630005  ]]
#
# --- Prediction Scores ---
#
# MAE: 0.9706088368537565
# MSE: 1.4849111001169633
# RMSE: 1.2185692840856293
# R^2 Score: 0.9893002982560384

# %% [markdown]
# #### Visualizing results

# %%
# Plot predicted and real closing stock prices
plt.plot(real_stock_price, color = 'blue', label = 'Real Stock Price')
plt.plot(predicted_stock_price, color = 'red', label = 'Predicted Stock Price')
plt.xlabel('Days')
plt.ylabel('Stock Price ($)')
plt.title('RBC Stock Price Prediction')
plt.legend()
plt.grid()
plt.show()
