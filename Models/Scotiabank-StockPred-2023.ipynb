# %% [markdown]
# # Scotiabank - Stock Prices Prediction

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas_datareader as webreader
import pandas as pd
import tensorflow as tf
import seaborn as sns
import datetime as dt

from datetime import date, timedelta, datetime
from sklearn.preprocessing import MinMaxScaler
from pandas_datareader import data
from tensorflow import keras

# %% [markdown]
# ## 2. Data Preprocessing and Visualization

# %% [markdown]
# ### 2.1. Load Data

# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader

# %%
# Import dataset
df = pd.read_csv('BNS-Stocks-2015-2023.csv')

# today = date.today()
# date_today = today.strftime("%Y-%m-%d")
# date_start = '2015-02-03'

# # Read stock quotes from Yahoo Finance
# df = data.DataReader("BNS.TO", data_source='yahoo', start=date_start, end=date_today)
# df = webreader.DataReader('BNS.TO', data_source='yahoo', start=date_start, end=date_today)

# Input data of np array - Closing price
dataset = df.iloc[:, 4:5].values

# Dataset shape
print(dataset.shape)
# Out:
# (1987, 1)

# %% [markdown]
# ### 2.2. Analyze Data

# %%
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2015-03-12  62.820000  63.639999  62.810001  63.240002  43.056576
# 1     2015-03-13  63.049999  63.169998  62.209999  62.849998  42.791039
# 2     2015-03-16  62.950001  64.220001  62.830002  63.750000  43.403809
# 3     2015-03-17  63.720001  63.740002  62.560001  63.330002  43.117847
# 4     2015-03-18  63.250000  63.470001  62.639999  63.080002  42.947643
# ...          ...        ...        ...        ...        ...        ...
# 1982  2023-02-03  73.500000  73.699997  72.949997  73.360001  73.360001
# 1983  2023-02-06  73.160004  73.199997  72.529999  72.820000  72.820000
# 1984  2023-02-07  72.559998  74.000000  72.300003  73.750000  73.750000
# 1985  2023-02-08  73.559998  74.180000  73.050003  73.220001  73.220001
# 1986  2023-02-09  73.500000  73.809998  72.849998  73.120003  73.120003
#
#        Volume
# 0     1661600
# 1     1827100
# 2     2054400
# 3     1907600
# 4     2023300
# ...       ...
# 1982  3120600
# 1983  2731700
# 1984  3266900
# 1985  2443100
# 1986  2325100
#
# [1987 rows x 7 columns]

# %%
# Brief info about dataframe - non-null values and datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987 entries, 0 to 1986
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1987 non-null   object
#  1   Open       1987 non-null   float64
#  2   High       1987 non-null   float64
#  3   Low        1987 non-null   float64
#  4   Close      1987 non-null   float64
#  5   Adj Close  1987 non-null   float64
#  6   Volume     1987 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 108.8+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# from sklearn.impute import SimpleImputer

# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# imputer.fit_transform(dataset)
# dataset = imputer.transform(dataset)
# df.dropna(inplace=True)

# %%
# Dataframe statistics on quantitative (numerical) values
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1987.000000  1987.000000  1987.000000  1987.000000  1987.000000
# mean     71.857614    72.293447    71.388405    71.848229    59.356065
# std       9.162235     9.126590     9.215315     9.165444    11.455189
# min      49.139999    50.570000    46.380001    46.720001    36.961864
# 25%      65.369999    65.864998    64.939999    65.405003    49.974079
# 50%      73.000000    73.379997    72.550003    72.930000    59.311695
# 75%      78.235000    78.614998    77.805001    78.174999    64.151932
# max      94.980003    95.000000    93.839996    94.489998    89.312477
#
#              Volume
# count  1.987000e+03
# mean   3.093438e+06
# std    2.173722e+06
# min    3.626000e+05
# 25%    1.712500e+06
# 50%    2.390200e+06
# 75%    3.704100e+06
# max    2.099180e+07

# %% [markdown]
# ### 2.3. Visualize Data

# %% [markdown]
# #### Pariwise relationship between features

# %%
# Pairwise distributions
sns.pairplot(df)

# Show figure
plt.show()

# %% [markdown]
# #### Correlation Map

# %%
# Define figure
plt.figure(figsize=(10,10))

# Correlation Map
sns.heatmap(df.corr(method='pearson'), annot=True, cmap='OrRd', fmt='.2f')
# Adjust X and Y-Axes
plt.xticks(rotation=0)
plt.yticks(rotation=0)
# Plot title
plt.title('Correlation Map')

# Show figure
plt.show()

# %% [markdown]
# #### Individual stock prices and volume distribution

# %%
# Define stock prices figure
bns_stock_prices = plt.figure(figsize=(10,24))

# Open Stock Price
ax1 = bns_stock_prices.add_subplot(6, 1, 1)
ax1 = plt.plot(df['Open'], color = 'violet')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 120, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid()

# High Stock Price
ax2 = bns_stock_prices.add_subplot(6, 1, 2)
ax2 = plt.plot(df['High'], color = 'indigo')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 120, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Low Stock Price
ax3 = bns_stock_prices.add_subplot(6, 1, 3)
ax3 = plt.plot(df['Low'], color = 'blue')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 120, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Closing Stock Price (target variable)
ax4 = bns_stock_prices.add_subplot(6, 1, 4)
ax4 = plt.plot(df['Close'], color = 'green')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 120, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Adjusting Closing Stock Price
ax5 = bns_stock_prices.add_subplot(6, 1, 5)
ax5 = plt.plot(df['Adj Close'], color = 'orange')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 120, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Volume (number of stocks)
ax6 = bns_stock_prices.add_subplot(6, 1, 6)
ax6 = plt.plot(df['Volume'], color = 'red')
# Adjust axes range(s)
# plt.xticks()
# plt.yticks()
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Stock Volume', fontsize=14)
# Plot grid
plt.grid()

# Show plot
plt.show()

# %% [markdown]
# #### Combined distributions

# %%
# Define figure
bns_stock_prices_comb = plt.figure(figsize=(12,6))

# Open Stock Price
bns_stock_prices_comb = plt.plot(df['Open'], color = 'violet', label = 'Open')
# High Stock Price
bns_stock_prices_comb = plt.plot(df['High'], color = 'indigo', label = 'High')
# Low Stock Price
bns_stock_prices_comb = plt.plot(df['High'], color = 'blue', label = 'Low')
# Closing Stock Price
bns_stock_prices_comb = plt.plot(df['Close'], color = 'green', label = 'Closing')
# Adjusted Closing Stock Price
bns_stock_prices_comb = plt.plot(df['Adj Close'], color = 'orange', 
                                 label = 'Adj. Closing')
# Adjust X and Y-Axes ranges
plt.xticks(np.arange(0, 2200, 200))
plt.yticks(np.arange(30, 110, 5))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Combined Stock Prices Distribution', fontsize=14)
# Plot legend and grid
plt.legend(title="Stock Prices", bbox_to_anchor=(1, 0.7))
plt.grid()

# Show plot
plt.show()

# %%
# Define figure
bns_comb_dist = plt.figure(figsize=(12, 36))

# -- Open Stock Prices --

# Histogram
ax1 = bns_comb_dist.add_subplot(6, 2, 1)
ax1 = plt.hist(x=df['Open'], color='violet', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 110, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Open Stock Price', fontsize=14)

# Box Plot
ax2 = bns_comb_dist.add_subplot(6, 2, 2)
ax2 = sns.boxplot(x=df['Open'], color='violet')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 110, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)

# -- High Stock Prices --

# Histogram
ax3 = bns_comb_dist.add_subplot(6, 2, 3)
ax3 = plt.hist(x=df['High'], color='indigo', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 110, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('High Stock Price', fontsize=14)

# Box Plot
ax4 = bns_comb_dist.add_subplot(6, 2, 4)
ax4 = sns.boxplot(x=df['High'], color='indigo')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 110, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)

# -- Low Stock Prices --

# Histogram
ax5 = bns_comb_dist.add_subplot(6, 2, 5)
ax5 = plt.hist(x=df['Low'], color='blue', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 110, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Low Stock Price', fontsize=14)

# Box Plot
ax6 = bns_comb_dist.add_subplot(6, 2, 6)
ax6 = sns.boxplot(x=df['Low'], color='blue')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 110, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)

# -- Closing Stock Prices --

# Histogram
ax7 = bns_comb_dist.add_subplot(6, 2, 7)
ax7 = plt.hist(x=df['Close'], color='green', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 110, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)

# Box Plot
ax8 = bns_comb_dist.add_subplot(6, 2, 8)
ax8 = sns.boxplot(x=df['Close'], color='green')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 110, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)

# -- Adjusted Closing Stock Prices --

# Histogram
ax9 = bns_comb_dist.add_subplot(6, 2, 9)
ax9 = plt.hist(x=df['Adj Close'], color='orange', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 110, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)

# Box Plot
ax10 = bns_comb_dist.add_subplot(6, 2, 10)
ax10 = sns.boxplot(x=df['Adj Close'], color='orange')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 110, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)

# -- Volume of Stocks --

# Histogram
ax11 = bns_comb_dist.add_subplot(6, 2, 11)
ax11 = plt.hist(x=df['Volume'], color='red', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 26000000, 2000000))
plt.yticks(np.arange(0, 1200, 100))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)

# Box Plot
ax12 = bns_comb_dist.add_subplot(6, 2, 12)
ax12 = sns.boxplot(x=df['Volume'], color='red')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 26000000, 2000000))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)

# Show subplot
plt.show()

# %% [markdown]
# ### 2.4. Feature Engineering

# %%
# Normalize data
sc = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = sc.fit_transform(dataset)

# %%
dataset_scaled
# Out:
# array([[0.34582378],
#        [0.33765958],
#        [0.3564999 ],
#        ...,
#        [0.56583631],
#        [0.5547415 ],
#        [0.55264818]])

# %%
# Split dataset into training set and test set (80/20 split)
training_size = int(len(df)*0.8)
dataset_train = dataset_scaled[:training_size]
dataset_test = dataset_scaled[training_size:]

print('Training set shape: ' + str(dataset_train.shape))
print('Test set shape: ' + str(dataset_test.shape))
# Out:
# Training set shape: (1589, 1)
# Test set shape: (398, 1)

# %%
# Define number of timesteps (number of business days)
timesteps = 60

# %%
# Predict stock price results using n timesteps
def define_training_data(timesteps, dataset):
  """
  timesteps - number of timesteps (business days)
  dataset   - stock prices (training) dataset
  """

  # X - number of timesteps, y - indicators (features) used for training
  X, y = [], []
  for i in range(timesteps, dataset.shape[0]):
    # Get number of timesteps (business days)
    X.append(dataset[i-timesteps:i, 0])
    # Starting date of reporting (increments during model training)
    y.append(dataset[i, 0])
  # Convert to NumPy array
  X, y = np.array(X), np.array(y)
  return X, y

X_train, y_train = define_training_data(timesteps, dataset_train)
print(X_train.shape, y_train.shape)
# Out:
# (1529, 60) (1529,)

# %%
# Reshape (number of rows, number of timesteps (columns), number of predictors)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# %%
X_train
# Out:
# array([[[0.34582378],
#         [0.33765958],
#         [0.3564999 ],
#         ...,
#         [0.41888221],
#         [0.41050873],
#         [0.40946199]],
#
#        [[0.33765958],
#         [0.3564999 ],
#         [0.34770781],
#         ...,
#         [0.41050873],
#         [0.40946199],
#         [0.38790036]],
#
#        [[0.3564999 ],
#         [0.34770781],
#         [0.3424744 ],
#         ...,
#         [0.40946199],
#         [0.38790036],
#         [0.40527532]],
#
#        ...,
#
#        [[0.66506173],
#         [0.64454685],
#         [0.64622141],
#         ...,
#         [0.71760522],
#         [0.70002104],
#         [0.68285529]],
#
#        [[0.64454685],
#         [0.64622141],
#         [0.64287211],
#         ...,
#         [0.70002104],
#         [0.68285529],
#         [0.67615654]],
#
#        [[0.64622141],
#         [0.64287211],
#         [0.64622141],
#         ...,
#         [0.68285529],
#         [0.67615654],
#         [0.65333894]]])

# %%
# X_train: (number of rows, number of columns, number of predictors)
X_train.shape
# Out:
# (1529, 60, 1)

# %% [markdown]
# ## 3. Define and Evaluate LSTM model

# %% [markdown]
# ###### **NOTE:** LSTM - Long Short-Term Memory

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define LSTM model
reg = Sequential()

# -- LSTM layers -- 

# Input and first (hidden) layer (with dropout regularization)
reg.add(LSTM(units=60, return_sequences=True, 
             input_shape=(X_train.shape[1], X_train.shape[2])))
reg.add(Dropout(0.1))

# Additional hidden layers
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=False))
reg.add(Dropout(0.1))

# Output layer
reg.add(Dense(units=X_train.shape[2]))

# Compile model
reg.compile(optimizer='adam', loss='mean_squared_error')

# Summarize LSTM model
reg.summary()

# Train (fit) model
history = reg.fit(X_train, y_train, batch_size=32, epochs=100)

# Plot loss during training (Mean Squared Error - MSE)
plt.plot(history.history['loss'], 'g', label='loss')
# Plot title and labels
plt.title('Training Curve')
plt.xlabel('Epochs')
plt.ylabel('MSE')
# Plot legend and grid
plt.legend()
plt.grid()

# Show loss results
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 60)            14880
#
#  dropout (Dropout)           (None, 60, 60)            0
#
#  lstm_1 (LSTM)               (None, 60, 60)            29040
#
#  dropout_1 (Dropout)         (None, 60, 60)            0
#
#  lstm_2 (LSTM)               (None, 60, 60)            29040
#
#  dropout_2 (Dropout)         (None, 60, 60)            0
#
#  lstm_3 (LSTM)               (None, 60)                29040
#
#  dropout_3 (Dropout)         (None, 60)                0
#
#  dense (Dense)               (None, 1)                 61
#
# =================================================================
# Total params: 102,061
# Trainable params: 102,061
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 48/48 [==============================] - 10s 91ms/step - loss: 0.0220
# Epoch 2/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.0043
# Epoch 3/100
# 48/48 [==============================] - 4s 93ms/step - loss: 0.0044
# Epoch 4/100
# 48/48 [==============================] - 4s 88ms/step - loss: 0.0043
# Epoch 5/100
# 48/48 [==============================] - 5s 100ms/step - loss: 0.0037
# Epoch 6/100
# 48/48 [==============================] - 4s 89ms/step - loss: 0.0035
# Epoch 7/100
# 48/48 [==============================] - 4s 91ms/step - loss: 0.0034
# Epoch 8/100
# 48/48 [==============================] - 5s 99ms/step - loss: 0.0033
# Epoch 9/100
# 48/48 [==============================] - 4s 89ms/step - loss: 0.0030
# Epoch 10/100
# 48/48 [==============================] - 5s 102ms/step - loss: 0.0029
# Epoch 11/100
# 48/48 [==============================] - 4s 93ms/step - loss: 0.0032
# Epoch 12/100
# 48/48 [==============================] - 5s 99ms/step - loss: 0.0029
# Epoch 13/100
# 48/48 [==============================] - 6s 119ms/step - loss: 0.0026
# Epoch 14/100
# 48/48 [==============================] - 4s 89ms/step - loss: 0.0025
# Epoch 15/100
# 48/48 [==============================] - 5s 100ms/step - loss: 0.0023
# Epoch 16/100
# 48/48 [==============================] - 4s 90ms/step - loss: 0.0025
# Epoch 17/100
# 48/48 [==============================] - 4s 89ms/step - loss: 0.0024
# Epoch 18/100
# 48/48 [==============================] - 5s 101ms/step - loss: 0.0022
# Epoch 19/100
# 48/48 [==============================] - 4s 92ms/step - loss: 0.0022
# Epoch 20/100
# 48/48 [==============================] - 5s 97ms/step - loss: 0.0020
# Epoch 21/100
# 48/48 [==============================] - 4s 93ms/step - loss: 0.0018
# Epoch 22/100
# 48/48 [==============================] - 4s 91ms/step - loss: 0.0018
# Epoch 23/100
# 48/48 [==============================] - 5s 113ms/step - loss: 0.0018
# Epoch 24/100
# 48/48 [==============================] - 4s 91ms/step - loss: 0.0018
# Epoch 25/100
# 48/48 [==============================] - 4s 91ms/step - loss: 0.0017
# Epoch 26/100
# 48/48 [==============================] - 5s 99ms/step - loss: 0.0015
# Epoch 27/100
# 48/48 [==============================] - 4s 90ms/step - loss: 0.0019
# Epoch 28/100
# 48/48 [==============================] - 5s 101ms/step - loss: 0.0015
# Epoch 29/100
# 48/48 [==============================] - 4s 91ms/step - loss: 0.0015
# Epoch 30/100
# 48/48 [==============================] - 4s 91ms/step - loss: 0.0016
# Epoch 31/100
# 48/48 [==============================] - 5s 102ms/step - loss: 0.0014
# Epoch 32/100
# 48/48 [==============================] - 4s 90ms/step - loss: 0.0014
# Epoch 33/100
# 48/48 [==============================] - 5s 100ms/step - loss: 0.0015
# Epoch 34/100
# 48/48 [==============================] - 4s 92ms/step - loss: 0.0013
# Epoch 35/100
# 48/48 [==============================] - 4s 90ms/step - loss: 0.0014
# Epoch 36/100
# 48/48 [==============================] - 5s 101ms/step - loss: 0.0014
# Epoch 37/100
# 48/48 [==============================] - 4s 91ms/step - loss: 0.0014
# Epoch 38/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.0014
# Epoch 39/100
# 48/48 [==============================] - 5s 98ms/step - loss: 0.0013
# Epoch 40/100
# 48/48 [==============================] - 4s 91ms/step - loss: 0.0013
# Epoch 41/100
# 48/48 [==============================] - 5s 102ms/step - loss: 0.0014
# Epoch 42/100
# 48/48 [==============================] - 4s 90ms/step - loss: 0.0012
# Epoch 43/100
# 48/48 [==============================] - 4s 92ms/step - loss: 0.0011
# Epoch 44/100
# 48/48 [==============================] - 5s 101ms/step - loss: 0.0013
# Epoch 45/100
# 48/48 [==============================] - 4s 92ms/step - loss: 0.0012
# Epoch 46/100
# 48/48 [==============================] - 5s 101ms/step - loss: 0.0013
# Epoch 47/100
# 48/48 [==============================] - 4s 90ms/step - loss: 0.0012
# Epoch 48/100
# 48/48 [==============================] - 4s 91ms/step - loss: 0.0012
# Epoch 49/100
# 48/48 [==============================] - 5s 99ms/step - loss: 0.0011
# Epoch 50/100
# 48/48 [==============================] - 4s 93ms/step - loss: 0.0011
# Epoch 51/100
# 48/48 [==============================] - 5s 97ms/step - loss: 0.0012
# Epoch 52/100
# 48/48 [==============================] - 5s 96ms/step - loss: 9.7610e-04
# Epoch 53/100
# 48/48 [==============================] - 4s 91ms/step - loss: 0.0010
# Epoch 54/100
# 48/48 [==============================] - 5s 102ms/step - loss: 0.0011
# Epoch 55/100
# 48/48 [==============================] - 4s 93ms/step - loss: 0.0011
# Epoch 56/100
# 48/48 [==============================] - 5s 95ms/step - loss: 0.0010
# Epoch 57/100
# 48/48 [==============================] - 5s 99ms/step - loss: 0.0011
# Epoch 58/100
# 48/48 [==============================] - 4s 92ms/step - loss: 0.0010
# Epoch 59/100
# 48/48 [==============================] - 5s 102ms/step - loss: 9.6300e-04
# Epoch 60/100
# 48/48 [==============================] - 4s 93ms/step - loss: 9.8416e-04
# Epoch 61/100
# 48/48 [==============================] - 4s 93ms/step - loss: 9.4208e-04
# Epoch 62/100
# 48/48 [==============================] - 5s 104ms/step - loss: 8.5218e-04
# Epoch 63/100
# 48/48 [==============================] - 4s 92ms/step - loss: 9.4995e-04
# Epoch 64/100
# 48/48 [==============================] - 5s 103ms/step - loss: 0.0011
# Epoch 65/100
# 48/48 [==============================] - 4s 92ms/step - loss: 9.8663e-04
# Epoch 66/100
# 48/48 [==============================] - 4s 90ms/step - loss: 8.4149e-04
# Epoch 67/100
# 48/48 [==============================] - 5s 102ms/step - loss: 8.6556e-04
# Epoch 68/100
# 48/48 [==============================] - 4s 91ms/step - loss: 8.6024e-04
# Epoch 69/100
# 48/48 [==============================] - 5s 102ms/step - loss: 8.7332e-04
# Epoch 70/100
# 48/48 [==============================] - 4s 91ms/step - loss: 9.2393e-04
# Epoch 71/100
# 48/48 [==============================] - 4s 92ms/step - loss: 8.8183e-04
# Epoch 72/100
# 48/48 [==============================] - 5s 103ms/step - loss: 8.1021e-04
# Epoch 73/100
# 48/48 [==============================] - 4s 93ms/step - loss: 8.3962e-04
# Epoch 74/100
# 48/48 [==============================] - 5s 99ms/step - loss: 8.9174e-04
# Epoch 75/100
# 48/48 [==============================] - 5s 95ms/step - loss: 7.4045e-04
# Epoch 76/100
# 48/48 [==============================] - 4s 91ms/step - loss: 7.8211e-04
# Epoch 77/100
# 48/48 [==============================] - 5s 102ms/step - loss: 7.7706e-04
# Epoch 78/100
# 48/48 [==============================] - 4s 93ms/step - loss: 7.9712e-04
# Epoch 79/100
# 48/48 [==============================] - 5s 96ms/step - loss: 7.1350e-04
# Epoch 80/100
# 48/48 [==============================] - 5s 100ms/step - loss: 7.6149e-04
# Epoch 81/100
# 48/48 [==============================] - 4s 93ms/step - loss: 6.8948e-04
# Epoch 82/100
# 48/48 [==============================] - 5s 100ms/step - loss: 6.6846e-04
# Epoch 83/100
# 48/48 [==============================] - 4s 92ms/step - loss: 7.4395e-04
# Epoch 84/100
# 48/48 [==============================] - 5s 105ms/step - loss: 7.4941e-04
# Epoch 85/100
# 48/48 [==============================] - 5s 98ms/step - loss: 6.4773e-04
# Epoch 86/100
# 48/48 [==============================] - 4s 92ms/step - loss: 6.6713e-04
# Epoch 87/100
# 48/48 [==============================] - 5s 102ms/step - loss: 6.6863e-04
# Epoch 88/100
# 48/48 [==============================] - 4s 92ms/step - loss: 6.7997e-04
# Epoch 89/100
# 48/48 [==============================] - 4s 93ms/step - loss: 7.0416e-04
# Epoch 90/100
# 48/48 [==============================] - 5s 103ms/step - loss: 7.0974e-04
# Epoch 91/100
# 48/48 [==============================] - 4s 92ms/step - loss: 6.9475e-04
# Epoch 92/100
# 48/48 [==============================] - 5s 104ms/step - loss: 7.2595e-04
# Epoch 93/100
# 48/48 [==============================] - 4s 93ms/step - loss: 6.8943e-04
# Epoch 94/100
# 48/48 [==============================] - 4s 92ms/step - loss: 6.0212e-04
# Epoch 95/100
# 48/48 [==============================] - 5s 104ms/step - loss: 6.2835e-04
# Epoch 96/100
# 48/48 [==============================] - 4s 92ms/step - loss: 7.0266e-04
# Epoch 97/100
# 48/48 [==============================] - 5s 102ms/step - loss: 6.4434e-04
# Epoch 98/100
# 48/48 [==============================] - 4s 93ms/step - loss: 5.9026e-04
# Epoch 99/100
# 48/48 [==============================] - 4s 93ms/step - loss: 6.2632e-04
# Epoch 100/100
# 48/48 [==============================] - 5s 103ms/step - loss: 6.4553e-04

# %% [markdown]
# #### Make predictions

# %%
# Get n (number of timesteps) previous stock prices for predicting
inputs = dataset[len(dataset)-len(dataset_test) - timesteps:]
# Reshape input values
inputs = inputs.reshape(-1, 1)
# Scale input values, directly apply transformations (already fitted)
inputs = sc.transform(inputs)

# Define test set structure
X_test = []
# For the entire test set:
for i in range(timesteps, timesteps + len(dataset_test)):
  # Range of values from i-60 to i, first column
  X_test.append(inputs[i-timesteps:i, 0])
# Convert to NumPy array
X_test = np.array(X_test)

# Obtain 3D structure of the test set
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Predict the test set results
predicted_stock_price = reg.predict(X_test)
# Apply inverse transformations
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
real_stock_price = sc.inverse_transform(dataset_test)

# Print predicted and real stock prices side-by-side (if required)
# print(np.concatenate((predicted_stock_price.reshape(len(predicted_stock_price), 1), 
#                       real_stock_price.reshape(len(real_stock_price), 1)), 1 ))

# Print Scores
print('')
print('--- Prediction Scores ---')
print('')
# Mean Absolute Error (MAE)
print('MAE: %.3f' % (mean_absolute_error(real_stock_price, predicted_stock_price)))
# Mean Squared Error (MSE)
print('MSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price)))
# Root Mean Squared Error (RMSE)
print('RMSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price, squared=False)))
# R^2 Score (Goodness-of-Fit)
print('R^2 Score: %.3f%%' % (r2_score(real_stock_price, predicted_stock_price) * 100))
# Out:
# 13/13 [==============================] - 2s 25ms/step
#
# --- Prediction Scores ---
#
# MAE: 0.708
# MSE: 0.910
# RMSE: 0.954
# R^2 Score: 98.695%

# %% [markdown]
# #### Visualize Prediction Results

# %%
# Define results figure
bns_results = plt.figure(figsize=(12,6))

# Plot results
bns_results = plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
bns_results = plt.plot(real_stock_price, color = 'red', label = 'Real Stock Price')
# Adjust Y-Axis range
plt.yticks(np.arange(55, 105, 5))
# Plot title and labels
plt.xlabel('Days')
plt.ylabel('Stock Price ($)')
plt.title('Scotiabank Stock Price Prediction')
# Plot legend and grid
plt.legend()
plt.grid()

# Show figure
plt.show()

# %%
# Combined box plot distributions
box_plots_comb = plt.figure(figsize=(8, 6))

# Box plot for lr_pred
ax1 = box_plots_comb.add_subplot(1, 2, 1)
ax1 = sns.boxplot(y=predicted_stock_price, color='blue', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(50, 120, 10))
# Plot title and labels
plt.xlabel('Predicted Stock Price', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Predicted Stock Price', fontsize=14)

# Box plot for linear_svr_pred
ax2 = box_plots_comb.add_subplot(1, 2, 2)
ax2 = sns.boxplot(y=real_stock_price, color='red', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(50, 120, 10))
# Plot title and label
plt.xlabel('Real Stock Price', fontsize=12)
plt.title('Real Stock Price', fontsize=14)

# Show subplot
plt.show()
