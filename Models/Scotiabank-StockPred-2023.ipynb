# %% [markdown]
# # Scotiabank - Stock Prices Prediction

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas_datareader as webreader
import pandas as pd
import tensorflow as tf
import seaborn as sns
import datetime as dt

from datetime import date, timedelta, datetime
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from pandas_datareader import data
from tensorflow import keras

# %% [markdown]
# ## 2. Data Preprocessing and Visualization

# %% [markdown]
# ### 2.1. Load Data

# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader

# %%
# Import dataset
df = pd.read_csv('BNS-Stocks-2015-2023.csv')

# today = date.today()
# date_today = today.strftime("%Y-%m-%d")
# date_start = '2015-02-03'

# # Read stock quotes from Yahoo Finance
# df = data.DataReader("BNS.TO", data_source='yahoo', start=date_start, end=date_today)
# df = webreader.DataReader('BNS.TO', data_source='yahoo', start=date_start, end=date_today)

# %% [markdown]
# ### 2.2. Analyze Data

# %%
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2015-03-13  63.049999  63.169998  62.209999  62.849998  42.791050
# 1     2015-03-16  62.950001  64.220001  62.830002  63.750000  43.403797
# 2     2015-03-17  63.720001  63.740002  62.560001  63.330002  43.117844
# 3     2015-03-18  63.250000  63.470001  62.639999  63.080002  42.947624
# 4     2015-03-19  63.330002  63.459999  62.720001  63.060001  42.934017
# ...          ...        ...        ...        ...        ...        ...
# 2003  2023-03-08  69.209999  69.269997  68.440002  68.709999  68.709999
# 2004  2023-03-09  68.580002  68.580002  67.120003  67.300003  67.300003
# 2005  2023-03-10  67.000000  67.080002  65.430000  65.730003  65.730003
# 2006  2023-03-13        NaN        NaN        NaN        NaN        NaN
# 2007  2023-03-14  67.080002  67.320000  65.540001  66.000000  66.000000
#
#          Volume
# 0     1827100.0
# 1     2054400.0
# 2     1907600.0
# 3     2023300.0
# 4     2889300.0
# ...         ...
# 2003  2616400.0
# 2004  6672400.0
# 2005  8805400.0
# 2006        NaN
# 2007  4199600.0
#
# [2008 rows x 7 columns]

# %%
# Brief info about dataframe - non-null values and datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2008 entries, 0 to 2007
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2008 non-null   object
#  1   Open       2007 non-null   float64
#  2   High       2007 non-null   float64
#  3   Low        2007 non-null   float64
#  4   Close      2007 non-null   float64
#  5   Adj Close  2007 non-null   float64
#  6   Volume     2007 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 109.9+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date         0
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
# Drop/impute missing values (if required)
df = df.dropna(how='any', axis=0)

# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# imputer.fit_transform(dataset)
# dataset = imputer.transform(dataset)
# df.dropna(inplace=True)

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Input data of np array - Closing price
dataset = df.iloc[:, 4:5].values

# Dataset shape
print(dataset.shape)
# Out:
# (2007, 1)

# %%
# Dataframe statistics on quantitative (numerical) values
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2007.000000  2007.000000  2007.000000  2007.000000  2007.000000
# mean     71.851156    72.285805    71.378764    71.838655    59.481034
# std       9.117743     9.082655     9.172218     9.122449    11.451656
# min      49.139999    50.570000    46.380001    46.720001    36.961864
# 25%      65.485000    65.939999    65.029999    65.459999    50.054603
# 50%      72.940002    73.279999    72.510002    72.900002    59.367191
# 75%      78.204998    78.580002    77.765000    78.150002    64.438748
# max      94.980003    95.000000    93.839996    94.489998    89.312469
#
#              Volume
# count  2.007000e+03
# mean   3.104239e+06
# std    2.177926e+06
# min    3.626000e+05
# 25%    1.716550e+06
# 50%    2.402400e+06
# 75%    3.723950e+06
# max    2.099180e+07

# %% [markdown]
# ### 2.3. Visualize Data

# %% [markdown]
# #### Pariwise relationship between features

# %%
# Pairwise distributions
sns.pairplot(df)

# Show figure
plt.show()

# %% [markdown]
# #### Correlation Map

# %%
# Define figure
plt.figure(figsize=(9,9))

# Correlation Map
sns.heatmap(df.corr(method='pearson'), annot=True, cmap='OrRd', fmt='.2f')
# Adjust X and Y-Axes
plt.xticks(rotation=0)
plt.yticks(rotation=0)
# Plot title
plt.title('Correlation Map')

# Show figure
plt.show()
# Out:
# <ipython-input-12-25126c870ef5>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method='pearson'), annot=True, cmap='OrRd', fmt='.2f')

# %% [markdown]
# #### Individual stock prices and volume distribution

# %%
# Define stock prices figure
bns_stock_prices = plt.figure(figsize=(9,24))

# Open Stock Price
ax1 = bns_stock_prices.add_subplot(6, 1, 1)
ax1 = plt.plot(df['Open'], color = 'violet')
# Rolling Average
ax1 = plt.plot(df['Open'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 120, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# High Stock Price
ax2 = bns_stock_prices.add_subplot(6, 1, 2)
ax2 = plt.plot(df['High'], color = 'blue')
# Rolling Average
ax2 = plt.plot(df['High'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 120, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Low Stock Price
ax3 = bns_stock_prices.add_subplot(6, 1, 3)
ax3 = plt.plot(df['Low'], color = 'turquoise')
# Rolling Average
ax3 = plt.plot(df['Low'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 120, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Closing Stock Price (target variable)
ax4 = bns_stock_prices.add_subplot(6, 1, 4)
ax4 = plt.plot(df['Close'], color = 'green')
# Rolling Average
ax4 = plt.plot(df['Close'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 120, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Adjusting Closing Stock Price
ax5 = bns_stock_prices.add_subplot(6, 1, 5)
ax5 = plt.plot(df['Adj Close'], color = 'lime')
# Rolling Average
ax5 = plt.plot(df['Adj Close'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 120, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Volume (number of stocks)
ax6 = bns_stock_prices.add_subplot(6, 1, 6)
ax6 = plt.plot(df['Volume'], color = 'orange')
# Rolling Average
ax6 = plt.plot(df['Volume'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks()
# plt.yticks()
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Stock Volume', fontsize=14)
# Plot legend and grid
plt.legend(loc = 'upper left')
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Combined distributions

# %%
# Define figure
bns_stock_prices_comb = plt.figure(figsize=(12,6))

# Open Stock Price
bns_stock_prices_comb = plt.plot(df['Open'], color = 'violet', label = 'Open')
# High Stock Price
bns_stock_prices_comb = plt.plot(df['High'], color = 'blue', label = 'High')
# Low Stock Price
bns_stock_prices_comb = plt.plot(df['High'], color = 'turquoise', label = 'Low')
# Closing Stock Price
bns_stock_prices_comb = plt.plot(df['Close'], color = 'green', label = 'Closing')
# Adjusted Closing Stock Price
bns_stock_prices_comb = plt.plot(df['Adj Close'], color = 'lime', 
                                 label = 'Adj. Closing')
# Adjust X and Y-Axes ranges
plt.xticks(np.arange(0, 2200, 200))
plt.yticks(np.arange(30, 110, 5))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Combined Stock Prices Distribution', fontsize=14)
# Plot legend and grid
plt.legend(title="Stock Prices", bbox_to_anchor=(1, 0.7))
plt.grid(True)

# Show plot
plt.show()

# %%
# Define figure
bns_comb_dist = plt.figure(figsize=(11, 36))

# -- Open Stock Prices --

# Histogram
ax1 = bns_comb_dist.add_subplot(6, 2, 1)
ax1 = plt.hist(x=df['Open'], color='violet', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 110, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax2 = bns_comb_dist.add_subplot(6, 2, 2)
ax2 = sns.boxplot(x=df['Open'], color='violet')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 110, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- High Stock Prices --

# Histogram
ax3 = bns_comb_dist.add_subplot(6, 2, 3)
ax3 = plt.hist(x=df['High'], color='blue', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 110, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax4 = bns_comb_dist.add_subplot(6, 2, 4)
ax4 = sns.boxplot(x=df['High'], color='blue')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 110, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Low Stock Prices --

# Histogram
ax5 = bns_comb_dist.add_subplot(6, 2, 5)
ax5 = plt.hist(x=df['Low'], color='turquoise', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 110, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax6 = bns_comb_dist.add_subplot(6, 2, 6)
ax6 = sns.boxplot(x=df['Low'], color='turquoise')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 110, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Closing Stock Prices --

# Histogram
ax7 = bns_comb_dist.add_subplot(6, 2, 7)
ax7 = plt.hist(x=df['Close'], color='green', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 110, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax8 = bns_comb_dist.add_subplot(6, 2, 8)
ax8 = sns.boxplot(x=df['Close'], color='green')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 110, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Adjusted Closing Stock Prices --

# Histogram
ax9 = bns_comb_dist.add_subplot(6, 2, 9)
ax9 = plt.hist(x=df['Adj Close'], color='lime', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 110, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax10 = bns_comb_dist.add_subplot(6, 2, 10)
ax10 = sns.boxplot(x=df['Adj Close'], color='lime')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 110, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Volume of Stocks --

# Histogram
ax11 = bns_comb_dist.add_subplot(6, 2, 11)
ax11 = plt.hist(x=df['Volume'], color='orange', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 26000000, 2000000))
plt.yticks(np.arange(0, 1200, 100))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax12 = bns_comb_dist.add_subplot(6, 2, 12)
ax12 = sns.boxplot(x=df['Volume'], color='orange')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 26000000, 2000000))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)
# Plot grid
plt.grid(True)

# Show subplot
plt.show()

# %% [markdown]
# ### 2.4. Feature Engineering

# %%
# Normalize data
sc = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = sc.fit_transform(dataset)

# %%
dataset_scaled
# Out:
# array([[0.33765958],
#        [0.3564999 ],
#        [0.34770781],
#        ...,
#        [0.43081439],
#        [0.39794857],
#        [0.40360059]])

# %%
# Split dataset into training set and test set (80/20 split)
training_size = int(len(df)*0.8)
dataset_train = dataset_scaled[:training_size]
dataset_test = dataset_scaled[training_size:]

print('Training set shape: ' + str(dataset_train.shape))
print('Test set shape: ' + str(dataset_test.shape))
# Out:
# Training set shape: (1605, 1)
# Test set shape: (402, 1)

# %%
# Define number of timesteps (number of business days)
timesteps = 60

# %%
# Predict stock price results using n timesteps
def define_training_data(timesteps, dataset):
  """
  timesteps - number of timesteps (business days)
  dataset   - stock prices (training) dataset
  """

  # X - number of timesteps, y - indicators (features) used for training
  X, y = [], []
  for i in range(timesteps, dataset.shape[0]):
    # Get number of timesteps (business days)
    X.append(dataset[i-timesteps:i, 0])
    # Starting date of reporting (increments during model training)
    y.append(dataset[i, 0])
  # Convert to NumPy array
  X, y = np.array(X), np.array(y)
  return X, y

X_train, y_train = define_training_data(timesteps, dataset_train)
print(X_train.shape, y_train.shape)
# Out:
# (1545, 60) (1545,)

# %%
# Reshape (number of rows, number of timesteps (columns), number of predictors)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# %%
X_train
# Out:
# array([[[0.33765958],
#         [0.3564999 ],
#         [0.34770781],
#         ...,
#         [0.41050873],
#         [0.40946199],
#         [0.38790036]],
#
#        [[0.3564999 ],
#         [0.34770781],
#         [0.3424744 ],
#         ...,
#         [0.40946199],
#         [0.38790036],
#         [0.40527532]],
#
#        [[0.34770781],
#         [0.3424744 ],
#         [0.3420557 ],
#         ...,
#         [0.38790036],
#         [0.40527532],
#         [0.40967137]],
#
#        ...,
#
#        [[0.67217926],
#         [0.68118072],
#         [0.6847394 ],
#         ...,
#         [0.65250157],
#         [0.65899096],
#         [0.6684112 ]],
#
#        [[0.68118072],
#         [0.6847394 ],
#         [0.68515801],
#         ...,
#         [0.65899096],
#         [0.6684112 ],
#         [0.65208298]],
#
#        [[0.6847394 ],
#         [0.68515801],
#         [0.66548049],
#         ...,
#         [0.6684112 ],
#         [0.65208298],
#         [0.65857235]]])

# %%
# X_train: (number of rows, number of columns, number of predictors)
X_train.shape
# Out:
# (1545, 60, 1)

# %% [markdown]
# ## 3. Define and Evaluate LSTM model

# %% [markdown]
# ###### **NOTE:** LSTM - Long Short-Term Memory

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define LSTM model
reg = Sequential()

# -- LSTM layers -- 

# Input and first (hidden) layer (with dropout regularization)
reg.add(LSTM(units=60, return_sequences=True, 
             input_shape=(X_train.shape[1], X_train.shape[2])))
reg.add(Dropout(0.1))

# Additional hidden layers
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=False))
reg.add(Dropout(0.1))

# Output layer
reg.add(Dense(units=X_train.shape[2]))

# Compile model
reg.compile(optimizer='adam', loss='mean_squared_error')

# Summarize LSTM model
reg.summary()

# Train (fit) model
history = reg.fit(X_train, y_train, batch_size=32, epochs=100)

# Plot loss during training (Mean Squared Error - MSE)
plt.plot(history.history['loss'], 'g', label='loss')
# Plot title and labels
plt.title('Training Curve', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('MSE', fontsize=12)
# Plot legend and grid
plt.legend()
plt.grid(True)

# Show loss results
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 60)            14880
#
#  dropout (Dropout)           (None, 60, 60)            0
#
#  lstm_1 (LSTM)               (None, 60, 60)            29040
#
#  dropout_1 (Dropout)         (None, 60, 60)            0
#
#  lstm_2 (LSTM)               (None, 60, 60)            29040
#
#  dropout_2 (Dropout)         (None, 60, 60)            0
#
#  lstm_3 (LSTM)               (None, 60)                29040
#
#  dropout_3 (Dropout)         (None, 60)                0
#
#  dense (Dense)               (None, 1)                 61
#
# =================================================================
# Total params: 102,061
# Trainable params: 102,061
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 49/49 [==============================] - 16s 140ms/step - loss: 0.0257
# Epoch 2/100
# 49/49 [==============================] - 8s 161ms/step - loss: 0.0043
# Epoch 3/100
# 49/49 [==============================] - 7s 146ms/step - loss: 0.0042
# Epoch 4/100
# 49/49 [==============================] - 8s 154ms/step - loss: 0.0039
# Epoch 5/100
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0035
# Epoch 6/100
# 49/49 [==============================] - 7s 141ms/step - loss: 0.0035
# Epoch 7/100
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0034
# Epoch 8/100
# 49/49 [==============================] - 7s 140ms/step - loss: 0.0033
# Epoch 9/100
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0030
# Epoch 10/100
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0027
# Epoch 11/100
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0031
# Epoch 12/100
# 49/49 [==============================] - 9s 173ms/step - loss: 0.0025
# Epoch 13/100
# 49/49 [==============================] - 7s 153ms/step - loss: 0.0023
# Epoch 14/100
# 49/49 [==============================] - 7s 151ms/step - loss: 0.0024
# Epoch 15/100
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0022
# Epoch 16/100
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0021
# Epoch 17/100
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0020
# Epoch 18/100
# 49/49 [==============================] - 7s 146ms/step - loss: 0.0022
# Epoch 19/100
# 49/49 [==============================] - 8s 157ms/step - loss: 0.0019
# Epoch 20/100
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0018
# Epoch 21/100
# 49/49 [==============================] - 7s 140ms/step - loss: 0.0017
# Epoch 22/100
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0018
# Epoch 23/100
# 49/49 [==============================] - 7s 152ms/step - loss: 0.0017
# Epoch 24/100
# 49/49 [==============================] - 7s 150ms/step - loss: 0.0018
# Epoch 25/100
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0016
# Epoch 26/100
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0017
# Epoch 27/100
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0016
# Epoch 28/100
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0015
# Epoch 29/100
# 49/49 [==============================] - 8s 157ms/step - loss: 0.0015
# Epoch 30/100
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0015
# Epoch 31/100
# 49/49 [==============================] - 7s 141ms/step - loss: 0.0014
# Epoch 32/100
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0014
# Epoch 33/100
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0014
# Epoch 34/100
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0013
# Epoch 35/100
# 49/49 [==============================] - 8s 160ms/step - loss: 0.0013
# Epoch 36/100
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0014
# Epoch 37/100
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0014
# Epoch 38/100
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0014
# Epoch 39/100
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0015
# Epoch 40/100
# 49/49 [==============================] - 8s 154ms/step - loss: 0.0011
# Epoch 41/100
# 49/49 [==============================] - 7s 147ms/step - loss: 0.0012
# Epoch 42/100
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0013
# Epoch 43/100
# 49/49 [==============================] - 7s 144ms/step - loss: 0.0011
# Epoch 44/100
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011
# Epoch 45/100
# 49/49 [==============================] - 7s 148ms/step - loss: 0.0012
# Epoch 46/100
# 49/49 [==============================] - 7s 150ms/step - loss: 0.0011
# Epoch 47/100
# 49/49 [==============================] - 8s 159ms/step - loss: 0.0013
# Epoch 48/100
# 49/49 [==============================] - 7s 139ms/step - loss: 0.0010
# Epoch 49/100
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0011
# Epoch 50/100
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0011
# Epoch 51/100
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0011
# Epoch 52/100
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0012
# Epoch 53/100
# 49/49 [==============================] - 7s 141ms/step - loss: 0.0010
# Epoch 54/100
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0010
# Epoch 55/100
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0010
# Epoch 56/100
# 49/49 [==============================] - 8s 161ms/step - loss: 9.9840e-04
# Epoch 57/100
# 49/49 [==============================] - 8s 159ms/step - loss: 0.0010
# Epoch 58/100
# 49/49 [==============================] - 7s 142ms/step - loss: 9.3889e-04
# Epoch 59/100
# 49/49 [==============================] - 8s 162ms/step - loss: 9.0969e-04
# Epoch 60/100
# 49/49 [==============================] - 7s 141ms/step - loss: 9.1893e-04
# Epoch 61/100
# 49/49 [==============================] - 8s 164ms/step - loss: 8.3947e-04
# Epoch 62/100
# 49/49 [==============================] - 8s 159ms/step - loss: 8.9865e-04
# Epoch 63/100
# 49/49 [==============================] - 7s 148ms/step - loss: 9.1985e-04
# Epoch 64/100
# 49/49 [==============================] - 8s 166ms/step - loss: 9.6901e-04
# Epoch 65/100
# 49/49 [==============================] - 7s 145ms/step - loss: 0.0010
# Epoch 66/100
# 49/49 [==============================] - 8s 165ms/step - loss: 8.7518e-04
# Epoch 67/100
# 49/49 [==============================] - 9s 188ms/step - loss: 9.1869e-04
# Epoch 68/100
# 49/49 [==============================] - 7s 145ms/step - loss: 0.0011
# Epoch 69/100
# 49/49 [==============================] - 8s 166ms/step - loss: 7.9293e-04
# Epoch 70/100
# 49/49 [==============================] - 7s 146ms/step - loss: 8.4253e-04
# Epoch 71/100
# 49/49 [==============================] - 8s 164ms/step - loss: 8.4851e-04
# Epoch 72/100
# 49/49 [==============================] - 8s 165ms/step - loss: 9.0471e-04
# Epoch 73/100
# 49/49 [==============================] - 7s 141ms/step - loss: 7.2882e-04
# Epoch 74/100
# 49/49 [==============================] - 8s 163ms/step - loss: 8.1690e-04
# Epoch 75/100
# 49/49 [==============================] - 7s 141ms/step - loss: 7.7448e-04
# Epoch 76/100
# 49/49 [==============================] - 8s 165ms/step - loss: 7.4782e-04
# Epoch 77/100
# 49/49 [==============================] - 8s 164ms/step - loss: 8.8299e-04
# Epoch 78/100
# 49/49 [==============================] - 7s 143ms/step - loss: 7.1069e-04
# Epoch 79/100
# 49/49 [==============================] - 8s 163ms/step - loss: 8.3273e-04
# Epoch 80/100
# 49/49 [==============================] - 7s 143ms/step - loss: 7.6360e-04
# Epoch 81/100
# 49/49 [==============================] - 8s 164ms/step - loss: 7.1408e-04
# Epoch 82/100
# 49/49 [==============================] - 8s 164ms/step - loss: 7.4967e-04
# Epoch 83/100
# 49/49 [==============================] - 7s 142ms/step - loss: 6.7300e-04
# Epoch 84/100
# 49/49 [==============================] - 8s 163ms/step - loss: 6.9048e-04
# Epoch 85/100
# 49/49 [==============================] - 7s 142ms/step - loss: 6.8659e-04
# Epoch 86/100
# 49/49 [==============================] - 8s 164ms/step - loss: 7.0425e-04
# Epoch 87/100
# 49/49 [==============================] - 8s 156ms/step - loss: 7.1317e-04
# Epoch 88/100
# 49/49 [==============================] - 7s 146ms/step - loss: 7.2016e-04
# Epoch 89/100
# 49/49 [==============================] - 8s 164ms/step - loss: 6.5569e-04
# Epoch 90/100
# 49/49 [==============================] - 8s 164ms/step - loss: 6.6422e-04
# Epoch 91/100
# 49/49 [==============================] - 8s 163ms/step - loss: 6.6937e-04
# Epoch 92/100
# 49/49 [==============================] - 8s 163ms/step - loss: 7.1332e-04
# Epoch 93/100
# 49/49 [==============================] - 7s 145ms/step - loss: 7.0605e-04
# Epoch 94/100
# 49/49 [==============================] - 8s 164ms/step - loss: 6.1254e-04
# Epoch 95/100
# 49/49 [==============================] - 7s 141ms/step - loss: 6.2353e-04
# Epoch 96/100
# 49/49 [==============================] - 8s 163ms/step - loss: 6.3383e-04
# Epoch 97/100
# 49/49 [==============================] - 8s 159ms/step - loss: 6.6881e-04
# Epoch 98/100
# 49/49 [==============================] - 7s 144ms/step - loss: 6.2480e-04
# Epoch 99/100
# 49/49 [==============================] - 8s 162ms/step - loss: 6.9120e-04
# Epoch 100/100
# 49/49 [==============================] - 7s 142ms/step - loss: 5.8417e-04

# %% [markdown]
# #### Make predictions

# %%
# Get n (number of timesteps) previous stock prices for predicting
inputs = dataset[len(dataset)-len(dataset_test) - timesteps:]
# Reshape input values
inputs = inputs.reshape(-1, 1)
# Scale input values, directly apply transformations (already fitted)
inputs = sc.transform(inputs)

# Define test set structure
X_test = []
# For the entire test set:
for i in range(timesteps, timesteps + len(dataset_test)):
  # Range of values from i-60 to i, first column
  X_test.append(inputs[i-timesteps:i, 0])
# Convert to NumPy array
X_test = np.array(X_test)

# Obtain 3D structure of the test set
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Predict the test set results
predicted_stock_price = reg.predict(X_test)
# Apply inverse transformations
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
real_stock_price = sc.inverse_transform(dataset_test)

# Print predicted and real stock prices side-by-side (if required)
# print(np.concatenate((predicted_stock_price.reshape(len(predicted_stock_price), 1), 
#                       real_stock_price.reshape(len(real_stock_price), 1)), 1 ))

# Print Scores
print('')
print('--- Prediction Scores ---')
print('')
# Mean Absolute Error (MAE)
print('MAE: %.3f' % (mean_absolute_error(real_stock_price, predicted_stock_price)))
# Mean Squared Error (MSE)
print('MSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price)))
# Root Mean Squared Error (RMSE)
print('RMSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price, squared=False)))
# R^2 Score (Goodness-of-Fit)
print('R^2 Score: %.3f%%' % (r2_score(real_stock_price, predicted_stock_price) * 100))
# Out:
# 13/13 [==============================] - 2s 39ms/step
#
# --- Prediction Scores ---
#
# MAE: 0.718
# MSE: 0.938
# RMSE: 0.969
# R^2 Score: 98.714%

# %% [markdown]
# #### Visualize Prediction Results

# %%
# Define figure
bns_pred_results = plt.figure(figsize=(10,6))

# Plot results
bns_pred_results = plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
# Plot rolling average (over 7 days)
df_real = pd.DataFrame(predicted_stock_price)
rolling_avg_pred = df_real.rolling(window = 7).mean()
bns_pred_results = plt.plot(rolling_avg_pred, "--", color = 'red', label = 'Rolling Average')

# Adjust Y-Axis range
plt.yticks(np.arange(55, 105, 5))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Stock Price ($)', fontsize=12)
plt.title('Predicted Stock Price', fontsize=14)
# Plot legend and grid
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
# Define figure
bns_real_results = plt.figure(figsize=(10,6))

# Plot results
bns_real_results = plt.plot(real_stock_price, color = 'blue', label = 'Real Stock Price')
# Plot rolling average (over 7 days)
df_real = pd.DataFrame(real_stock_price)
rolling_avg_real = df_real.rolling(window = 7).mean()
bns_real_results = plt.plot(rolling_avg_real, "--", color = 'red', label = 'Rolling Average')

# Adjust Y-Axis range
plt.yticks(np.arange(55, 105, 5))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Stock Price ($)', fontsize=12)
plt.title('Real Stock Price', fontsize=14)
# Plot legend and grid
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
# Define results figure
bns_results = plt.figure(figsize=(12,6))

# Plot results
bns_results = plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
bns_results = plt.plot(real_stock_price, color = 'red', label = 'Real Stock Price')
# Adjust Y-Axis range
plt.yticks(np.arange(55, 105, 5))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Stock Price ($)', fontsize=12)
plt.title('Scotiabank Stock Price Prediction', fontsize=14)
# Plot legend and grid
plt.legend()
plt.grid(True)

# Show figure
plt.show()

# %%
# Combined box plot distributions
box_plots_comb = plt.figure(figsize=(8, 6))

# Box plot for lr_pred
ax1 = box_plots_comb.add_subplot(1, 2, 1)
ax1 = sns.boxplot(y=predicted_stock_price, color='blue', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(50, 120, 10))
# Plot title and labels
plt.xlabel('Predicted Stock Price', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Predicted Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box plot for linear_svr_pred
ax2 = box_plots_comb.add_subplot(1, 2, 2)
ax2 = sns.boxplot(y=real_stock_price, color='red', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(50, 120, 10))
# Plot title and label
plt.xlabel('Real Stock Price', fontsize=12)
plt.title('Real Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Show subplot
plt.show()
