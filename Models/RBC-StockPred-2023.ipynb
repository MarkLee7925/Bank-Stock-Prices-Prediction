# %% [markdown]
# # RBC - Stock Prices Prediction

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas_datareader as webreader
import pandas as pd
import tensorflow as tf
import seaborn as sns
import datetime as dt

from datetime import date, timedelta, datetime
from sklearn.preprocessing import MinMaxScaler
from pandas_datareader import data
from tensorflow import keras

# %% [markdown]
# ## 2. Data Preprocessing and Visualization

# %% [markdown]
# ### 2.1. Load Data

# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader

# %%
# Import dataset
df = pd.read_csv('RBC-Stocks-2015-2023.csv')

# today = date.today()
# date_today = today.strftime("%Y-%m-%d")
# date_start = '2016-01-01'

# # Read stock quotes from Yahoo Finance
# df = webreader.DataReader('RY.TO', data_source='yahoo', start=date_start, end=date_today)

# Input data of np array - Closing price
dataset = df.iloc[:, 4:5].values

# Dataset shape
print(dataset.shape)
# Out:
# (1987, 1)

# %% [markdown]
# ### 2.2. Analyze Data

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-03-12   76.010002   76.760002   75.980003   76.349998   55.762344
# 1     2015-03-13   76.230003   76.269997   75.099998   75.690002   55.280315
# 2     2015-03-16   75.779999   76.760002   75.610001   76.300003   55.725849
# 3     2015-03-17   75.830002   76.309998   75.199997   76.160004   55.623589
# 4     2015-03-18   76.089996   76.320000   75.379997   75.949997   55.470219
# ...          ...         ...         ...         ...         ...         ...
# 1982  2023-02-03  136.500000  138.199997  136.460007  138.149994  138.149994
# 1983  2023-02-06  137.630005  138.250000  137.070007  138.119995  138.119995
# 1984  2023-02-07  137.589996  139.070007  137.419998  138.619995  138.619995
# 1985  2023-02-08  138.229996  139.639999  138.039993  139.550003  139.550003
# 1986  2023-02-09  139.990005  140.179993  138.550003  139.250000  139.250000
#
#        Volume
# 0     1969300
# 1     1737400
# 2     2689300
# 3     2470400
# 4     2448400
# ...       ...
# 1982  4559100
# 1983  7063600
# 1984  5276300
# 1985  3103900
# 1986  3103000
#
# [1987 rows x 7 columns]

# %%
# Brief info about dataframe - non-null values and datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987 entries, 0 to 1986
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1987 non-null   object
#  1   Open       1987 non-null   float64
#  2   High       1987 non-null   float64
#  3   Low        1987 non-null   float64
#  4   Close      1987 non-null   float64
#  5   Adj Close  1987 non-null   float64
#  6   Volume     1987 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 108.8+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# from sklearn.impute import SimpleImputer

# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# imputer.fit_transform(dataset)
# dataset = imputer.transform(dataset)
# df.dropna(inplace=True)

# %%
# Dataframe statistics on quantitative (numerical) values
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1987.000000  1987.000000  1987.000000  1987.000000  1987.000000
# mean    101.665541   102.284253   101.053246   101.693986    88.524928
# std      18.942058    19.034059    18.883428    18.956617    23.851155
# min      65.300003    65.440002    64.519997    65.000000    49.399590
# 25%      90.105000    91.145001    89.520001    90.300003    74.212402
# 50%     100.199997   100.900002    99.709999   100.400002    84.790741
# 75%     109.189999   109.549999   108.684998   109.229999   100.244316
# max     148.899994   149.600006   147.750000   149.149994   142.208099
#
#              Volume
# count  1.987000e+03
# mean   3.122343e+06
# std    2.057345e+06
# min    3.688000e+05
# 25%    1.856700e+06
# 50%    2.499600e+06
# 75%    3.627100e+06
# max    1.605430e+07

# %% [markdown]
# ### 2.3. Visualize Data

# %% [markdown]
# #### Pariwise relationship between features

# %%
# Pairwise distributions
sns.pairplot(df)

# Show figure
plt.show()

# %% [markdown]
# #### Correlation Map

# %%
# Define figure
plt.figure(figsize=(10,10))

# Correlation Map
sns.heatmap(df.corr(method='pearson'), annot=True, cmap='YlGnBu', fmt='.2f')
# Adjust X and Y-Axes
plt.xticks(rotation=0)
plt.yticks(rotation=0)
# Plot title
plt.title('Correlation Map')

# Show figure
plt.show()

# %% [markdown]
# #### Individual stock prices and volume distribution

# %%
# Define stock prices figure
rbc_stock_prices = plt.figure(figsize=(10,24))

# Open Stock Price
ax1 = rbc_stock_prices.add_subplot(6, 1, 1)
ax1 = plt.plot(df['Open'], color = 'violet')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(40, 170, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid()

# High Stock Price
ax2 = rbc_stock_prices.add_subplot(6, 1, 2)
ax2 = plt.plot(df['High'], color = 'indigo')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(40, 170, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Low Stock Price
ax3 = rbc_stock_prices.add_subplot(6, 1, 3)
ax3 = plt.plot(df['Low'], color = 'blue')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(40, 170, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Closing Stock Price (target variable)
ax4 = rbc_stock_prices.add_subplot(6, 1, 4)
ax4 = plt.plot(df['Close'], color = 'green')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(40, 170, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Adjusting Closing Stock Price
ax5 = rbc_stock_prices.add_subplot(6, 1, 5)
ax5 = plt.plot(df['Adj Close'], color = 'orange')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(40, 170, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Volume (number of stocks)
ax6 = rbc_stock_prices.add_subplot(6, 1, 6)
ax6 = plt.plot(df['Volume'], color = 'red')
# Adjust axes range(s)
# plt.xticks()
# plt.yticks()
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Stock Volume', fontsize=14)
# Plot grid
plt.grid()

# Show plot
plt.show()

# %% [markdown]
# #### Combined distributions

# %%
# Define figure
rbc_stock_prices_comb = plt.figure(figsize=(12,6))

# Open Stock Price
rbc_stock_prices_comb = plt.plot(df['Open'], color = 'violet', label = 'Open')
# High Stock Price
rbc_stock_prices_comb = plt.plot(df['High'], color = 'indigo', label = 'High')
# Low Stock Price
rbc_stock_prices_comb = plt.plot(df['High'], color = 'blue', label = 'Low')
# Closing Stock Price
rbc_stock_prices_comb = plt.plot(df['Close'], color = 'green', label = 'Closing')
# Adjusted Closing Stock Price
rbc_stock_prices_comb = plt.plot(df['Adj Close'], color = 'orange', 
                                 label = 'Adj. Closing')
# Adjust X and Y-Axes ranges
plt.xticks(np.arange(0, 2200, 200))
plt.yticks(np.arange(40, 165, 5))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Combined Stock Prices Distribution', fontsize=14)
# Plot legend and grid
plt.legend(title="Stock Prices", bbox_to_anchor=(1, 0.7))
plt.grid()

# Show plot
plt.show()

# %%
# Define figure
rbc_comb_dist = plt.figure(figsize=(12, 36))

# -- Open Stock Prices --

# Histogram
ax1 = rbc_comb_dist.add_subplot(6, 2, 1)
ax1 = plt.hist(x=df['Open'], color='violet', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(40, 170, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Open Stock Price', fontsize=14)

# Box Plot
ax2 = rbc_comb_dist.add_subplot(6, 2, 2)
ax2 = sns.boxplot(x=df['Open'], color='violet')
# Adjust X-Axis range(s)
plt.xticks(np.arange(40, 170, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)

# -- High Stock Prices --

# Histogram
ax3 = rbc_comb_dist.add_subplot(6, 2, 3)
ax3 = plt.hist(x=df['High'], color='indigo', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(40, 170, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('High Stock Price', fontsize=14)

# Box Plot
ax4 = rbc_comb_dist.add_subplot(6, 2, 4)
ax4 = sns.boxplot(x=df['High'], color='indigo')
# Adjust X-Axis range(s)
plt.xticks(np.arange(40, 170, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)

# -- Low Stock Prices --

# Histogram
ax5 = rbc_comb_dist.add_subplot(6, 2, 5)
ax5 = plt.hist(x=df['Low'], color='blue', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(40, 170, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Low Stock Price', fontsize=14)

# Box Plot
ax6 = rbc_comb_dist.add_subplot(6, 2, 6)
ax6 = sns.boxplot(x=df['Low'], color='blue')
# Adjust X-Axis range(s)
plt.xticks(np.arange(40, 170, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)

# -- Closing Stock Prices --

# Histogram
ax7 = rbc_comb_dist.add_subplot(6, 2, 7)
ax7 = plt.hist(x=df['Close'], color='green', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(40, 170, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)

# Box Plot
ax8 = rbc_comb_dist.add_subplot(6, 2, 8)
ax8 = sns.boxplot(x=df['Close'], color='green')
# Adjust X-Axis range(s)
plt.xticks(np.arange(40, 170, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)

# -- Adjusted Closing Stock Prices --

# Histogram
ax9 = rbc_comb_dist.add_subplot(6, 2, 9)
ax9 = plt.hist(x=df['Adj Close'], color='orange', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(40, 170, 10))
plt.yticks(np.arange(0, 520, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)

# Box Plot
ax10 = rbc_comb_dist.add_subplot(6, 2, 10)
ax10 = sns.boxplot(x=df['Adj Close'], color='orange')
# Adjust X-Axis range(s)
plt.xticks(np.arange(40, 170, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)

# -- Volume of Stocks --

# Histogram
ax11 = rbc_comb_dist.add_subplot(6, 2, 11)
ax11 = plt.hist(x=df['Volume'], color='red', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 20000000, 2000000))
plt.yticks(np.arange(0, 1100, 100))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)

# Box Plot
ax12 = rbc_comb_dist.add_subplot(6, 2, 12)
ax12 = sns.boxplot(x=df['Volume'], color='red')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 20000000, 2000000))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)

# Show subplot
plt.show()

# %% [markdown]
# ### 2.4. Feature Engineering

# %%
# Normalize data
sc = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = sc.fit_transform(dataset)

# %%
dataset_scaled
# Out:
# array([[0.13487818],
#        [0.12703509],
#        [0.13428406],
#        ...,
#        [0.87486631],
#        [0.8859181 ],
#        [0.882353  ]])

# %%
# Split dataset into training set and test set (80/20 split)
training_size = int(len(df)*0.8)
dataset_train = dataset_scaled[:training_size]
dataset_test = dataset_scaled[training_size:]

print('Training set shape: ' + str(dataset_train.shape))
print('Test set shape: ' + str(dataset_test.shape))
# Out:
# Training set shape: (1589, 1)
# Test set shape: (398, 1)

# %%
# Define number of timesteps (number of business days)
timesteps = 60

# %%
# Predict stock price results using n timesteps
def define_training_data(timesteps, dataset):
  """
  timesteps - number of timesteps (business days)
  dataset   - stock prices (training) dataset
  """

  # X - number of timesteps, y - indicators (features) used for training
  X, y = [], []
  for i in range(timesteps, dataset.shape[0]):
    # Get number of timesteps (business days)
    X.append(dataset[i-timesteps:i, 0])
    # Starting date of reporting (increments during model training)
    y.append(dataset[i, 0])
  # Convert to NumPy array
  X, y = np.array(X), np.array(y)
  return X, y

X_train, y_train = define_training_data(timesteps, dataset_train)
print(X_train.shape, y_train.shape)
# Out:
# (1529, 60) (1529,)

# %%
# Reshape (number of rows, number of timesteps (columns), number of predictors)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# %%
X_train
# Out:
# array([[[0.13487818],
#         [0.12703509],
#         [0.13428406],
#         ...,
#         [0.18146165],
#         [0.17825313],
#         [0.17326207]],
#
#        [[0.12703509],
#         [0.13428406],
#         [0.13262038],
#         ...,
#         [0.17825313],
#         [0.17326207],
#         [0.16197264]],
#
#        [[0.13428406],
#         [0.13262038],
#         [0.13012475],
#         ...,
#         [0.17326207],
#         [0.16197264],
#         [0.15353534]],
#
#        ...,
#
#        [[0.62495543],
#         [0.62008323],
#         [0.62198455],
#         ...,
#         [0.72525257],
#         [0.72941178],
#         [0.72465844]],
#
#        [[0.62008323],
#         [0.62198455],
#         [0.63006537],
#         ...,
#         [0.72941178],
#         [0.72465844],
#         [0.72430186]],
#
#        [[0.62198455],
#         [0.63006537],
#         [0.63565065],
#         ...,
#         [0.72465844],
#         [0.72430186],
#         [0.72228168]]])

# %%
# X_train: (number of rows, number of columns, number of predictors)
X_train.shape
# Out:
# (1529, 60, 1)

# %% [markdown]
# ## 3. Define and Evaluate LSTM model

# %% [markdown]
# ###### **NOTE:** LSTM - Long Short-Term Memory

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define model
reg = Sequential()

# -- LSTM layers -- 

# Input and first (hidden) layer (with dropout regularization)
reg.add(LSTM(units=70, return_sequences=True, 
             input_shape=(X_train.shape[1], X_train.shape[2])))

# Additional hidden layers
reg.add(Dropout(0.2))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.2))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.2))
reg.add(LSTM(units=60, return_sequences=False))
reg.add(Dropout(0.15))

# Output layer
reg.add(Dense(units=X_train.shape[2]))

# Compile model
reg.compile(optimizer='adam', loss='mean_squared_error')

# Summarize LSTM model
reg.summary()

# Train (fit) model
history = reg.fit(X_train, y_train, batch_size=32, epochs=100)

# Plot loss during training (Mean Squared Error - MSE)
plt.plot(history.history['loss'], 'g', label='loss')
# Plot title and labels
plt.title('Training Curve')
plt.xlabel('Epochs')
plt.ylabel('MSE')
# Plot legend and grid
plt.legend()
plt.grid()

# Show loss results
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 70)            20160
#
#  dropout (Dropout)           (None, 60, 70)            0
#
#  lstm_1 (LSTM)               (None, 60, 60)            31440
#
#  dropout_1 (Dropout)         (None, 60, 60)            0
#
#  lstm_2 (LSTM)               (None, 60, 60)            29040
#
#  dropout_2 (Dropout)         (None, 60, 60)            0
#
#  lstm_3 (LSTM)               (None, 60)                29040
#
#  dropout_3 (Dropout)         (None, 60)                0
#
#  dense (Dense)               (None, 1)                 61
#
# =================================================================
# Total params: 109,741
# Trainable params: 109,741
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 48/48 [==============================] - 11s 109ms/step - loss: 0.0129
# Epoch 2/100
# 48/48 [==============================] - 6s 122ms/step - loss: 0.0025
# Epoch 3/100
# 48/48 [==============================] - 5s 109ms/step - loss: 0.0025
# Epoch 4/100
# 48/48 [==============================] - 6s 117ms/step - loss: 0.0023
# Epoch 5/100
# 48/48 [==============================] - 5s 108ms/step - loss: 0.0021
# Epoch 6/100
# 48/48 [==============================] - 5s 109ms/step - loss: 0.0022
# Epoch 7/100
# 48/48 [==============================] - 6s 115ms/step - loss: 0.0018
# Epoch 8/100
# 48/48 [==============================] - 5s 110ms/step - loss: 0.0017
# Epoch 9/100
# 48/48 [==============================] - 6s 120ms/step - loss: 0.0016
# Epoch 10/100
# 48/48 [==============================] - 5s 113ms/step - loss: 0.0014
# Epoch 11/100
# 48/48 [==============================] - 6s 121ms/step - loss: 0.0014
# Epoch 12/100
# 48/48 [==============================] - 6s 117ms/step - loss: 0.0014
# Epoch 13/100
# 48/48 [==============================] - 6s 124ms/step - loss: 0.0015
# Epoch 14/100
# 48/48 [==============================] - 7s 141ms/step - loss: 0.0012
# Epoch 15/100
# 48/48 [==============================] - 6s 125ms/step - loss: 0.0013
# Epoch 16/100
# 48/48 [==============================] - 5s 111ms/step - loss: 0.0014
# Epoch 17/100
# 48/48 [==============================] - 6s 119ms/step - loss: 0.0012
# Epoch 18/100
# 48/48 [==============================] - 5s 111ms/step - loss: 0.0013
# Epoch 19/100
# 48/48 [==============================] - 6s 119ms/step - loss: 0.0012
# Epoch 20/100
# 48/48 [==============================] - 5s 107ms/step - loss: 0.0012
# Epoch 21/100
# 48/48 [==============================] - 7s 136ms/step - loss: 0.0012
# Epoch 22/100
# 48/48 [==============================] - 5s 110ms/step - loss: 0.0012
# Epoch 23/100
# 48/48 [==============================] - 6s 123ms/step - loss: 9.9151e-04
# Epoch 24/100
# 48/48 [==============================] - 5s 110ms/step - loss: 9.5835e-04
# Epoch 25/100
# 48/48 [==============================] - 6s 120ms/step - loss: 0.0011
# Epoch 26/100
# 48/48 [==============================] - 5s 112ms/step - loss: 0.0010
# Epoch 27/100
# 48/48 [==============================] - 5s 109ms/step - loss: 0.0010
# Epoch 28/100
# 48/48 [==============================] - 6s 117ms/step - loss: 9.4643e-04
# Epoch 29/100
# 48/48 [==============================] - 5s 107ms/step - loss: 8.8050e-04
# Epoch 30/100
# 48/48 [==============================] - 6s 119ms/step - loss: 9.1737e-04
# Epoch 31/100
# 48/48 [==============================] - 5s 108ms/step - loss: 9.5910e-04
# Epoch 32/100
# 48/48 [==============================] - 6s 122ms/step - loss: 9.1506e-04
# Epoch 33/100
# 48/48 [==============================] - 5s 109ms/step - loss: 7.9904e-04
# Epoch 34/100
# 48/48 [==============================] - 6s 122ms/step - loss: 8.1866e-04
# Epoch 35/100
# 48/48 [==============================] - 5s 110ms/step - loss: 7.8218e-04
# Epoch 36/100
# 48/48 [==============================] - 6s 128ms/step - loss: 9.2969e-04
# Epoch 37/100
# 48/48 [==============================] - 6s 116ms/step - loss: 7.9703e-04
# Epoch 38/100
# 48/48 [==============================] - 7s 137ms/step - loss: 7.3825e-04
# Epoch 39/100
# 48/48 [==============================] - 5s 111ms/step - loss: 8.3517e-04
# Epoch 40/100
# 48/48 [==============================] - 6s 130ms/step - loss: 8.4664e-04
# Epoch 41/100
# 48/48 [==============================] - 6s 117ms/step - loss: 7.6313e-04
# Epoch 42/100
# 48/48 [==============================] - 6s 121ms/step - loss: 8.8329e-04
# Epoch 43/100
# 48/48 [==============================] - 5s 112ms/step - loss: 8.1271e-04
# Epoch 44/100
# 48/48 [==============================] - 6s 121ms/step - loss: 7.3875e-04
# Epoch 45/100
# 48/48 [==============================] - 6s 115ms/step - loss: 7.7052e-04
# Epoch 46/100
# 48/48 [==============================] - 6s 117ms/step - loss: 7.4804e-04
# Epoch 47/100
# 48/48 [==============================] - 5s 113ms/step - loss: 6.8061e-04
# Epoch 48/100
# 48/48 [==============================] - 6s 117ms/step - loss: 7.3165e-04
# Epoch 49/100
# 48/48 [==============================] - 6s 121ms/step - loss: 7.5750e-04
# Epoch 50/100
# 48/48 [==============================] - 5s 113ms/step - loss: 7.6135e-04
# Epoch 51/100
# 48/48 [==============================] - 6s 124ms/step - loss: 7.0568e-04
# Epoch 52/100
# 48/48 [==============================] - 6s 117ms/step - loss: 6.3695e-04
# Epoch 53/100
# 48/48 [==============================] - 6s 126ms/step - loss: 6.5469e-04
# Epoch 54/100
# 48/48 [==============================] - 6s 119ms/step - loss: 6.7352e-04
# Epoch 55/100
# 48/48 [==============================] - 7s 143ms/step - loss: 6.5223e-04
# Epoch 56/100
# 48/48 [==============================] - 6s 128ms/step - loss: 6.6759e-04
# Epoch 57/100
# 48/48 [==============================] - 7s 138ms/step - loss: 5.8732e-04
# Epoch 58/100
# 48/48 [==============================] - 7s 140ms/step - loss: 6.0762e-04
# Epoch 59/100
# 48/48 [==============================] - 5s 113ms/step - loss: 6.3212e-04
# Epoch 60/100
# 48/48 [==============================] - 6s 126ms/step - loss: 6.1379e-04
# Epoch 61/100
# 48/48 [==============================] - 6s 128ms/step - loss: 6.5608e-04
# Epoch 62/100
# 48/48 [==============================] - 6s 133ms/step - loss: 6.4673e-04
# Epoch 63/100
# 48/48 [==============================] - 6s 115ms/step - loss: 6.8857e-04
# Epoch 64/100
# 48/48 [==============================] - 6s 124ms/step - loss: 5.9391e-04
# Epoch 65/100
# 48/48 [==============================] - 5s 112ms/step - loss: 5.6327e-04
# Epoch 66/100
# 48/48 [==============================] - 6s 121ms/step - loss: 5.9485e-04
# Epoch 67/100
# 48/48 [==============================] - 6s 114ms/step - loss: 5.6638e-04
# Epoch 68/100
# 48/48 [==============================] - 6s 122ms/step - loss: 5.3143e-04
# Epoch 69/100
# 48/48 [==============================] - 6s 118ms/step - loss: 5.5869e-04
# Epoch 70/100
# 48/48 [==============================] - 6s 119ms/step - loss: 5.3876e-04
# Epoch 71/100
# 48/48 [==============================] - 6s 123ms/step - loss: 5.7760e-04
# Epoch 72/100
# 48/48 [==============================] - 7s 141ms/step - loss: 5.8864e-04
# Epoch 73/100
# 48/48 [==============================] - 6s 123ms/step - loss: 5.3226e-04
# Epoch 74/100
# 48/48 [==============================] - 8s 158ms/step - loss: 5.8694e-04
# Epoch 75/100
# 48/48 [==============================] - 6s 120ms/step - loss: 5.1544e-04
# Epoch 76/100
# 48/48 [==============================] - 6s 124ms/step - loss: 4.5937e-04
# Epoch 77/100
# 48/48 [==============================] - 6s 122ms/step - loss: 5.9196e-04
# Epoch 78/100
# 48/48 [==============================] - 7s 154ms/step - loss: 5.5559e-04
# Epoch 79/100
# 48/48 [==============================] - 6s 123ms/step - loss: 5.1200e-04
# Epoch 80/100
# 48/48 [==============================] - 6s 126ms/step - loss: 4.8681e-04
# Epoch 81/100
# 48/48 [==============================] - 5s 113ms/step - loss: 4.7390e-04
# Epoch 82/100
# 48/48 [==============================] - 6s 124ms/step - loss: 5.0819e-04
# Epoch 83/100
# 48/48 [==============================] - 5s 114ms/step - loss: 4.7434e-04
# Epoch 84/100
# 48/48 [==============================] - 6s 124ms/step - loss: 4.8650e-04
# Epoch 85/100
# 48/48 [==============================] - 5s 112ms/step - loss: 4.7919e-04
# Epoch 86/100
# 48/48 [==============================] - 6s 122ms/step - loss: 4.6357e-04
# Epoch 87/100
# 48/48 [==============================] - 6s 131ms/step - loss: 5.0660e-04
# Epoch 88/100
# 48/48 [==============================] - 7s 139ms/step - loss: 4.4635e-04
# Epoch 89/100
# 48/48 [==============================] - 6s 121ms/step - loss: 4.5105e-04
# Epoch 90/100
# 48/48 [==============================] - 6s 127ms/step - loss: 4.7122e-04
# Epoch 91/100
# 48/48 [==============================] - 5s 113ms/step - loss: 4.4487e-04
# Epoch 92/100
# 48/48 [==============================] - 6s 131ms/step - loss: 5.2694e-04
# Epoch 93/100
# 48/48 [==============================] - 6s 114ms/step - loss: 5.1820e-04
# Epoch 94/100
# 48/48 [==============================] - 6s 126ms/step - loss: 5.0007e-04
# Epoch 95/100
# 48/48 [==============================] - 6s 117ms/step - loss: 4.2437e-04
# Epoch 96/100
# 48/48 [==============================] - 6s 128ms/step - loss: 4.4586e-04
# Epoch 97/100
# 48/48 [==============================] - 6s 120ms/step - loss: 4.3079e-04
# Epoch 98/100
# 48/48 [==============================] - 6s 128ms/step - loss: 4.5981e-04
# Epoch 99/100
# 48/48 [==============================] - 6s 116ms/step - loss: 4.4606e-04
# Epoch 100/100
# 48/48 [==============================] - 6s 129ms/step - loss: 4.1760e-04

# %% [markdown]
# #### Make predictions

# %%
# Get n (number of timesteps) previous stock prices for predicting
inputs = dataset[len(dataset)-len(dataset_test) - timesteps:]
# Reshape input values
inputs = inputs.reshape(-1, 1)
# Scale input values, directly apply transformations (already fitted)
inputs = sc.transform(inputs)

# Define test set structure
X_test = []
# For the entire test set
for i in range(timesteps, timesteps + len(dataset_test)):
  # Range of values from i-60 to i, first column
  X_test.append(inputs[i-timesteps:i, 0])
# Convert to NumPy array
X_test = np.array(X_test)

# Obtain 3D structure of the test set
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Predict the test set results
predicted_stock_price = reg.predict(X_test)
# Apply inverse transformations
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
real_stock_price = sc.inverse_transform(dataset_test)

# Print predicted and real stock prices side-by-side (if required)
# print(np.concatenate((predicted_stock_price.reshape(len(predicted_stock_price), 1), 
#                       real_stock_price.reshape(len(real_stock_price), 1)), 1 ))

# Print Scores
print('')
print('--- Prediction Scores ---')
print('')
# Mean Absolute Error (MAE)
print('MAE: %.3f' % (mean_absolute_error(real_stock_price, predicted_stock_price)))
# Mean Squared Error (MSE)
print('MSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price)))
# Root Mean Squared Error (RMSE)
print('RMSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price, squared=False)))
# R^2 Score (Goodness-of-Fit)
print('R^2 Score: %.3f%%' % (r2_score(real_stock_price, predicted_stock_price) * 100))
# Out:
# 13/13 [==============================] - 2s 35ms/step
#
# --- Prediction Scores ---
#
# MAE: 1.194
# MSE: 2.285
# RMSE: 1.512
# R^2 Score: 94.015%

# %% [markdown]
# #### Visualize Prediction Results

# %%
# Define results figure
rbc_results = plt.figure(figsize=(12,6))

# Plot results
rbc_results = plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
rbc_results = plt.plot(real_stock_price, color = 'red', label = 'Real Stock Price')
# Adjust Y-Axis range
plt.yticks(np.arange(110, 165, 5))
# Plot title and labels
plt.xlabel('Days')
plt.ylabel('Stock Price ($)')
plt.title('RBC Stock Price Prediction')
# Plot legend and grid
plt.legend()
plt.grid()

# Show plot
plt.show()

# %%
# Combined box plot distributions
box_plots_comb = plt.figure(figsize=(8, 6))

# Box plot for lr_pred
ax1 = box_plots_comb.add_subplot(1, 2, 1)
ax1 = sns.boxplot(y=predicted_stock_price, color='blue', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(110, 160, 5))
# Plot title and labels
plt.xlabel('Predicted Stock Price', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Predicted Stock Price', fontsize=14)

# Box plot for linear_svr_pred
ax2 = box_plots_comb.add_subplot(1, 2, 2)
ax2 = sns.boxplot(y=real_stock_price, color='red', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(110, 160, 5))
# Plot title and label
plt.xlabel('Real Stock Price', fontsize=12)
plt.title('Real Stock Price', fontsize=14)

# Show subplot
plt.show()
