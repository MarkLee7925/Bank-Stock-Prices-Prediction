# %% [markdown]
# # Scotiabank - Stock Prices Prediction

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas_datareader as webreader
import pandas as pd
import tensorflow as tf
import seaborn as sns
import datetime as dt
import pandas_datareader as webreader
from datetime import date, timedelta, datetime

# %% [markdown]
# ## 2. Load Data

# %%
# Import dataset
df = pd.read_csv('Scotiabank_StockPrices_2016-2021.csv')

# today = date.today()
# date_today = today.strftime("%Y-%m-%d")
# date_start = '2016-01-01'

# # # Read stock quotes from Yahoo Finance
# df = webreader.DataReader('BNS.TO', data_source='yahoo', start=date_start, end=date_today)

# Input data of np array - Closing price
dataset = df.iloc[:, 4:5].values

print(dataset.shape)
# Out:
# (1254, 1)

# %%
df
# Out:
#             Date       Open       High  ...      Close  Adj Close   Volume
# 0     2016-09-15  69.029999  70.139999  ...  70.059998  55.257874  1490700
# 1     2016-09-16  70.059998  70.129997  ...  69.900002  55.131676  4076200
# 2     2016-09-19  70.089996  70.699997  ...  70.000000  55.210552  1571900
# 3     2016-09-20  70.440002  70.699997  ...  70.430000  55.549698  1459500
# 4     2016-09-21  70.750000  70.900002  ...  70.730003  55.786324  1196100
# ...          ...        ...        ...  ...        ...        ...      ...
# 1249  2021-09-08  78.190002  78.459999  ...  78.059998  78.059998  1594600
# 1250  2021-09-09  78.050003  78.489998  ...  78.150002  78.150002  1897200
# 1251  2021-09-10  78.410004  78.470001  ...  78.050003  78.050003  2579500
# 1252  2021-09-13  78.489998  78.870003  ...  78.360001  78.360001  3686700
# 1253  2021-09-14  78.440002  78.459999  ...  77.690002  77.690002  3348900
#
# [1254 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1254 entries, 0 to 1253
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1254 non-null   object
#  1   Open       1254 non-null   float64
#  2   High       1254 non-null   float64
#  3   Low        1254 non-null   float64
#  4   Close      1254 non-null   float64
#  5   Adj Close  1254 non-null   float64
#  6   Volume     1254 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.7+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# from sklearn.impute import SimpleImputer

# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# imputer.fit_transform(dataset)
# dataset = imputer.transform(dataset)
# df.dropna(inplace=True)

# %% [markdown]
# ## 3. Visualize Data

# %%
# Plot each data column
fig1 = df.plot(subplots=True, figsize=(12,20), sharex=False, cmap='rainbow')
plt.xlabel('Days')
# fig1.xaxis.set_major_locator(mdates.AutoDateLocator())
plt.show()

# %%
# Pariwise relationship between features
sns.pairplot(df)

# %%
# Correlation Map
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(method='pearson'), annot=True, cmap='hot', fmt='.2f')
plt.title('Correlation Map')
plt.xticks(rotation=60)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5]),
#  <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# ## 4. Data Preprocessing and Feature Engineering

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Normalize data
sc = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = sc.fit_transform(dataset)

# %%
dataset_scaled
# Out:
# array([[0.61179543],
#        [0.60760157],
#        [0.61022275],
#        ...,
#        [0.82123199],
#        [0.82935775],
#        [0.81179553]])

# %%
# Split dataset into training set and test set (80/20 split)
training_size = int(len(df)*0.8)
dataset_train = dataset_scaled[:training_size]
dataset_test = dataset_scaled[training_size:]

print('Training set shape: ' + str(dataset_train.shape))
print('Test set shape: ' + str(dataset_test.shape))
# Out:
# Training set shape: (1003, 1)
# Test set shape: (251, 1)

# %%
# Predict stock price results using 60 timesteps (60 business days)
timesteps = 60

def define_training_data(timesteps, dataset):
  # X - number of timesteps, y - indicators (features) used for training
  X, y = [], []
  for i in range(timesteps, dataset.shape[0]):
    X.append(dataset[i-timesteps:i, 0])
    y.append(dataset[i, 0])
  X, y = np.array(X), np.array(y)
  return X, y

X_train, y_train = define_training_data(timesteps, dataset_train)
print(X_train.shape, y_train.shape)
# Out:
# (943, 60) (943,)

# %%
# Reshape(number of rows, number of timesteps (columns), number of predictors)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train
# Out:
# array([[[0.61179543],
#         [0.60760157],
#         [0.61022275],
#         ...,
#         [0.7328964 ],
#         [0.75701168],
#         [0.7719527 ]],
#
#        [[0.60760157],
#         [0.61022275],
#         [0.62149404],
#         ...,
#         [0.75701168],
#         [0.7719527 ],
#         [0.79030145]],
#
#        [[0.61022275],
#         [0.62149404],
#         [0.62935782],
#         ...,
#         [0.7719527 ],
#         [0.79030145],
#         [0.78138916]],
#
#        ...,
#
#        [[0.30065524],
#         [0.31533416],
#         [0.30642198],
#         ...,
#         [0.22595016],
#         [0.21310607],
#         [0.22857136]],
#
#        [[0.31533416],
#         [0.30642198],
#         [0.29305375],
#         ...,
#         [0.21310607],
#         [0.22857136],
#         [0.22201828]],
#
#        [[0.30642198],
#         [0.29305375],
#         [0.27024895],
#         ...,
#         [0.22857136],
#         [0.22201828],
#         [0.22699868]]])

# %%
X_train.shape
# Out:
# (943, 60, 1)

# %% [markdown]
# ## 5. Define LSTM model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define model
reg = Sequential()

# LSTM layers
reg.add(LSTM(units=60, return_sequences=True, 
             input_shape=(X_train.shape[1], X_train.shape[2])))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=False))
reg.add(Dropout(0.1))

# Output layer
reg.add(Dense(units=X_train.shape[2]))

# Compile model
reg.compile(optimizer='adam', loss='mean_squared_error')

# Train (fit) model
history = reg.fit(X_train, y_train, batch_size=32, epochs=100)

# Plot loss during training
plt.plot(history.history['loss'], 'g', label='loss')
plt.title('Training Curve')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1/100
# 30/30 [==============================] - 11s 139ms/step - loss: 0.0805
# Epoch 2/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0119
# Epoch 3/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.0078
# Epoch 4/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0077
# Epoch 5/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0076
# Epoch 6/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0076
# Epoch 7/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0072
# Epoch 8/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0071
# Epoch 9/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0072
# Epoch 10/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0060
# Epoch 11/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0068
# Epoch 12/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.0059
# Epoch 13/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0057
# Epoch 14/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0055
# Epoch 15/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0062
# Epoch 16/100
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0052
# Epoch 17/100
# 30/30 [==============================] - 5s 164ms/step - loss: 0.0052
# Epoch 18/100
# 30/30 [==============================] - 5s 142ms/step - loss: 0.0052
# Epoch 19/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0071
# Epoch 20/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0064
# Epoch 21/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0055
# Epoch 22/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0047
# Epoch 23/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0042
# Epoch 24/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0041
# Epoch 25/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0040
# Epoch 26/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.0038
# Epoch 27/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0039
# Epoch 28/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0045
# Epoch 29/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0039
# Epoch 30/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0035
# Epoch 31/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0039
# Epoch 32/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0037
# Epoch 33/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0034
# Epoch 34/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0035
# Epoch 35/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0033
# Epoch 36/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0034
# Epoch 37/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0032
# Epoch 38/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0033
# Epoch 39/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0035
# Epoch 40/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0030
# Epoch 41/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0030
# Epoch 42/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0033
# Epoch 43/100
# 30/30 [==============================] - 5s 165ms/step - loss: 0.0028
# Epoch 44/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0028
# Epoch 45/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0033
# Epoch 46/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.0030
# Epoch 47/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0031
# Epoch 48/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0027
# Epoch 49/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0029
# Epoch 50/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.0028
# Epoch 51/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0027
# Epoch 52/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0028
# Epoch 53/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0025
# Epoch 54/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0026
# Epoch 55/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0026
# Epoch 56/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0024
# Epoch 57/100
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0025
# Epoch 58/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0029
# Epoch 59/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0027
# Epoch 60/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0026
# Epoch 61/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.0024
# Epoch 62/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0024
# Epoch 63/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0022
# Epoch 64/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0025
# Epoch 65/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0022
# Epoch 66/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0022
# Epoch 67/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0023
# Epoch 68/100
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0020
# Epoch 69/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0021
# Epoch 70/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0022
# Epoch 71/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0022
# Epoch 72/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0025
# Epoch 73/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0022
# Epoch 74/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0022
# Epoch 75/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0025
# Epoch 76/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0022
# Epoch 77/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0022
# Epoch 78/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.0022
# Epoch 79/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0020
# Epoch 80/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0021
# Epoch 81/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0020
# Epoch 82/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0020
# Epoch 83/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0020
# Epoch 84/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0019
# Epoch 85/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0020
# Epoch 86/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0019
# Epoch 87/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0018
# Epoch 88/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0019
# Epoch 89/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0019
# Epoch 90/100
# 30/30 [==============================] - 4s 140ms/step - loss: 0.0024
# Epoch 91/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0022
# Epoch 92/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0019
# Epoch 93/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.0019
# Epoch 94/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0018
# Epoch 95/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.0019
# Epoch 96/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0018
# Epoch 97/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.0017
# Epoch 98/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.0018
# Epoch 99/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0017
# Epoch 100/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.0017

# %% [markdown]
# ## 6. Evalutate model

# %% [markdown]
# #### Make predictions

# %%
# Get 60 previous stock prices for predicting
inputs = dataset[len(dataset)-len(dataset_test) - timesteps:]
# Reshape input values
inputs = inputs.reshape(-1, 1)
# Scale input values, directly apply transformations (already fitted)
inputs = sc.transform(inputs)

# Define test set structure
X_test = []
# For the entire test set
for i in range(timesteps, timesteps + len(dataset_test)):
  # Range of values from i-60 to i, first column
  X_test.append(inputs[i-timesteps:i, 0])
X_test = np.array(X_test)

# Obtain 3D structure of the test set
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Predict the test set results
predicted_stock_price = reg.predict(X_test)
# Apply inverse transformations
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
real_stock_price = sc.inverse_transform(dataset_test)

# Print predicted and real stock prices side-by-side
print(np.concatenate((predicted_stock_price.reshape(len(predicted_stock_price), 1), 
                      real_stock_price.reshape(len(real_stock_price), 1)), 1 ))

# Print Scores
print('')
print('--- Prediction Scores ---')
print('')
mae = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: ' + str(mae))
mse = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: ' + str(mse))
rmse = np.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+ str(rmse))
#  [81.22970581 80.879997  ]
#  [81.19868469 81.879997  ]
#  [81.31539154 81.639999  ]
#  [81.47818756 81.209999  ]
#  [81.44962311 81.150002  ]
#  [81.28832245 81.169998  ]
#  [81.14007568 80.970001  ]
#  [81.00484467 80.830002  ]
#  [80.86912537 80.959999  ]
#  [80.81172943 80.839996  ]
#  [80.78097534 81.230003  ]
#  [80.8817749  81.949997  ]
#  [81.25022888 80.809998  ]
#  [81.28044891 79.370003  ]
#  [80.60192871 79.849998  ]
#  [79.91786957 79.629997  ]
#  [79.50871277 79.93      ]
#  [79.48618317 80.239998  ]
#  [79.75514221 80.889999  ]
#  [80.2508316  80.239998  ]
#  [80.48223877 80.580002  ]
#  [80.54834747 80.620003  ]
#  [80.56481171 81.        ]
#  [80.69374847 80.160004  ]
#  [80.60146332 79.339996  ]
#  [80.12742615 79.019997  ]
#  [79.50654602 77.93      ]
#  [78.71620178 78.900002  ]
#  [78.37547302 79.290001  ]
#  [78.58763123 79.099998  ]
#  [78.9360733  79.07      ]
#  [79.14876556 79.220001  ]
#  [79.24214935 78.519997  ]
#  [79.05596161 76.769997  ]
#  [78.24286652 77.650002  ]
#  [77.57035828 77.989998  ]
#  [77.42681122 77.379997  ]
#  [77.4582901  77.919998  ]
#  [77.64122772 77.970001  ]
#  [77.86367035 77.889999  ]
#  [77.99861145 78.199997  ]
#  [78.12397003 78.650002  ]
#  [78.36022949 77.870003  ]
#  [78.37458801 78.18      ]
#  [78.30258179 78.110001  ]
#  [78.22522736 78.699997  ]
#  [78.35355377 79.589996  ]
#  [78.83859253 79.790001  ]
#  [79.42224884 80.709999  ]
#  [80.08757782 81.07      ]
#  [80.69288635 81.110001  ]
#  [81.07209015 80.970001  ]
#  [81.16738892 81.029999  ]
#  [81.12019348 80.550003  ]
#  [80.90434265 80.370003  ]
#  [80.61562347 79.610001  ]
#  [80.1626358  79.93      ]
#  [79.85034943 80.230003  ]
#  [79.8425827  79.599998  ]
#  [79.7983551  80.629997  ]
#  [79.99890137 79.800003  ]
#  [80.04641724 79.389999  ]
#  [79.80802917 78.589996  ]
#  [79.25213623 78.150002  ]
#  [78.58120728 78.050003  ]
#  [78.06687164 78.309998  ]
#  [77.91055298 78.120003  ]
#  [77.94782257 78.150002  ]
#  [78.03994751 78.059998  ]
#  [78.08553314 78.150002  ]
#  [78.11264038 78.050003  ]
#  [78.1071701  78.360001  ]
#  [78.18082428 77.690002  ]]
#
# --- Prediction Scores ---
#
# MAE: 0.6864354419538642
# MSE: 0.8815380502360365
# RMSE: 0.9389025776064504
# R^2 Score: 0.9885232857955808

# %% [markdown]
# #### Visualize Results

# %%
# Plot predicted and real closing stock prices
plt.figure(figsize=(8,6))
plt.plot(real_stock_price, color = 'blue', label = 'Real Stock Price')
plt.plot(predicted_stock_price, color = 'red', label = 'Predicted Stock Price')
plt.xlabel('Days')
plt.ylabel('Stock Price ($)')
plt.title('Scotiabank Stock Price Prediction')
plt.legend()
plt.grid()
plt.show()
