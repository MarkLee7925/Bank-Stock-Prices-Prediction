# %% [markdown]
# # CIBC - Stock Prices Prediction

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas_datareader as webreader
import pandas as pd
import tensorflow as tf
import seaborn as sns
import datetime as dt
import pandas_datareader as webreader
from datetime import date, timedelta, datetime

# %% [markdown]
# ## 2. Load Data

# %%
# Import dataset
df = pd.read_csv('CIBC_StockPrices_2016-2021.csv')

# today = date.today()
# date_today = today.strftime("%Y-%m-%d")
# date_start = '2016-01-01'

# # Read stock quotes from Yahoo Finance
# df = webreader.DataReader('CM-PQ.TO', data_source='yahoo', start=date_start, end=date_today)

# Input data of np array - Closing price
dataset = df.iloc[:, 4:5].values

print(dataset.shape)
# Out:
# (1254, 1)

# %%
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  Volume
# 0     2016-09-15  19.900000  20.020000  19.900000  20.000000  16.067154    7600
# 1     2016-09-16  20.000000  20.090000  20.000000  20.090000  16.139454    6500
# 2     2016-09-19  20.100000  20.440001  20.100000  20.400000  16.388498   18100
# 3     2016-09-20  20.340000  20.410000  20.180000  20.250000  16.267994   14531
# 4     2016-09-21  20.320000  20.540001  20.250000  20.320000  16.324226    3700
# ...          ...        ...        ...        ...        ...        ...     ...
# 1249  2021-09-08  24.950001  24.950001  24.900000  24.900000  24.900000    2200
# 1250  2021-09-09  24.900000  24.900000  24.900000  24.900000  24.900000     900
# 1251  2021-09-10  24.950001  24.950001  24.950001  24.950001  24.950001    1900
# 1252  2021-09-13  24.990000  25.000000  24.950001  24.950001  24.950001    2500
# 1253  2021-09-14  24.950001  24.950001  24.900000  24.950001  24.950001    2000
#
# [1254 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1254 entries, 0 to 1253
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1254 non-null   object
#  1   Open       1254 non-null   float64
#  2   High       1254 non-null   float64
#  3   Low        1254 non-null   float64
#  4   Close      1254 non-null   float64
#  5   Adj Close  1254 non-null   float64
#  6   Volume     1254 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.7+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# from sklearn.impute import SimpleImputer

# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# imputer.fit_transform(dataset)
# dataset = imputer.transform(dataset)
# df.dropna(inplace=True)

# %% [markdown]
# ## 3. Visualize Data

# %%
# Plot each data column
df.plot(subplots=True, figsize=(12,20), sharex=False, cmap='rainbow')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc3c3030d50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fc3c2fb0410>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fc3c2f69a50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fc3c2f29110>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fc3c2edf790>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fc3c2e93d90>],
#       dtype=object)

# %%
# Pariwise relationship between features
sns.pairplot(df)

# %%
# Correlation Map
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(method='pearson'), annot=True, cmap='hot', fmt='.2f')
plt.title('Correlation Map')
plt.xticks(rotation=60)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5]),
#  <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# ## 4. Data Preprocessing and Feature Engineering

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Normalize data
sc = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = sc.fit_transform(dataset)

# %%
dataset_scaled
# Out:
# array([[0.64872326],
#        [0.65493444],
#        [0.6763285 ],
#        ...,
#        [0.99033823],
#        [0.99033823],
#        [0.99033823]])

# %%
# Split dataset into training set and test set (80/20 split)
training_size = int(len(df)*0.8)
dataset_train = dataset_scaled[:training_size]
dataset_test = dataset_scaled[training_size:]

print('Training set shape: ' + str(dataset_train.shape))
print('Test set shape: ' + str(dataset_test.shape))
# Out:
# Training set shape: (1003, 1)
# Test set shape: (251, 1)

# %% [markdown]
# #### Create a data structure with 60 timesteps and 1 output

# %%
# Predict stock price results using 60 timesteps (60 business days)
timesteps = 60

def define_training_data(timesteps, dataset):
  ''' 
  Define number of timesteps and features needed for training and 
  validating RNN model 
  '''

  # X - number of timesteps, y - indicators (features) used for training
  X, y = [], []
  for i in range(timesteps, dataset.shape[0]):
    X.append(dataset[i-timesteps:i, 0])
    y.append(dataset[i, 0])
  X, y = np.array(X), np.array(y)
  return X, y

X_train, y_train = define_training_data(timesteps, dataset_train)
print(X_train.shape, y_train.shape)
# Out:
# (943, 60) (943,)

# %% [markdown]
# #### Reshaping

# %%
# Reshape(number of rows, number of timesteps (columns), number of predictors)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train
# Out:
# array([[[0.64872326],
#         [0.65493444],
#         [0.6763285 ],
#         ...,
#         [0.72463768],
#         [0.71773637],
#         [0.71083506]],
#
#        [[0.65493444],
#         [0.6763285 ],
#         [0.66597654],
#         ...,
#         [0.71773637],
#         [0.71083506],
#         [0.71497578]],
#
#        [[0.6763285 ],
#         [0.66597654],
#         [0.67080745],
#         ...,
#         [0.71083506],
#         [0.71497578],
#         [0.71980683]],
#
#        ...,
#
#        [[0.28295376],
#         [0.3015873 ],
#         [0.31055901],
#         ...,
#         [0.59834369],
#         [0.59834369],
#         [0.60386473]],
#
#        [[0.3015873 ],
#         [0.31055901],
#         [0.30710835],
#         ...,
#         [0.59834369],
#         [0.60386473],
#         [0.58868178]],
#
#        [[0.31055901],
#         [0.30710835],
#         [0.30710835],
#         ...,
#         [0.60386473],
#         [0.58868178],
#         [0.59627329]]])

# %%
X_train.shape
# Out:
# (943, 60, 1)

# %% [markdown]
# ## 5. Define LSTM model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define model
reg = Sequential()

# LSTM layers
reg.add(LSTM(units=60, return_sequences=True, 
             input_shape=(X_train.shape[1], X_train.shape[2])))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=50, return_sequences=False))
reg.add(Dropout(0.1))

# Output layer
reg.add(Dense(units=X_train.shape[2]))

# Compile model
reg.compile(optimizer='adam', loss='mean_squared_error')

# Train (fit) model
history = reg.fit(X_train, y_train, batch_size=32, epochs=100)

# Plot loss during training
plt.plot(history.history['loss'], 'g', label='loss')
plt.title('Training Curve')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1/100
# 30/30 [==============================] - 10s 128ms/step - loss: 0.0935
# Epoch 2/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0122
# Epoch 3/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0073
# Epoch 4/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0071
# Epoch 5/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0069
# Epoch 6/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0062
# Epoch 7/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0067
# Epoch 8/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0061
# Epoch 9/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0057
# Epoch 10/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0057
# Epoch 11/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0063
# Epoch 12/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0048
# Epoch 13/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0048
# Epoch 14/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0049
# Epoch 15/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0049
# Epoch 16/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0050
# Epoch 17/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0048
# Epoch 18/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0043
# Epoch 19/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0044
# Epoch 20/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0043
# Epoch 21/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0039
# Epoch 22/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0039
# Epoch 23/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0045
# Epoch 24/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0036
# Epoch 25/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0040
# Epoch 26/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0045
# Epoch 27/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0036
# Epoch 28/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0035
# Epoch 29/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0035
# Epoch 30/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0038
# Epoch 31/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0031
# Epoch 32/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0032
# Epoch 33/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0032
# Epoch 34/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0032
# Epoch 35/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0030
# Epoch 36/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0032
# Epoch 37/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0032
# Epoch 38/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0030
# Epoch 39/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0027
# Epoch 40/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0027
# Epoch 41/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0031
# Epoch 42/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0037
# Epoch 43/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0029
# Epoch 44/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0029
# Epoch 45/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0029
# Epoch 46/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0043
# Epoch 47/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0028
# Epoch 48/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.0026
# Epoch 49/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0025
# Epoch 50/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0025
# Epoch 51/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0024
# Epoch 52/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0025
# Epoch 53/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0025
# Epoch 54/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0023
# Epoch 55/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0022
# Epoch 56/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0026
# Epoch 57/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0026
# Epoch 58/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0029
# Epoch 59/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0024
# Epoch 60/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0024
# Epoch 61/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0027
# Epoch 62/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0028
# Epoch 63/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0022
# Epoch 64/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0023
# Epoch 65/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0022
# Epoch 66/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0027
# Epoch 67/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0021
# Epoch 68/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0023
# Epoch 69/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0019
# Epoch 70/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0023
# Epoch 71/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0023
# Epoch 72/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0028
# Epoch 73/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0021
# Epoch 74/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0020
# Epoch 75/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0019
# Epoch 76/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0022
# Epoch 77/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0019
# Epoch 78/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0021
# Epoch 79/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0024
# Epoch 80/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0019
# Epoch 81/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.0020
# Epoch 82/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0018
# Epoch 83/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0020
# Epoch 84/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0019
# Epoch 85/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0018
# Epoch 86/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0020
# Epoch 87/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0019
# Epoch 88/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0018
# Epoch 89/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0019
# Epoch 90/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0019
# Epoch 91/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0018
# Epoch 92/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0018
# Epoch 93/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0017
# Epoch 94/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0016
# Epoch 95/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0016
# Epoch 96/100
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0016
# Epoch 97/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0018
# Epoch 98/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0015
# Epoch 99/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0017
# Epoch 100/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0020

# %% [markdown]
# ## 6. Evalutate model

# %% [markdown]
# #### Make predictions

# %%
# Get 60 previous stock prices for predicting
inputs = dataset[len(dataset)-len(dataset_test) - timesteps:]
# Reshape input values
inputs = inputs.reshape(-1, 1)
# Scale input values, directly apply transformations (already fitted)
inputs = sc.transform(inputs)

# Define test set structure
X_test = []
# For the entire test set
for i in range(timesteps, timesteps + len(dataset_test)):
  # Range of values from i-60 to i, first column
  X_test.append(inputs[i-timesteps:i, 0])
X_test = np.array(X_test)

# Obtain 3D structure of the test set
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Predict the test set results
predicted_stock_price = reg.predict(X_test)
# Apply inverse transformations
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
real_stock_price = sc.inverse_transform(dataset_test)

# Print predicted and real stock prices side-by-side
print(np.concatenate((predicted_stock_price.reshape(len(predicted_stock_price), 1), 
                      real_stock_price.reshape(len(real_stock_price), 1)), 1 ))

# Print Scores
print('')
print('--- Prediction Scores ---')
print('')
mae = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: ' + str(mae))
mse = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: ' + str(mse))
rmse = np.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+ str(rmse))
r2 = r2_score(real_stock_price, predicted_stock_price)
print('R^2 Score: '+ str(r2))
# Out:
# [[19.35245132 19.18      ]
#  [19.36278152 19.25      ]
#  [19.36571121 19.16      ]
#  [19.34852219 19.        ]
#  [19.29246521 18.82      ]
#  [19.1853447  18.82      ]
#  [19.05870056 18.76      ]
#  [18.9413147  18.620001  ]
#  [18.83325195 18.5       ]
#  [18.72646713 18.41      ]
#  [18.61985779 18.25      ]
#  [18.50407791 18.99      ]
#  [18.52217102 18.99      ]
#  [18.66989136 18.870001  ]
#  [18.84490204 19.        ]
#  [18.99745178 18.879999  ]
#  [19.08445549 19.08      ]
#  [19.13510323 19.09      ]
#  [19.16790771 19.09      ]
#  [19.18787193 19.09      ]
#  [19.19599152 19.129999  ]
#  [19.20068359 19.450001  ]
#  [19.25465012 19.469999  ]
#  [19.35215378 19.27      ]
#  [19.42725563 19.4       ]
#  [19.47542953 19.299999  ]
#  [19.48649597 19.299999  ]
#  [19.46940994 19.35      ]
#  [19.44856262 19.200001  ]
#  [19.41275597 19.18      ]
#  [19.36450768 19.08      ]
#  [19.30135536 19.049999  ]
#  [19.23296928 18.950001  ]
#  [19.15945053 19.049999  ]
#  [19.11046982 18.950001  ]
#  [19.07900429 19.1       ]
#  [19.08423042 19.15      ]
#  [19.12691879 19.34      ]
#  [19.21593094 19.5       ]
#  [19.34770012 19.5       ]
#  [19.48398781 19.549999  ]
#  [19.59772873 19.49      ]
#  [19.66402245 19.639999  ]
#  [19.70566177 19.68      ]
#  [19.73971748 19.77      ]
#  [19.78145027 19.99      ]
#  [19.85894203 19.809999  ]
#  [19.92800331 19.870001  ]
#  [19.97481155 19.950001  ]
#  [20.01076889 19.860001  ]
#  [20.0255909  19.889999  ]
#  [20.02586365 20.1       ]
#  [20.05271149 20.35      ]
#  [20.14419746 20.299999  ]
#  [20.2638855  20.6       ]
#  [20.41508484 20.719999  ]
#  [20.58320618 20.99      ]
#  [20.77157593 20.860001  ]
#  [20.9270153  20.82      ]
#  [21.01763153 20.77      ]
#  [21.03941727 20.799999  ]
#  [21.01931572 21.709999  ]
#  [21.12203979 21.07      ]
#  [21.23627472 20.9       ]
#  [21.27647209 20.82      ]
#  [21.230896   20.83      ]
#  [21.14085007 20.85      ]
#  [21.05473328 21.        ]
#  [21.02256203 21.379999  ]
#  [21.10170364 21.370001  ]
#  [21.24695206 21.18      ]
#  [21.36512184 21.18      ]
#  [21.42458534 21.07      ]
#  [21.41703415 21.07      ]
#  [21.36816788 21.059999  ]
#  [21.30757713 21.049999  ]
#  [21.25527191 21.41      ]
#  [21.27735901 21.65      ]
#  [21.39533615 21.690001  ]
#  [21.55984879 21.6       ]
#  [21.69859314 21.5       ]
#  [21.76825905 21.5       ]
#  [21.77581024 21.59      ]
#  [21.76134682 21.57      ]
#  [21.74424553 21.299999  ]
#  [21.69118309 21.540001  ]
#  [21.6510582  21.51      ]
#  [21.63640022 21.540001  ]
#  [21.64660645 21.459999  ]
#  [21.65744781 21.620001  ]
#  [21.68532944 21.610001  ]
#  [21.72325325 21.549999  ]
#  [21.74980545 21.91      ]
#  [21.81434441 21.85      ]
#  [21.89619255 21.76      ]
#  [21.95481491 21.799999  ]
#  [21.98564339 22.26      ]
#  [22.06334114 22.26      ]
#  [22.17659378 22.309999  ]
#  [22.29489708 22.4       ]
#  [22.40286446 22.290001  ]
#  [22.46974373 22.32      ]
#  [22.4990139  22.5       ]
#  [22.52968216 22.74      ]
#  [22.60217667 22.75      ]
#  [22.6991806  22.76      ]
#  [22.79180908 22.870001  ]
#  [22.87677956 22.98      ]
#  [22.96034431 22.700001  ]
#  [22.99347878 22.9       ]
#  [23.00831032 22.9       ]
#  [23.02028275 22.98      ]
#  [23.04453087 23.18      ]
#  [23.10477257 23.34      ]
#  [23.20461845 23.5       ]
#  [23.33388901 23.6       ]
#  [23.47070122 23.75      ]
#  [23.60595322 23.709999  ]
#  [23.71283531 23.690001  ]
#  [23.77915001 23.6       ]
#  [23.79818726 23.629999  ]
#  [23.79053497 23.65      ]
#  [23.77761841 23.85      ]
#  [23.79758835 23.9       ]
#  [23.84939957 23.959999  ]
#  [23.91891861 23.940001  ]
#  [23.98200989 23.809999  ]
#  [24.0094223  23.9       ]
#  [24.01897621 24.        ]
#  [24.03583145 23.809999  ]
#  [24.03410912 23.9       ]
#  [24.02869415 23.9       ]
#  [24.02609825 23.700001  ]
#  [23.9993782  23.450001  ]
#  [23.92159462 23.25      ]
#  [23.79162788 23.5       ]
#  [23.69014931 23.450001  ]
#  [23.63434029 23.049999  ]
#  [23.55633545 23.25      ]
#  [23.49134445 23.309999  ]
#  [23.4628315  23.370001  ]
#  [23.47289276 23.379999  ]
#  [23.50309372 23.379999  ]
#  [23.53409386 23.5       ]
#  [23.57240677 23.219999  ]
#  [23.56978798 23.35      ]
#  [23.55047417 23.5       ]
#  [23.5520668  23.48      ]
#  [23.57061768 23.5       ]
#  [23.59657669 23.6       ]
#  [23.6341629  23.370001  ]
#  [23.64128876 23.299999  ]
#  [23.61011124 23.41      ]
#  [23.57659149 23.42      ]
#  [23.55803108 23.690001  ]
#  [23.59357643 23.610001  ]
#  [23.65102386 23.98      ]
#  [23.75485039 23.860001  ]
#  [23.85687256 24.        ]
#  [23.9498291  24.200001  ]
#  [24.0486145  24.24      ]
#  [24.14407921 23.959999  ]
#  [24.18452644 24.190001  ]
#  [24.20695686 24.1       ]
#  [24.2135582  24.1       ]
#  [24.21153069 24.200001  ]
#  [24.22102737 24.190001  ]
#  [24.23961258 24.190001  ]
#  [24.26047134 24.200001  ]
#  [24.27992058 24.280001  ]
#  [24.30631828 24.209999  ]
#  [24.32531166 24.25      ]
#  [24.33979034 24.25      ]
#  [24.35049629 24.360001  ]
#  [24.37271118 24.389999  ]
#  [24.40513229 24.459999  ]
#  [24.44692993 24.629999  ]
#  [24.50941849 24.57      ]
#  [24.56764412 24.459999  ]
#  [24.59479904 24.73      ]
#  [24.63054085 24.610001  ]
#  [24.65862083 24.59      ]
#  [24.67226601 24.5       ]
#  [24.66290855 24.379999  ]
#  [24.62509918 24.26      ]
#  [24.56061172 24.15      ]
#  [24.47732925 24.1       ]
#  [24.39228821 24.129999  ]
#  [24.32869911 24.25      ]
#  [24.30973434 24.1       ]
#  [24.30165863 24.1       ]
#  [24.29286194 24.290001  ]
#  [24.30874634 24.280001  ]
#  [24.33890152 24.08      ]
#  [24.34129906 24.        ]
#  [24.30698586 23.99      ]
#  [24.25393295 23.76      ]
#  [24.17026901 23.84      ]
#  [24.09088135 23.91      ]
#  [24.04485703 23.709999  ]
#  [24.00219154 23.84      ]
#  [23.97945023 23.35      ]
#  [23.90466881 23.77      ]
#  [23.85658264 23.780001  ]
#  [23.85161018 23.65      ]
#  [23.85484123 23.719999  ]
#  [23.86293793 23.82      ]
#  [23.88553619 23.9       ]
#  [23.92534447 23.83      ]
#  [23.95837402 23.860001  ]
#  [23.98052406 24.        ]
#  [24.01131248 23.85      ]
#  [24.02578354 23.98      ]
#  [24.04077148 24.1       ]
#  [24.07421684 23.950001  ]
#  [24.09631157 24.07      ]
#  [24.11831093 24.23      ]
#  [24.16169357 24.23      ]
#  [24.2150898  24.15      ]
#  [24.2524662  24.15      ]
#  [24.269804   24.15      ]
#  [24.2731514  24.15      ]
#  [24.27023125 24.15      ]
#  [24.2665081  24.15      ]
#  [24.26457787 24.15      ]
#  [24.26491928 24.1       ]
#  [24.26007843 24.15      ]
#  [24.25868607 24.15      ]
#  [24.26166344 24.25      ]
#  [24.28057861 24.18      ]
#  [24.29812431 24.18      ]
#  [24.30817223 24.18      ]
#  [24.31118202 24.200001  ]
#  [24.3127346  24.18      ]
#  [24.3116951  24.209999  ]
#  [24.31315422 24.48      ]
#  [24.3535614  24.84      ]
#  [24.46380043 24.870001  ]
#  [24.60229301 24.82      ]
#  [24.71874809 24.9       ]
#  [24.8053112  24.940001  ]
#  [24.86628723 24.99      ]
#  [24.91180992 24.99      ]
#  [24.94477654 25.09      ]
#  [24.9799366  24.76      ]
#  [24.97325706 25.        ]
#  [24.96743584 24.9       ]
#  [24.96051979 24.9       ]
#  [24.95497704 24.950001  ]
#  [24.95897675 24.950001  ]
#  [24.96996117 24.950001  ]]
#
# --- Prediction Scores ---
#
# MAE: 0.17285107386275225
# MSE: 0.04720371003664696
# RMSE: 0.21726414807014746
# R^2 Score: 0.9881246481830376

# %% [markdown]
# #### Visualizing results

# %%
# Plot predicted and real closing stock prices
plt.figure(figsize=(8,6))
plt.plot(real_stock_price, color = 'blue', label = 'Real Stock Price')
plt.plot(predicted_stock_price, color = 'red', label = 'Predicted Stock Price')
plt.xlabel('Days')
plt.ylabel('Stock Price ($)')
plt.title('CIBC Stock Price Prediction')
plt.legend()
plt.grid()
plt.show()
