# %% [markdown]
# # TD Bank - Stock Prices Prediction

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas_datareader as webreader
import pandas as pd
import tensorflow as tf
import seaborn as sns
import datetime as dt

from datetime import date, timedelta, datetime
from sklearn.preprocessing import MinMaxScaler
from pandas_datareader import data
from tensorflow import keras

# %% [markdown]
# ## 2. Data Preprocessing and Visualization

# %% [markdown]
# ### 2.1. Load Data

# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader

# %%
# Import dataset
df = pd.read_csv('TD-Stocks-2015-2023.csv')

# today = date.today()
# date_today = today.strftime("%Y-%m-%d")
# date_start = '2016-01-01'

# # Read stock quotes from Yahoo Finance
# df = webreader.DataReader('TD.TO', data_source='yahoo', start=date_start, end=date_today)

# Input data of np array - Closing price
dataset = df.iloc[:, 4:5].values

# Dataset shape
print(dataset.shape)
# Out:
# (2008, 1)

# %% [markdown]
# ### 2.2. Analyze Data

# %%
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2015-02-03  52.000000  52.930000  51.680000  52.790001  38.548180
# 1     2015-02-04  52.700001  52.910000  52.419998  52.549999  38.372921
# 2     2015-02-05  52.849998  53.779999  52.610001  53.660000  39.183464
# 3     2015-02-06  54.000000  54.970001  53.939999  54.259998  39.621597
# 4     2015-02-09  54.000000  54.889999  53.939999  54.520000  39.811447
# ...          ...        ...        ...        ...        ...        ...
# 2003  2023-01-27  90.760002  91.580002  90.540001  91.419998  91.419998
# 2004  2023-01-30  90.959999  91.470001  90.410004  90.650002  90.650002
# 2005  2023-01-31  90.660004  92.150002  90.500000  92.059998  92.059998
# 2006  2023-02-01  91.500000  92.110001  91.139999  91.489998  91.489998
# 2007  2023-02-02  91.589996  92.339996  91.300003  91.949997  91.949997
#
#         Volume
# 0      4483100
# 1      2569300
# 2      3781500
# 3      3516100
# 4      2443800
# ...        ...
# 2003   4310600
# 2004  11892000
# 2005  10354400
# 2006   3029400
# 2007   4720400
#
# [2008 rows x 7 columns]

# %%
# Brief info about dataframe - non-null values and datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2008 entries, 0 to 2007
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2008 non-null   object
#  1   Open       2008 non-null   float64
#  2   High       2008 non-null   float64
#  3   Low        2008 non-null   float64
#  4   Close      2008 non-null   float64
#  5   Adj Close  2008 non-null   float64
#  6   Volume     2008 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 109.9+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# from sklearn.impute import SimpleImputer

# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# imputer.fit_transform(dataset)
# dataset = imputer.transform(dataset)
# df.dropna(inplace=True)

# %%
# Dataframe statistics on quantitative (numerical) values
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2008.000000  2008.000000  2008.000000  2008.000000  2008.000000
# mean     71.414542    71.850478    70.956325    71.415194    61.758145
# std      13.062909    13.137310    13.010312    13.068015    16.275276
# min      48.299999    49.209999    47.750000    49.020000    36.482430
# 25%      59.772499    60.375001    59.247501    59.942500    50.619279
# 50%      72.619999    73.024998    72.260002    72.615002    60.438477
# 75%      78.902502    79.182501    78.552502    78.772501    69.384222
# max     107.800003   109.080002   107.279999   107.839996   103.521088
#
#              Volume
# count  2.008000e+03
# mean   4.155874e+06
# std    2.938273e+06
# min    4.116000e+05
# 25%    2.486000e+06
# 50%    3.245000e+06
# 75%    4.671600e+06
# max    2.547830e+07

# %% [markdown]
# ### 2.3. Visualize Data

# %% [markdown]
# #### Pariwise relationship between features

# %%
# Pairwise distributions
sns.pairplot(df)

# Show figure
plt.show()

# %% [markdown]
# #### Correlation Map

# %%
# Define figure
plt.figure(figsize=(10,10))

# Correlation Map
sns.heatmap(df.corr(method='pearson'), annot=True, cmap='YlGn', fmt='.2f')
# Adjust X and Y-Axes
plt.xticks(rotation=0)
plt.yticks(rotation=0)
# Plot title
plt.title('Correlation Map')

# Show figure
plt.show()

# %% [markdown]
# #### Individual stock prices and volume distribution

# %%
# Define stock prices figure
td_stock_prices = plt.figure(figsize=(10,24))

# Open Stock Price
ax1 = td_stock_prices.add_subplot(6, 1, 1)
ax1 = plt.plot(df['Open'], color = 'violet')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid()

# High Stock Price
ax2 = td_stock_prices.add_subplot(6, 1, 2)
ax2 = plt.plot(df['High'], color = 'indigo')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Low Stock Price
ax3 = td_stock_prices.add_subplot(6, 1, 3)
ax3 = plt.plot(df['Low'], color = 'blue')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Closing Stock Price (target variable)
ax4 = td_stock_prices.add_subplot(6, 1, 4)
ax4 = plt.plot(df['Close'], color = 'green')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Adjusting Closing Stock Price
ax5 = td_stock_prices.add_subplot(6, 1, 5)
ax5 = plt.plot(df['Adj Close'], color = 'orange')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Volume (number of stocks)
ax6 = td_stock_prices.add_subplot(6, 1, 6)
ax6 = plt.plot(df['Volume'], color = 'red')
# Adjust axes range(s)
# plt.xticks()
# plt.yticks()
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Stock Volume', fontsize=14)
# Plot grid
plt.grid()

# Show plot
plt.show()

# %% [markdown]
# #### Combined distributions

# %%
# Define figure
td_stock_prices_comb = plt.figure(figsize=(12,6))

# Open Stock Price
td_stock_prices_comb = plt.plot(df['Open'], color = 'violet', label = 'Open')
# High Stock Price
td_stock_prices_comb = plt.plot(df['High'], color = 'indigo', label = 'High')
# Low Stock Price
td_stock_prices_comb = plt.plot(df['High'], color = 'blue', label = 'Low')
# Closing Stock Price
td_stock_prices_comb = plt.plot(df['Close'], color = 'green', label = 'Closing')
# Adjusted Closing Stock Price
td_stock_prices_comb = plt.plot(df['Adj Close'], color = 'orange', 
                                 label = 'Adj. Closing')
# Adjust X and Y-Axes ranges
plt.xticks(np.arange(0, 2200, 200))
plt.yticks(np.arange(30, 125, 5))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Combined Stock Prices Distribution', fontsize=14)
# Plot legend and grid
plt.legend(title="Stock Prices", bbox_to_anchor=(1, 0.7))
plt.grid()

# Show plot
plt.show()

# %%
# Define figure
td_comb_dist = plt.figure(figsize=(12, 36))

# -- Open Stock Prices --

# Histogram
ax1 = td_comb_dist.add_subplot(6, 2, 1)
ax1 = plt.hist(x=df['Open'], color='violet', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Open Stock Price', fontsize=14)

# Box Plot
ax2 = td_comb_dist.add_subplot(6, 2, 2)
ax2 = sns.boxplot(x=df['Open'], color='violet')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)

# -- High Stock Prices --

# Histogram
ax3 = td_comb_dist.add_subplot(6, 2, 3)
ax3 = plt.hist(x=df['High'], color='indigo', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('High Stock Price', fontsize=14)

# Box Plot
ax4 = td_comb_dist.add_subplot(6, 2, 4)
ax4 = sns.boxplot(x=df['High'], color='indigo')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)

# -- Low Stock Prices --

# Histogram
ax5 = td_comb_dist.add_subplot(6, 2, 5)
ax5 = plt.hist(x=df['Low'], color='blue', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Low Stock Price', fontsize=14)

# Box Plot
ax6 = td_comb_dist.add_subplot(6, 2, 6)
ax6 = sns.boxplot(x=df['Low'], color='blue')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)

# -- Closing Stock Prices --

# Histogram
ax7 = td_comb_dist.add_subplot(6, 2, 7)
ax7 = plt.hist(x=df['Close'], color='green', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)

# Box Plot
ax8 = td_comb_dist.add_subplot(6, 2, 8)
ax8 = sns.boxplot(x=df['Close'], color='green')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)

# -- Adjusted Closing Stock Prices --

# Histogram
ax9 = td_comb_dist.add_subplot(6, 2, 9)
ax9 = plt.hist(x=df['Adj Close'], color='orange', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 480, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)

# Box Plot
ax10 = td_comb_dist.add_subplot(6, 2, 10)
ax10 = sns.boxplot(x=df['Adj Close'], color='orange')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)

# -- Volume of Stocks --

# Histogram
ax11 = td_comb_dist.add_subplot(6, 2, 11)
ax11 = plt.hist(x=df['Volume'], color='red', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 28000000, 2000000))
plt.yticks(np.arange(0, 1100, 100))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)

# Box Plot
ax12 = td_comb_dist.add_subplot(6, 2, 12)
ax12 = sns.boxplot(x=df['Volume'], color='red')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 28000000, 2000000))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)

# Show subplot
plt.show()

# %% [markdown]
# ### 2.4. Feature Engineering

# %%
# Normalize data
sc = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = sc.fit_transform(dataset)

# %%
dataset_scaled
# Out:
# array([[0.06409387],
#        [0.06001359],
#        [0.07888474],
#        ...,
#        [0.73172392],
#        [0.72203334],
#        [0.72985379]])

# %%
# Split dataset into training set and test set (80/20 split)
training_size = int(len(df)*0.8)
dataset_train = dataset_scaled[:training_size]
dataset_test = dataset_scaled[training_size:]

print('Training set shape: ' + str(dataset_train.shape))
print('Test set shape: ' + str(dataset_test.shape))
# Out:
# Training set shape: (1606, 1)
# Test set shape: (402, 1)

# %%
# Define number of timesteps (number of business days)
timesteps = 60

# %%
# Predict stock price results using n timesteps
def define_training_data(timesteps, dataset):
  """
  timesteps - number of timesteps (business days)
  dataset   - stock prices (training) dataset
  """

  # X - number of timesteps, y - indicators (features) used for training
  X, y = [], []
  for i in range(timesteps, dataset.shape[0]):
    # Get number of timesteps (business days)
    X.append(dataset[i-timesteps:i, 0])
    # Starting date of reporting (increments during model training)
    y.append(dataset[i, 0])
  # Convert to NumPy array
  X, y = np.array(X), np.array(y)
  return X, y

X_train, y_train = define_training_data(timesteps, dataset_train)
print(X_train.shape, y_train.shape)
# Out:
# (1546, 60) (1546,)

# %%
# Reshape (number of rows, number of timesteps (columns), number of predictors)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# %%
X_train
# Out:
# array([[[0.06409387],
#         [0.06001359],
#         [0.07888474],
#         ...,
#         [0.12155727],
#         [0.12070723],
#         [0.12002724]],
#
#        [[0.06001359],
#         [0.07888474],
#         [0.08908532],
#         ...,
#         [0.12070723],
#         [0.12002724],
#         [0.11356684]],
#
#        [[0.07888474],
#         [0.08908532],
#         [0.09350562],
#         ...,
#         [0.12002724],
#         [0.11356684],
#         [0.11798707]],
#
#        ...,
#
#        [[0.56851413],
#         [0.57140427],
#         [0.56001362],
#         ...,
#         [0.64722881],
#         [0.65521932],
#         [0.64773896]],
#
#        [[0.57140427],
#         [0.56001362],
#         [0.56851413],
#         ...,
#         [0.65521932],
#         [0.64773896],
#         [0.64569879]],
#
#        [[0.56001362],
#         [0.56851413],
#         [0.5856852 ],
#         ...,
#         [0.64773896],
#         [0.64569879],
#         [0.64858893]]])

# %%
# X_train: (number of rows, number of columns, number of predictors)
X_train.shape
# Out:
# (1546, 60, 1)

# %% [markdown]
# ## 3. Define and Evaluate LSTM model

# %% [markdown]
# ###### **NOTE:** LSTM - Long Short-Term Memory

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define model
reg = Sequential()

# -- LSTM layers -- 

# Input and first (hidden) layer (with dropout regularization)
reg.add(LSTM(units=60, return_sequences=True, 
             input_shape=(X_train.shape[1], X_train.shape[2])))
reg.add(Dropout(0.1))

# Additional hidden layers
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=False))
reg.add(Dropout(0.1))

# Output layer
reg.add(Dense(units=X_train.shape[2]))

# Compile model
reg.compile(optimizer='adam', loss='mean_squared_error')

# Summarize LSTM model
reg.summary()

# Train (fit) model
history = reg.fit(X_train, y_train, batch_size=32, epochs=100)

# Plot loss during training (Mean Squared Error - MSE)
plt.plot(history.history['loss'], 'g', label='loss')
# Plot title and labels
plt.title('Training Curve')
plt.xlabel('Epochs')
plt.ylabel('MSE')
# Plot legend and grid
plt.legend()
plt.grid()

# Show loss results
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 60)            14880
#
#  dropout (Dropout)           (None, 60, 60)            0
#
#  lstm_1 (LSTM)               (None, 60, 60)            29040
#
#  dropout_1 (Dropout)         (None, 60, 60)            0
#
#  lstm_2 (LSTM)               (None, 60, 60)            29040
#
#  dropout_2 (Dropout)         (None, 60, 60)            0
#
#  lstm_3 (LSTM)               (None, 60)                29040
#
#  dropout_3 (Dropout)         (None, 60)                0
#
#  dense (Dense)               (None, 1)                 61
#
# =================================================================
# Total params: 102,061
# Trainable params: 102,061
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 49/49 [==============================] - 14s 125ms/step - loss: 0.0111
# Epoch 2/100
# 49/49 [==============================] - 7s 148ms/step - loss: 0.0025
# Epoch 3/100
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0022
# Epoch 4/100
# 49/49 [==============================] - 7s 146ms/step - loss: 0.0019
# Epoch 5/100
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0018
# Epoch 6/100
# 49/49 [==============================] - 7s 145ms/step - loss: 0.0017
# Epoch 7/100
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0016
# Epoch 8/100
# 49/49 [==============================] - 7s 146ms/step - loss: 0.0015
# Epoch 9/100
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0016
# Epoch 10/100
# 49/49 [==============================] - 7s 144ms/step - loss: 0.0013
# Epoch 11/100
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0014
# Epoch 12/100
# 49/49 [==============================] - 7s 138ms/step - loss: 0.0012
# Epoch 13/100
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0012
# Epoch 14/100
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0012
# Epoch 15/100
# 49/49 [==============================] - 7s 148ms/step - loss: 0.0013
# Epoch 16/100
# 49/49 [==============================] - 6s 126ms/step - loss: 0.0010
# Epoch 17/100
# 49/49 [==============================] - 8s 155ms/step - loss: 9.6057e-04
# Epoch 18/100
# 49/49 [==============================] - 7s 145ms/step - loss: 9.3168e-04
# Epoch 19/100
# 49/49 [==============================] - 7s 151ms/step - loss: 9.2106e-04
# Epoch 20/100
# 49/49 [==============================] - 7s 148ms/step - loss: 9.1475e-04
# Epoch 21/100
# 49/49 [==============================] - 7s 138ms/step - loss: 8.3861e-04
# Epoch 22/100
# 49/49 [==============================] - 8s 155ms/step - loss: 8.7129e-04
# Epoch 23/100
# 49/49 [==============================] - 7s 133ms/step - loss: 9.0410e-04
# Epoch 24/100
# 49/49 [==============================] - 8s 154ms/step - loss: 9.1764e-04
# Epoch 25/100
# 49/49 [==============================] - 6s 130ms/step - loss: 8.4758e-04
# Epoch 26/100
# 49/49 [==============================] - 7s 151ms/step - loss: 9.1289e-04
# Epoch 27/100
# 49/49 [==============================] - 6s 128ms/step - loss: 8.1620e-04
# Epoch 28/100
# 49/49 [==============================] - 7s 150ms/step - loss: 7.3985e-04
# Epoch 29/100
# 49/49 [==============================] - 7s 136ms/step - loss: 8.5218e-04
# Epoch 30/100
# 49/49 [==============================] - 7s 138ms/step - loss: 7.3407e-04
# Epoch 31/100
# 49/49 [==============================] - 7s 150ms/step - loss: 7.2133e-04
# Epoch 32/100
# 49/49 [==============================] - 6s 129ms/step - loss: 7.4061e-04
# Epoch 33/100
# 49/49 [==============================] - 7s 149ms/step - loss: 7.0513e-04
# Epoch 34/100
# 49/49 [==============================] - 6s 129ms/step - loss: 6.9345e-04
# Epoch 35/100
# 49/49 [==============================] - 7s 150ms/step - loss: 6.7452e-04
# Epoch 36/100
# 49/49 [==============================] - 6s 129ms/step - loss: 6.9109e-04
# Epoch 37/100
# 49/49 [==============================] - 7s 150ms/step - loss: 7.1607e-04
# Epoch 38/100
# 49/49 [==============================] - 6s 128ms/step - loss: 6.7862e-04
# Epoch 39/100
# 49/49 [==============================] - 7s 151ms/step - loss: 7.0757e-04
# Epoch 40/100
# 49/49 [==============================] - 6s 129ms/step - loss: 6.5052e-04
# Epoch 41/100
# 49/49 [==============================] - 7s 146ms/step - loss: 6.4860e-04
# Epoch 42/100
# 49/49 [==============================] - 7s 142ms/step - loss: 5.7145e-04
# Epoch 43/100
# 49/49 [==============================] - 7s 132ms/step - loss: 5.9801e-04
# Epoch 44/100
# 49/49 [==============================] - 7s 147ms/step - loss: 5.1455e-04
# Epoch 45/100
# 49/49 [==============================] - 6s 128ms/step - loss: 6.2458e-04
# Epoch 46/100
# 49/49 [==============================] - 7s 149ms/step - loss: 5.5378e-04
# Epoch 47/100
# 49/49 [==============================] - 6s 130ms/step - loss: 5.7935e-04
# Epoch 48/100
# 49/49 [==============================] - 7s 150ms/step - loss: 5.4629e-04
# Epoch 49/100
# 49/49 [==============================] - 6s 128ms/step - loss: 5.6155e-04
# Epoch 50/100
# 49/49 [==============================] - 7s 149ms/step - loss: 5.3327e-04
# Epoch 51/100
# 49/49 [==============================] - 6s 128ms/step - loss: 6.0861e-04
# Epoch 52/100
# 49/49 [==============================] - 7s 149ms/step - loss: 5.3131e-04
# Epoch 53/100
# 49/49 [==============================] - 6s 131ms/step - loss: 5.1596e-04
# Epoch 54/100
# 49/49 [==============================] - 7s 145ms/step - loss: 5.6401e-04
# Epoch 55/100
# 49/49 [==============================] - 7s 144ms/step - loss: 5.1841e-04
# Epoch 56/100
# 49/49 [==============================] - 7s 132ms/step - loss: 5.0938e-04
# Epoch 57/100
# 49/49 [==============================] - 7s 150ms/step - loss: 5.6663e-04
# Epoch 58/100
# 49/49 [==============================] - 7s 152ms/step - loss: 5.0507e-04
# Epoch 59/100
# 49/49 [==============================] - 7s 150ms/step - loss: 5.2985e-04
# Epoch 60/100
# 49/49 [==============================] - 6s 129ms/step - loss: 4.9576e-04
# Epoch 61/100
# 49/49 [==============================] - 7s 150ms/step - loss: 4.5040e-04
# Epoch 62/100
# 49/49 [==============================] - 6s 130ms/step - loss: 5.0950e-04
# Epoch 63/100
# 49/49 [==============================] - 7s 149ms/step - loss: 4.6732e-04
# Epoch 64/100
# 49/49 [==============================] - 7s 142ms/step - loss: 4.6275e-04
# Epoch 65/100
# 49/49 [==============================] - 7s 134ms/step - loss: 4.3956e-04
# Epoch 66/100
# 49/49 [==============================] - 7s 150ms/step - loss: 4.3600e-04
# Epoch 67/100
# 49/49 [==============================] - 6s 128ms/step - loss: 4.3130e-04
# Epoch 68/100
# 49/49 [==============================] - 7s 150ms/step - loss: 3.9984e-04
# Epoch 69/100
# 49/49 [==============================] - 6s 128ms/step - loss: 4.3031e-04
# Epoch 70/100
# 49/49 [==============================] - 7s 150ms/step - loss: 4.0740e-04
# Epoch 71/100
# 49/49 [==============================] - 6s 128ms/step - loss: 4.2758e-04
# Epoch 72/100
# 49/49 [==============================] - 7s 150ms/step - loss: 4.0343e-04
# Epoch 73/100
# 49/49 [==============================] - 6s 130ms/step - loss: 4.2565e-04
# Epoch 74/100
# 49/49 [==============================] - 7s 150ms/step - loss: 3.9005e-04
# Epoch 75/100
# 49/49 [==============================] - 7s 137ms/step - loss: 4.3199e-04
# Epoch 76/100
# 49/49 [==============================] - 7s 141ms/step - loss: 4.2863e-04
# Epoch 77/100
# 49/49 [==============================] - 7s 148ms/step - loss: 4.5087e-04
# Epoch 78/100
# 49/49 [==============================] - 6s 129ms/step - loss: 4.4620e-04
# Epoch 79/100
# 49/49 [==============================] - 7s 150ms/step - loss: 4.1103e-04
# Epoch 80/100
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9735e-04
# Epoch 81/100
# 49/49 [==============================] - 7s 150ms/step - loss: 4.1553e-04
# Epoch 82/100
# 49/49 [==============================] - 6s 129ms/step - loss: 4.0637e-04
# Epoch 83/100
# 49/49 [==============================] - 7s 149ms/step - loss: 3.7032e-04
# Epoch 84/100
# 49/49 [==============================] - 6s 128ms/step - loss: 3.8702e-04
# Epoch 85/100
# 49/49 [==============================] - 7s 150ms/step - loss: 3.7344e-04
# Epoch 86/100
# 49/49 [==============================] - 6s 131ms/step - loss: 4.0977e-04
# Epoch 87/100
# 49/49 [==============================] - 7s 145ms/step - loss: 4.1095e-04
# Epoch 88/100
# 49/49 [==============================] - 7s 143ms/step - loss: 3.4111e-04
# Epoch 89/100
# 49/49 [==============================] - 7s 133ms/step - loss: 3.6418e-04
# Epoch 90/100
# 49/49 [==============================] - 7s 149ms/step - loss: 3.4669e-04
# Epoch 91/100
# 49/49 [==============================] - 6s 127ms/step - loss: 3.6469e-04
# Epoch 92/100
# 49/49 [==============================] - 7s 150ms/step - loss: 3.7262e-04
# Epoch 93/100
# 49/49 [==============================] - 6s 129ms/step - loss: 3.5735e-04
# Epoch 94/100
# 49/49 [==============================] - 7s 150ms/step - loss: 3.8010e-04
# Epoch 95/100
# 49/49 [==============================] - 6s 129ms/step - loss: 3.5086e-04
# Epoch 96/100
# 49/49 [==============================] - 7s 152ms/step - loss: 3.6333e-04
# Epoch 97/100
# 49/49 [==============================] - 7s 135ms/step - loss: 4.1918e-04
# Epoch 98/100
# 49/49 [==============================] - 9s 176ms/step - loss: 3.6244e-04
# Epoch 99/100
# 49/49 [==============================] - 7s 137ms/step - loss: 3.3813e-04
# Epoch 100/100
# 49/49 [==============================] - 7s 147ms/step - loss: 3.6077e-04

# %% [markdown]
# #### Make predictions

# %%
# Get n (number of timesteps) previous stock prices for predicting
inputs = dataset[len(dataset)-len(dataset_test) - timesteps:]
# Reshape input values
inputs = inputs.reshape(-1, 1)
# Scale input values, directly apply transformations (already fitted)
inputs = sc.transform(inputs)

# Define test set structure
X_test = []
# For the entire test set:
for i in range(timesteps, timesteps + len(dataset_test)):
  # Range of values from i-60 to i, first column
  X_test.append(inputs[i-timesteps:i, 0])
# Convert to NumPy array
X_test = np.array(X_test)

# Obtain 3D structure of the test set
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Predict the test set results
predicted_stock_price = reg.predict(X_test)
# Apply inverse transformations
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
real_stock_price = sc.inverse_transform(dataset_test)

# Print predicted and real stock prices side-by-side (if required)
# print(np.concatenate((predicted_stock_price.reshape(len(predicted_stock_price), 1), 
#                       real_stock_price.reshape(len(real_stock_price), 1)), 1 ))

# Print Scores
print('')
print('--- Prediction Scores ---')
print('')
# Mean Absolute Error (MAE)
print('MAE: %.3f' % (mean_absolute_error(real_stock_price, predicted_stock_price)))
# Mean Squared Error (MSE)
print('MSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price)))
# Root Mean Squared Error (RMSE)
print('RMSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price, squared=False)))
# R^2 Score (Goodness-of-Fit)
print('R^2 Score: %.3f%%' % (r2_score(real_stock_price, predicted_stock_price) * 100))
# Out:
# 13/13 [==============================] - 2s 35ms/step
#
# --- Prediction Scores ---
#
# MAE: 0.870
# MSE: 1.331
# RMSE: 1.154
# R^2 Score: 96.950%

# %% [markdown]
# #### Visualize Prediction Results

# %%
# Define results figure
td_results = plt.figure(figsize=(12,6))

# Plot results
td_results = plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
td_results = plt.plot(real_stock_price, color = 'red', label = 'Real Stock Price')
# Adjust Y-Axis range
plt.yticks(np.arange(70, 130, 5))
# Plot title and labels
plt.xlabel('Days')
plt.ylabel('Stock Price ($)')
plt.title('TD Bank Stock Price Prediction')
# Plot legend and grid
plt.legend()
plt.grid()

# Show plot
plt.show()

# %%
# Combined box plot distributions
box_plots_comb = plt.figure(figsize=(8, 6))

# Box plot for lr_pred
ax1 = box_plots_comb.add_subplot(1, 2, 1)
ax1 = sns.boxplot(y=predicted_stock_price, color='blue', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(60, 130, 10))
# Plot title and labels
plt.xlabel('Predicted Stock Price', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Predicted Stock Price', fontsize=14)

# Box plot for linear_svr_pred
ax2 = box_plots_comb.add_subplot(1, 2, 2)
ax2 = sns.boxplot(y=real_stock_price, color='red', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(60, 130, 10))
# Plot title and label
plt.xlabel('Real Stock Price', fontsize=12)
plt.title('Real Stock Price', fontsize=14)

# Show subplot
plt.show()
