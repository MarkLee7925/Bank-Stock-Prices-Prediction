# %% [markdown]
# # TD Bank - Stock Prices Prediction

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas_datareader as webreader
import pandas as pd
import tensorflow as tf
import seaborn as sns
import datetime as dt
import requests

from datetime import date, timedelta, datetime
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from pandas_datareader import data
from tensorflow import keras

# %% [markdown]
# ## 2. Data Preprocessing and Visualization

# %% [markdown]
# ### 2.1. Load Data

# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader

# %%
# # Import dataset
df = pd.read_csv('TD-Stocks-2015-2023.csv')

# today = date.today()
# date_today = today.strftime("%Y-%m-%d")
# date_start = '2015-03-11'

# # Read stock quotes from Yahoo Finance
# df = data.DataReader('TD.TO', data_source='yahoo', start=date_start, end=date_today)

# %% [markdown]
# ### 2.2. Analyze Data

# %%
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2015-03-13  53.709999  53.820000  53.029999  53.570000  39.117744
# 1     2015-03-16  53.639999  54.400002  53.369999  53.950001  39.395226
# 2     2015-03-17  54.000000  54.250000  53.349998  54.119999  39.519360
# 3     2015-03-18  54.000000  54.139999  53.730000  54.000000  39.431740
# 4     2015-03-19  54.049999  54.090000  53.380001  53.639999  39.168861
# ...          ...        ...        ...        ...        ...        ...
# 2003  2023-03-08  87.239998  87.540001  86.800003  87.190002  87.190002
# 2004  2023-03-09  86.910004  86.970001  85.260002  85.620003  85.620003
# 2005  2023-03-10  85.000000  85.050003  83.070000  83.769997  83.769997
# 2006  2023-03-13        NaN        NaN        NaN        NaN        NaN
# 2007  2023-03-14  84.000000  84.000000  80.809998  81.000000  81.000000
#
#          Volume
# 0     2078400.0
# 1     3030000.0
# 2     2659100.0
# 3     2984500.0
# 4     3309500.0
# ...         ...
# 2003  5172100.0
# 2004  6337400.0
# 2005  9909700.0
# 2006        NaN
# 2007  8181200.0
#
# [2008 rows x 7 columns]

# %%
# Brief info about dataframe - non-null values and datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2008 entries, 0 to 2007
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2008 non-null   object
#  1   Open       2007 non-null   float64
#  2   High       2007 non-null   float64
#  3   Low        2007 non-null   float64
#  4   Close      2007 non-null   float64
#  5   Adj Close  2007 non-null   float64
#  6   Volume     2007 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 109.9+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date         0
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
# Drop/impute missing values (if required)
df = df.dropna(how='any', axis=0)

# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# imputer.fit_transform(dataset)
# dataset = imputer.transform(dataset)
# df.dropna(inplace=True)

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Input data of np array - Closing price
dataset = df.iloc[:, 4:5].values

# Dataset shape
print(dataset.shape)
# Out:
# (2007, 1)

# %%
# Dataframe statistics on quantitative (numerical) values
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2007.000000  2007.000000  2007.000000  2007.000000  2007.000000
# mean     71.894569    72.330558    71.431096    71.892043    62.426862
# std      13.089991    13.164481    13.033544    13.091871    16.390616
# min      48.299999    49.209999    47.750000    49.020000    36.482422
# 25%      60.524999    61.024999    60.065000    60.524999    51.086191
# 50%      72.959999    73.279999    72.510002    72.889999    61.081535
# 75%      79.905002    80.655002    79.555001    80.314999    75.331440
# max     107.800003   109.080002   107.279999   107.839996   103.521088
#
#              Volume
# count  2.007000e+03
# mean   4.169345e+06
# std    2.945870e+06
# min    4.116000e+05
# 25%    2.478200e+06
# 50%    3.251100e+06
# 75%    4.725900e+06
# max    2.547830e+07

# %% [markdown]
# ### 2.3. Visualize Data

# %% [markdown]
# #### Pariwise relationship between features

# %%
# Pairwise distributions
sns.pairplot(df)

# Show figure
plt.show()

# %% [markdown]
# #### Correlation Map

# %%
# Define figure
plt.figure(figsize=(10,10))

# Correlation Map
sns.heatmap(df.corr(method='pearson'), annot=True, cmap='YlGn', fmt='.2f')
# Adjust X and Y-Axes
plt.xticks(rotation=0)
plt.yticks(rotation=0)
# Plot title
plt.title('Correlation Map')

# Show figure
plt.show()

# %% [markdown]
# #### Individual stock prices and volume distribution

# %%
# Define stock prices figure
td_stock_prices = plt.figure(figsize=(10,24))

# Open Stock Price
ax1 = td_stock_prices.add_subplot(6, 1, 1)
ax1 = plt.plot(df['Open'], color = 'violet')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# High Stock Price
ax2 = td_stock_prices.add_subplot(6, 1, 2)
ax2 = plt.plot(df['High'], color = 'blue')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Low Stock Price
ax3 = td_stock_prices.add_subplot(6, 1, 3)
ax3 = plt.plot(df['Low'], color = 'cyan')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Closing Stock Price (target variable)
ax4 = td_stock_prices.add_subplot(6, 1, 4)
ax4 = plt.plot(df['Close'], color = 'green')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Adjusting Closing Stock Price
ax5 = td_stock_prices.add_subplot(6, 1, 5)
ax5 = plt.plot(df['Adj Close'], color = 'orange')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Volume (number of stocks)
ax6 = td_stock_prices.add_subplot(6, 1, 6)
ax6 = plt.plot(df['Volume'], color = 'red')
# Adjust axes range(s)
# plt.xticks()
# plt.yticks()
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Stock Volume', fontsize=14)
# Plot grid
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Combined distributions

# %%
# Define figure
td_stock_prices_comb = plt.figure(figsize=(12,6))

# Open Stock Price
td_stock_prices_comb = plt.plot(df['Open'], color = 'violet', label = 'Open')
# High Stock Price
td_stock_prices_comb = plt.plot(df['High'], color = 'blue', label = 'High')
# Low Stock Price
td_stock_prices_comb = plt.plot(df['High'], color = 'cyan', label = 'Low')
# Closing Stock Price
td_stock_prices_comb = plt.plot(df['Close'], color = 'green', label = 'Closing')
# Adjusted Closing Stock Price
td_stock_prices_comb = plt.plot(df['Adj Close'], color = 'orange', 
                                 label = 'Adj. Closing')
# Adjust X and Y-Axes ranges
plt.xticks(np.arange(0, 2200, 200))
plt.yticks(np.arange(30, 125, 5))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Combined Stock Prices Distribution', fontsize=14)
# Plot legend and grid
plt.legend(title="Stock Prices", bbox_to_anchor=(1, 0.7))
plt.grid(True)

# Show plot
plt.show()

# %%
# Define figure
td_comb_dist = plt.figure(figsize=(12, 36))

# -- Open Stock Prices --

# Histogram
ax1 = td_comb_dist.add_subplot(6, 2, 1)
ax1 = plt.hist(x=df['Open'], color='violet', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax2 = td_comb_dist.add_subplot(6, 2, 2)
ax2 = sns.boxplot(x=df['Open'], color='violet')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- High Stock Prices --

# Histogram
ax3 = td_comb_dist.add_subplot(6, 2, 3)
ax3 = plt.hist(x=df['High'], color='blue', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax4 = td_comb_dist.add_subplot(6, 2, 4)
ax4 = sns.boxplot(x=df['High'], color='blue')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Low Stock Prices --

# Histogram
ax5 = td_comb_dist.add_subplot(6, 2, 5)
ax5 = plt.hist(x=df['Low'], color='cyan', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax6 = td_comb_dist.add_subplot(6, 2, 6)
ax6 = sns.boxplot(x=df['Low'], color='cyan')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Closing Stock Prices --

# Histogram
ax7 = td_comb_dist.add_subplot(6, 2, 7)
ax7 = plt.hist(x=df['Close'], color='green', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax8 = td_comb_dist.add_subplot(6, 2, 8)
ax8 = sns.boxplot(x=df['Close'], color='green')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Adjusted Closing Stock Prices --

# Histogram
ax9 = td_comb_dist.add_subplot(6, 2, 9)
ax9 = plt.hist(x=df['Adj Close'], color='orange', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 480, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax10 = td_comb_dist.add_subplot(6, 2, 10)
ax10 = sns.boxplot(x=df['Adj Close'], color='orange')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Volume of Stocks --

# Histogram
ax11 = td_comb_dist.add_subplot(6, 2, 11)
ax11 = plt.hist(x=df['Volume'], color='red', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 28000000, 2000000))
plt.yticks(np.arange(0, 1100, 100))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax12 = td_comb_dist.add_subplot(6, 2, 12)
ax12 = sns.boxplot(x=df['Volume'], color='red')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 28000000, 2000000))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)
# Plot grid
plt.grid(True)

# Show subplot
plt.show()

# %% [markdown]
# ### 2.4. Feature Engineering

# %%
# Normalize data
sc = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = sc.fit_transform(dataset)

# %%
dataset_scaled
# Out:
# array([[0.07735465],
#        [0.08381505],
#        [0.08670519],
#        ...,
#        [0.62223743],
#        [0.59078544],
#        [0.54369266]])

# %%
# Split dataset into training set and test set (80/20 split)
training_size = int(len(df)*0.8)
dataset_train = dataset_scaled[:training_size]
dataset_test = dataset_scaled[training_size:]

print('Training set shape: ' + str(dataset_train.shape))
print('Test set shape: ' + str(dataset_test.shape))
# Out:
# Training set shape: (1605, 1)
# Test set shape: (402, 1)

# %%
# Define number of timesteps (number of business days)
timesteps = 60

# %%
# Predict stock price results using n timesteps
def define_training_data(timesteps, dataset):
  """
  timesteps - number of timesteps (business days)
  dataset   - stock prices (training) dataset
  """

  # X - number of timesteps, y - indicators (features) used for training
  X, y = [], []
  for i in range(timesteps, dataset.shape[0]):
    # Get number of timesteps (business days)
    X.append(dataset[i-timesteps:i, 0])
    # Starting date of reporting (increments during model training)
    y.append(dataset[i, 0])
  # Convert to NumPy array
  X, y = np.array(X), np.array(y)
  return X, y

X_train, y_train = define_training_data(timesteps, dataset_train)
print(X_train.shape, y_train.shape)
# Out:
# (1545, 60) (1545,)

# %%
# Reshape (number of rows, number of timesteps (columns), number of predictors)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# %%
X_train
# Out:
# array([[[0.07735465],
#         [0.08381505],
#         [0.08670519],
#         ...,
#         [0.09197552],
#         [0.09061541],
#         [0.07633455]],
#
#        [[0.08381505],
#         [0.08670519],
#         [0.08466509],
#         ...,
#         [0.09061541],
#         [0.07633455],
#         [0.09214552]],
#
#        [[0.08670519],
#         [0.08466509],
#         [0.0785447 ],
#         ...,
#         [0.07633455],
#         [0.09214552],
#         [0.09384565]],
#
#        ...,
#
#        [[0.61560703],
#         [0.62716774],
#         [0.63039783],
#         ...,
#         [0.57922472],
#         [0.58194496],
#         [0.58959536]],
#
#        [[0.62716774],
#         [0.63039783],
#         [0.62529761],
#         ...,
#         [0.58194496],
#         [0.58959536],
#         [0.5768446 ]],
#
#        [[0.63039783],
#         [0.62529761],
#         [0.62104736],
#         ...,
#         [0.58959536],
#         [0.5768446 ],
#         [0.58823539]]])

# %%
# X_train: (number of rows, number of columns, number of predictors)
X_train.shape
# Out:
# (1545, 60, 1)

# %% [markdown]
# ## 3. Define and Evaluate LSTM model

# %% [markdown]
# ###### **NOTE:** LSTM - Long Short-Term Memory

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define model
reg = Sequential()

# -- LSTM layers -- 

# Input and first (hidden) layer (with dropout regularization)
reg.add(LSTM(units=60, return_sequences=True, 
             input_shape=(X_train.shape[1], X_train.shape[2])))
reg.add(Dropout(0.1))

# Additional hidden layers
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=False))
reg.add(Dropout(0.1))

# Output layer
reg.add(Dense(units=X_train.shape[2]))

# Compile model
reg.compile(optimizer='adam', loss='mean_squared_error')

# Summarize LSTM model
reg.summary()

# Train (fit) model
history = reg.fit(X_train, y_train, batch_size=32, epochs=100)

# Plot loss during training (Mean Squared Error - MSE)
plt.plot(history.history['loss'], 'g', label='loss')
# Plot title and labels
plt.title('Training Curve')
plt.xlabel('Epochs')
plt.ylabel('MSE')
# Plot legend and grid
plt.legend()
plt.grid(True)

# Show loss results
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 60)            14880
#
#  dropout (Dropout)           (None, 60, 60)            0
#
#  lstm_1 (LSTM)               (None, 60, 60)            29040
#
#  dropout_1 (Dropout)         (None, 60, 60)            0
#
#  lstm_2 (LSTM)               (None, 60, 60)            29040
#
#  dropout_2 (Dropout)         (None, 60, 60)            0
#
#  lstm_3 (LSTM)               (None, 60)                29040
#
#  dropout_3 (Dropout)         (None, 60)                0
#
#  dense (Dense)               (None, 1)                 61
#
# =================================================================
# Total params: 102,061
# Trainable params: 102,061
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 49/49 [==============================] - 16s 159ms/step - loss: 0.0116
# Epoch 2/100
# 49/49 [==============================] - 8s 168ms/step - loss: 0.0023
# Epoch 3/100
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0022
# Epoch 4/100
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0019
# Epoch 5/100
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0021
# Epoch 6/100
# 49/49 [==============================] - 8s 160ms/step - loss: 0.0016
# Epoch 7/100
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0015
# Epoch 8/100
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0014
# Epoch 9/100
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013
# Epoch 10/100
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0013
# Epoch 11/100
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0012
# Epoch 12/100
# 49/49 [==============================] - 8s 158ms/step - loss: 0.0011
# Epoch 13/100
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0013
# Epoch 14/100
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0011
# Epoch 15/100
# 49/49 [==============================] - 8s 154ms/step - loss: 0.0013
# Epoch 16/100
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0010
# Epoch 17/100
# 49/49 [==============================] - 8s 167ms/step - loss: 9.1788e-04
# Epoch 18/100
# 49/49 [==============================] - 8s 163ms/step - loss: 9.6754e-04
# Epoch 19/100
# 49/49 [==============================] - 9s 178ms/step - loss: 9.6044e-04
# Epoch 20/100
# 49/49 [==============================] - 8s 155ms/step - loss: 8.7846e-04
# Epoch 21/100
# 49/49 [==============================] - 9s 177ms/step - loss: 9.5405e-04
# Epoch 22/100
# 49/49 [==============================] - 9s 180ms/step - loss: 9.4786e-04
# Epoch 23/100
# 49/49 [==============================] - 8s 161ms/step - loss: 8.5432e-04
# Epoch 24/100
# 49/49 [==============================] - 9s 184ms/step - loss: 8.1584e-04
# Epoch 25/100
# 49/49 [==============================] - 9s 180ms/step - loss: 8.4107e-04
# Epoch 26/100
# 49/49 [==============================] - 7s 150ms/step - loss: 8.0021e-04
# Epoch 27/100
# 49/49 [==============================] - 9s 176ms/step - loss: 8.0265e-04
# Epoch 28/100
# 49/49 [==============================] - 9s 178ms/step - loss: 7.6267e-04
# Epoch 29/100
# 49/49 [==============================] - 7s 149ms/step - loss: 7.3996e-04
# Epoch 30/100
# 49/49 [==============================] - 9s 177ms/step - loss: 7.0352e-04
# Epoch 31/100
# 49/49 [==============================] - 8s 169ms/step - loss: 6.9099e-04
# Epoch 32/100
# 49/49 [==============================] - 8s 164ms/step - loss: 7.5118e-04
# Epoch 33/100
# 49/49 [==============================] - 9s 180ms/step - loss: 7.0811e-04
# Epoch 34/100
# 49/49 [==============================] - 8s 159ms/step - loss: 8.0700e-04
# Epoch 35/100
# 49/49 [==============================] - 8s 171ms/step - loss: 7.8457e-04
# Epoch 36/100
# 49/49 [==============================] - 9s 182ms/step - loss: 6.9174e-04
# Epoch 37/100
# 49/49 [==============================] - 8s 158ms/step - loss: 6.7617e-04
# Epoch 38/100
# 49/49 [==============================] - 9s 177ms/step - loss: 6.2876e-04
# Epoch 39/100
# 49/49 [==============================] - 9s 182ms/step - loss: 6.5345e-04
# Epoch 40/100
# 49/49 [==============================] - 8s 155ms/step - loss: 6.5360e-04
# Epoch 41/100
# 49/49 [==============================] - 9s 184ms/step - loss: 7.1956e-04
# Epoch 42/100
# 49/49 [==============================] - 9s 179ms/step - loss: 6.7019e-04
# Epoch 43/100
# 49/49 [==============================] - 8s 154ms/step - loss: 6.2041e-04
# Epoch 44/100
# 49/49 [==============================] - 9s 179ms/step - loss: 6.3513e-04
# Epoch 45/100
# 49/49 [==============================] - 9s 181ms/step - loss: 5.4886e-04
# Epoch 46/100
# 49/49 [==============================] - 8s 159ms/step - loss: 6.1229e-04
# Epoch 47/100
# 49/49 [==============================] - 9s 180ms/step - loss: 6.2404e-04
# Epoch 48/100
# 49/49 [==============================] - 9s 179ms/step - loss: 5.6726e-04
# Epoch 49/100
# 49/49 [==============================] - 8s 158ms/step - loss: 6.5079e-04
# Epoch 50/100
# 49/49 [==============================] - 9s 180ms/step - loss: 5.7863e-04
# Epoch 51/100
# 49/49 [==============================] - 8s 170ms/step - loss: 5.6484e-04
# Epoch 52/100
# 49/49 [==============================] - 8s 164ms/step - loss: 5.7254e-04
# Epoch 53/100
# 49/49 [==============================] - 9s 184ms/step - loss: 5.8224e-04
# Epoch 54/100
# 49/49 [==============================] - 8s 167ms/step - loss: 5.3503e-04
# Epoch 55/100
# 49/49 [==============================] - 9s 175ms/step - loss: 5.0420e-04
# Epoch 56/100
# 49/49 [==============================] - 10s 201ms/step - loss: 5.3485e-04
# Epoch 57/100
# 49/49 [==============================] - 10s 206ms/step - loss: 5.3025e-04
# Epoch 58/100
# 49/49 [==============================] - 9s 179ms/step - loss: 4.7245e-04
# Epoch 59/100
# 49/49 [==============================] - 10s 204ms/step - loss: 4.7565e-04
# Epoch 60/100
# 49/49 [==============================] - 11s 215ms/step - loss: 5.4301e-04
# Epoch 61/100
# 49/49 [==============================] - 10s 213ms/step - loss: 4.5529e-04
# Epoch 62/100
# 49/49 [==============================] - 9s 188ms/step - loss: 4.8056e-04
# Epoch 63/100
# 49/49 [==============================] - 10s 197ms/step - loss: 5.6186e-04
# Epoch 64/100
# 49/49 [==============================] - 11s 219ms/step - loss: 4.7378e-04
# Epoch 65/100
# 49/49 [==============================] - 11s 216ms/step - loss: 4.5425e-04
# Epoch 66/100
# 49/49 [==============================] - 11s 222ms/step - loss: 5.0734e-04
# Epoch 67/100
# 49/49 [==============================] - 9s 189ms/step - loss: 4.9407e-04
# Epoch 68/100
# 49/49 [==============================] - 11s 217ms/step - loss: 4.5150e-04
# Epoch 69/100
# 49/49 [==============================] - 11s 216ms/step - loss: 4.5825e-04
# Epoch 70/100
# 49/49 [==============================] - 10s 198ms/step - loss: 4.4938e-04
# Epoch 71/100
# 49/49 [==============================] - 8s 155ms/step - loss: 4.2883e-04
# Epoch 72/100
# 49/49 [==============================] - 9s 193ms/step - loss: 4.1553e-04
# Epoch 73/100
# 49/49 [==============================] - 10s 207ms/step - loss: 4.0440e-04
# Epoch 74/100
# 49/49 [==============================] - 10s 199ms/step - loss: 4.1401e-04
# Epoch 75/100
# 49/49 [==============================] - 9s 179ms/step - loss: 4.1585e-04
# Epoch 76/100
# 49/49 [==============================] - 10s 205ms/step - loss: 4.9385e-04
# Epoch 77/100
# 49/49 [==============================] - 10s 206ms/step - loss: 4.0295e-04
# Epoch 78/100
# 49/49 [==============================] - 10s 196ms/step - loss: 3.9451e-04
# Epoch 79/100
# 49/49 [==============================] - 10s 192ms/step - loss: 4.0842e-04
# Epoch 80/100
# 49/49 [==============================] - 10s 210ms/step - loss: 3.8649e-04
# Epoch 81/100
# 49/49 [==============================] - 10s 210ms/step - loss: 4.2467e-04
# Epoch 82/100
# 49/49 [==============================] - 10s 202ms/step - loss: 4.3181e-04
# Epoch 83/100
# 49/49 [==============================] - 9s 181ms/step - loss: 3.7852e-04
# Epoch 84/100
# 49/49 [==============================] - 10s 204ms/step - loss: 3.4055e-04
# Epoch 85/100
# 49/49 [==============================] - 10s 203ms/step - loss: 3.6914e-04
# Epoch 86/100
# 49/49 [==============================] - 9s 191ms/step - loss: 3.8012e-04
# Epoch 87/100
# 49/49 [==============================] - 9s 183ms/step - loss: 3.9175e-04
# Epoch 88/100
# 49/49 [==============================] - 10s 199ms/step - loss: 4.0025e-04
# Epoch 89/100
# 49/49 [==============================] - 10s 196ms/step - loss: 3.7116e-04
# Epoch 90/100
# 49/49 [==============================] - 8s 165ms/step - loss: 3.5281e-04
# Epoch 91/100
# 49/49 [==============================] - 9s 187ms/step - loss: 3.8440e-04
# Epoch 92/100
# 49/49 [==============================] - 9s 189ms/step - loss: 4.0344e-04
# Epoch 93/100
# 49/49 [==============================] - 8s 168ms/step - loss: 3.7743e-04
# Epoch 94/100
# 49/49 [==============================] - 9s 184ms/step - loss: 4.0009e-04
# Epoch 95/100
# 49/49 [==============================] - 9s 189ms/step - loss: 4.0210e-04
# Epoch 96/100
# 49/49 [==============================] - 9s 180ms/step - loss: 3.8803e-04
# Epoch 97/100
# 49/49 [==============================] - 9s 175ms/step - loss: 3.5855e-04
# Epoch 98/100
# 49/49 [==============================] - 9s 190ms/step - loss: 3.7530e-04
# Epoch 99/100
# 49/49 [==============================] - 9s 188ms/step - loss: 3.4014e-04
# Epoch 100/100
# 49/49 [==============================] - 8s 164ms/step - loss: 3.5076e-04

# %% [markdown]
# #### Make predictions

# %%
# Get n (number of timesteps) previous stock prices for predicting
inputs = dataset[len(dataset)-len(dataset_test) - timesteps:]
# Reshape input values
inputs = inputs.reshape(-1, 1)
# Scale input values, directly apply transformations (already fitted)
inputs = sc.transform(inputs)

# Define test set structure
X_test = []
# For the entire test set:
for i in range(timesteps, timesteps + len(dataset_test)):
  # Range of values from i-60 to i, first column
  X_test.append(inputs[i-timesteps:i, 0])
# Convert to NumPy array
X_test = np.array(X_test)

# Obtain 3D structure of the test set
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Predict the test set results
predicted_stock_price = reg.predict(X_test)
# Apply inverse transformations
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
real_stock_price = sc.inverse_transform(dataset_test)

# Print predicted and real stock prices side-by-side (if required)
# print(np.concatenate((predicted_stock_price.reshape(len(predicted_stock_price), 1), 
#                       real_stock_price.reshape(len(real_stock_price), 1)), 1 ))

# Print Scores
print('')
print('--- Prediction Scores ---')
print('')
# Mean Absolute Error (MAE)
print('MAE: %.3f' % (mean_absolute_error(real_stock_price, predicted_stock_price)))
# Mean Squared Error (MSE)
print('MSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price)))
# Root Mean Squared Error (RMSE)
print('RMSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price, squared=False)))
# R^2 Score (Goodness-of-Fit)
print('R^2 Score: %.3f%%' % (r2_score(real_stock_price, predicted_stock_price) * 100))
# Out:
# 13/13 [==============================] - 2s 44ms/step
#
# --- Prediction Scores ---
#
# MAE: 0.859
# MSE: 1.255
# RMSE: 1.120
# R^2 Score: 96.986%

# %% [markdown]
# #### Visualize Prediction Results

# %%
# Define results figure
td_results = plt.figure(figsize=(12,6))

# Plot results
td_results = plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
td_results = plt.plot(real_stock_price, color = 'red', label = 'Real Stock Price')
# Adjust Y-Axis range
plt.yticks(np.arange(70, 130, 5))
# Plot title and labels
plt.xlabel('Days')
plt.ylabel('Stock Price ($)')
plt.title('TD Bank Stock Price Prediction')
# Plot legend and grid
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
# Combined box plot distributions
box_plots_comb = plt.figure(figsize=(8, 6))

# Box plot for lr_pred
ax1 = box_plots_comb.add_subplot(1, 2, 1)
ax1 = sns.boxplot(y=predicted_stock_price, color='blue', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(60, 130, 10))
# Plot title and labels
plt.xlabel('Predicted Stock Price', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Predicted Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box plot for linear_svr_pred
ax2 = box_plots_comb.add_subplot(1, 2, 2)
ax2 = sns.boxplot(y=real_stock_price, color='red', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(60, 130, 10))
# Plot title and label
plt.xlabel('Real Stock Price', fontsize=12)
plt.title('Real Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Show subplot
plt.show()
