# %% [markdown]
# # TD Bank - Stock Prices Prediction

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas_datareader as webreader
import pandas as pd
import tensorflow as tf
import seaborn as sns
import datetime as dt

from datetime import date, timedelta, datetime
from sklearn.preprocessing import MinMaxScaler
from pandas_datareader import data
from tensorflow import keras

# %% [markdown]
# ## 2. Data Preprocessing and Visualization

# %% [markdown]
# ### 2.1. Load Data

# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader

# %%
# Import dataset
df = pd.read_csv('TD-Stocks-2015-2023.csv')

# today = date.today()
# date_today = today.strftime("%Y-%m-%d")
# date_start = '2016-01-01'

# # Read stock quotes from Yahoo Finance
# df = webreader.DataReader('TD.TO', data_source='yahoo', start=date_start, end=date_today)

# Input data of np array - Closing price
dataset = df.iloc[:, 4:5].values

# Dataset shape
print(dataset.shape)
# Out:
# (1987, 1)

# %% [markdown]
# ### 2.2. Analyze Data

# %%
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2015-03-12  53.570000  54.099998  53.560001  53.900002  39.358719
# 1     2015-03-13  53.709999  53.820000  53.029999  53.570000  39.117737
# 2     2015-03-16  53.639999  54.400002  53.369999  53.950001  39.395233
# 3     2015-03-17  54.000000  54.250000  53.349998  54.119999  39.519367
# 4     2015-03-18  54.000000  54.139999  53.730000  54.000000  39.431740
# ...          ...        ...        ...        ...        ...        ...
# 1982  2023-02-03  92.000000  92.949997  91.980003  92.419998  92.419998
# 1983  2023-02-06  92.040001  92.150002  91.440002  91.699997  91.699997
# 1984  2023-02-07  91.529999  92.919998  91.449997  92.820000  92.820000
# 1985  2023-02-08  92.550003  93.180000  92.360001  92.879997  92.879997
# 1986  2023-02-09  93.199997  93.660004  92.290001  92.669998  92.669998
#
#        Volume
# 0     2495900
# 1     2078400
# 2     3030000
# 3     2659100
# 4     2984500
# ...       ...
# 1982  6171900
# 1983  5463000
# 1984  3180300
# 1985  2357300
# 1986  2251000
#
# [1987 rows x 7 columns]

# %%
# Brief info about dataframe - non-null values and datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987 entries, 0 to 1986
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1987 non-null   object
#  1   Open       1987 non-null   float64
#  2   High       1987 non-null   float64
#  3   Low        1987 non-null   float64
#  4   Close      1987 non-null   float64
#  5   Adj Close  1987 non-null   float64
#  6   Volume     1987 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 108.8+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# from sklearn.impute import SimpleImputer

# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# imputer.fit_transform(dataset)
# dataset = imputer.transform(dataset)
# df.dropna(inplace=True)

# %%
# Dataframe statistics on quantitative (numerical) values
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1987.000000  1987.000000  1987.000000  1987.000000  1987.000000
# mean     71.691862    72.128666    71.233432    71.693478    62.125707
# std      13.022496    13.098858    12.970210    13.028219    16.232256
# min      48.299999    49.209999    47.750000    49.020000    36.482445
# 25%      60.345001    60.935000    60.014999    60.375000    51.026584
# 50%      72.809998    73.150002    72.389999    72.830002    60.794788
# 75%      79.180001    79.529999    78.744999    79.194999    69.987961
# max     107.800003   109.080002   107.279999   107.839996   103.521088
#
#              Volume
# count  1.987000e+03
# mean   4.167548e+06
# std    2.951783e+06
# min    4.116000e+05
# 25%    2.477550e+06
# 50%    3.250600e+06
# 75%    4.713250e+06
# max    2.547830e+07

# %% [markdown]
# ### 2.3. Visualize Data

# %% [markdown]
# #### Pariwise relationship between features

# %%
# Pairwise distributions
sns.pairplot(df)

# Show figure
plt.show()

# %% [markdown]
# #### Correlation Map

# %%
# Define figure
plt.figure(figsize=(10,10))

# Correlation Map
sns.heatmap(df.corr(method='pearson'), annot=True, cmap='YlGn', fmt='.2f')
# Adjust X and Y-Axes
plt.xticks(rotation=0)
plt.yticks(rotation=0)
# Plot title
plt.title('Correlation Map')

# Show figure
plt.show()

# %% [markdown]
# #### Individual stock prices and volume distribution

# %%
# Define stock prices figure
td_stock_prices = plt.figure(figsize=(10,24))

# Open Stock Price
ax1 = td_stock_prices.add_subplot(6, 1, 1)
ax1 = plt.plot(df['Open'], color = 'violet')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid()

# High Stock Price
ax2 = td_stock_prices.add_subplot(6, 1, 2)
ax2 = plt.plot(df['High'], color = 'indigo')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Low Stock Price
ax3 = td_stock_prices.add_subplot(6, 1, 3)
ax3 = plt.plot(df['Low'], color = 'blue')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Closing Stock Price (target variable)
ax4 = td_stock_prices.add_subplot(6, 1, 4)
ax4 = plt.plot(df['Close'], color = 'green')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Adjusting Closing Stock Price
ax5 = td_stock_prices.add_subplot(6, 1, 5)
ax5 = plt.plot(df['Adj Close'], color = 'orange')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(30, 130, 10))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid()

# Volume (number of stocks)
ax6 = td_stock_prices.add_subplot(6, 1, 6)
ax6 = plt.plot(df['Volume'], color = 'red')
# Adjust axes range(s)
# plt.xticks()
# plt.yticks()
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Stock Volume', fontsize=14)
# Plot grid
plt.grid()

# Show plot
plt.show()

# %% [markdown]
# #### Combined distributions

# %%
# Define figure
td_stock_prices_comb = plt.figure(figsize=(12,6))

# Open Stock Price
td_stock_prices_comb = plt.plot(df['Open'], color = 'violet', label = 'Open')
# High Stock Price
td_stock_prices_comb = plt.plot(df['High'], color = 'indigo', label = 'High')
# Low Stock Price
td_stock_prices_comb = plt.plot(df['High'], color = 'blue', label = 'Low')
# Closing Stock Price
td_stock_prices_comb = plt.plot(df['Close'], color = 'green', label = 'Closing')
# Adjusted Closing Stock Price
td_stock_prices_comb = plt.plot(df['Adj Close'], color = 'orange', 
                                 label = 'Adj. Closing')
# Adjust X and Y-Axes ranges
plt.xticks(np.arange(0, 2200, 200))
plt.yticks(np.arange(30, 125, 5))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Combined Stock Prices Distribution', fontsize=14)
# Plot legend and grid
plt.legend(title="Stock Prices", bbox_to_anchor=(1, 0.7))
plt.grid()

# Show plot
plt.show()

# %%
# Define figure
td_comb_dist = plt.figure(figsize=(12, 36))

# -- Open Stock Prices --

# Histogram
ax1 = td_comb_dist.add_subplot(6, 2, 1)
ax1 = plt.hist(x=df['Open'], color='violet', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Open Stock Price', fontsize=14)

# Box Plot
ax2 = td_comb_dist.add_subplot(6, 2, 2)
ax2 = sns.boxplot(x=df['Open'], color='violet')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)

# -- High Stock Prices --

# Histogram
ax3 = td_comb_dist.add_subplot(6, 2, 3)
ax3 = plt.hist(x=df['High'], color='indigo', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('High Stock Price', fontsize=14)

# Box Plot
ax4 = td_comb_dist.add_subplot(6, 2, 4)
ax4 = sns.boxplot(x=df['High'], color='indigo')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)

# -- Low Stock Prices --

# Histogram
ax5 = td_comb_dist.add_subplot(6, 2, 5)
ax5 = plt.hist(x=df['Low'], color='blue', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Low Stock Price', fontsize=14)

# Box Plot
ax6 = td_comb_dist.add_subplot(6, 2, 6)
ax6 = sns.boxplot(x=df['Low'], color='blue')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)

# -- Closing Stock Prices --

# Histogram
ax7 = td_comb_dist.add_subplot(6, 2, 7)
ax7 = plt.hist(x=df['Close'], color='green', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 640, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)

# Box Plot
ax8 = td_comb_dist.add_subplot(6, 2, 8)
ax8 = sns.boxplot(x=df['Close'], color='green')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)

# -- Adjusted Closing Stock Prices --

# Histogram
ax9 = td_comb_dist.add_subplot(6, 2, 9)
ax9 = plt.hist(x=df['Adj Close'], color='orange', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(30, 130, 10))
plt.yticks(np.arange(0, 480, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)

# Box Plot
ax10 = td_comb_dist.add_subplot(6, 2, 10)
ax10 = sns.boxplot(x=df['Adj Close'], color='orange')
# Adjust X-Axis range(s)
plt.xticks(np.arange(30, 130, 10))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)

# -- Volume of Stocks --

# Histogram
ax11 = td_comb_dist.add_subplot(6, 2, 11)
ax11 = plt.hist(x=df['Volume'], color='red', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 28000000, 2000000))
plt.yticks(np.arange(0, 1100, 100))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)

# Box Plot
ax12 = td_comb_dist.add_subplot(6, 2, 12)
ax12 = sns.boxplot(x=df['Volume'], color='red')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 28000000, 2000000))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)

# Show subplot
plt.show()

# %% [markdown]
# ### 2.4. Feature Engineering

# %%
# Normalize data
sc = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = sc.fit_transform(dataset)

# %%
dataset_scaled
# Out:
# array([[0.08296502],
#        [0.07735465],
#        [0.08381505],
#        ...,
#        [0.74464473],
#        [0.74566474],
#        [0.74209454]])

# %%
# Split dataset into training set and test set (80/20 split)
training_size = int(len(df)*0.8)
dataset_train = dataset_scaled[:training_size]
dataset_test = dataset_scaled[training_size:]

print('Training set shape: ' + str(dataset_train.shape))
print('Test set shape: ' + str(dataset_test.shape))
# Out:
# Training set shape: (1589, 1)
# Test set shape: (398, 1)

# %%
# Define number of timesteps (number of business days)
timesteps = 60

# %%
# Predict stock price results using n timesteps
def define_training_data(timesteps, dataset):
  """
  timesteps - number of timesteps (business days)
  dataset   - stock prices (training) dataset
  """

  # X - number of timesteps, y - indicators (features) used for training
  X, y = [], []
  for i in range(timesteps, dataset.shape[0]):
    # Get number of timesteps (business days)
    X.append(dataset[i-timesteps:i, 0])
    # Starting date of reporting (increments during model training)
    y.append(dataset[i, 0])
  # Convert to NumPy array
  X, y = np.array(X), np.array(y)
  return X, y

X_train, y_train = define_training_data(timesteps, dataset_train)
print(X_train.shape, y_train.shape)
# Out:
# (1529, 60) (1529,)

# %%
# Reshape (number of rows, number of timesteps (columns), number of predictors)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# %%
X_train
# Out:
# array([[[0.08296502],
#         [0.07735465],
#         [0.08381505],
#         ...,
#         [0.09996604],
#         [0.09197552],
#         [0.09061541]],
#
#        [[0.07735465],
#         [0.08381505],
#         [0.08670519],
#         ...,
#         [0.09197552],
#         [0.09061541],
#         [0.07633455]],
#
#        [[0.08381505],
#         [0.08670519],
#         [0.08466509],
#         ...,
#         [0.09061541],
#         [0.07633455],
#         [0.09214552]],
#
#        ...,
#
#        [[0.58789528],
#         [0.57973487],
#         [0.57701464],
#         ...,
#         [0.64569879],
#         [0.65657942],
#         [0.64994904]],
#
#        [[0.57973487],
#         [0.57701464],
#         [0.57123436],
#         ...,
#         [0.65657942],
#         [0.64994904],
#         [0.64467876]],
#
#        [[0.57701464],
#         [0.57123436],
#         [0.57565453],
#         ...,
#         [0.64994904],
#         [0.64467876],
#         [0.59044547]]])

# %%
# X_train: (number of rows, number of columns, number of predictors)
X_train.shape
# Out:
# (1529, 60, 1)

# %% [markdown]
# ## 3. Define and Evaluate LSTM model

# %% [markdown]
# ###### **NOTE:** LSTM - Long Short-Term Memory

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define model
reg = Sequential()

# -- LSTM layers -- 

# Input and first (hidden) layer (with dropout regularization)
reg.add(LSTM(units=60, return_sequences=True, 
             input_shape=(X_train.shape[1], X_train.shape[2])))
reg.add(Dropout(0.1))

# Additional hidden layers
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=False))
reg.add(Dropout(0.1))

# Output layer
reg.add(Dense(units=X_train.shape[2]))

# Compile model
reg.compile(optimizer='adam', loss='mean_squared_error')

# Summarize LSTM model
reg.summary()

# Train (fit) model
history = reg.fit(X_train, y_train, batch_size=32, epochs=100)

# Plot loss during training (Mean Squared Error - MSE)
plt.plot(history.history['loss'], 'g', label='loss')
# Plot title and labels
plt.title('Training Curve')
plt.xlabel('Epochs')
plt.ylabel('MSE')
# Plot legend and grid
plt.legend()
plt.grid()

# Show loss results
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 60)            14880
#
#  dropout (Dropout)           (None, 60, 60)            0
#
#  lstm_1 (LSTM)               (None, 60, 60)            29040
#
#  dropout_1 (Dropout)         (None, 60, 60)            0
#
#  lstm_2 (LSTM)               (None, 60, 60)            29040
#
#  dropout_2 (Dropout)         (None, 60, 60)            0
#
#  lstm_3 (LSTM)               (None, 60)                29040
#
#  dropout_3 (Dropout)         (None, 60)                0
#
#  dense (Dense)               (None, 1)                 61
#
# =================================================================
# Total params: 102,061
# Trainable params: 102,061
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 48/48 [==============================] - 14s 150ms/step - loss: 0.0118
# Epoch 2/100
# 48/48 [==============================] - 7s 156ms/step - loss: 0.0027
# Epoch 3/100
# 48/48 [==============================] - 7s 145ms/step - loss: 0.0023
# Epoch 4/100
# 48/48 [==============================] - 7s 145ms/step - loss: 0.0022
# Epoch 5/100
# 48/48 [==============================] - 7s 138ms/step - loss: 0.0019
# Epoch 6/100
# 48/48 [==============================] - 7s 154ms/step - loss: 0.0018
# Epoch 7/100
# 48/48 [==============================] - 6s 127ms/step - loss: 0.0017
# Epoch 8/100
# 48/48 [==============================] - 7s 151ms/step - loss: 0.0015
# Epoch 9/100
# 48/48 [==============================] - 6s 128ms/step - loss: 0.0015
# Epoch 10/100
# 48/48 [==============================] - 7s 150ms/step - loss: 0.0013
# Epoch 11/100
# 48/48 [==============================] - 6s 127ms/step - loss: 0.0011
# Epoch 12/100
# 48/48 [==============================] - 9s 183ms/step - loss: 0.0014
# Epoch 13/100
# 48/48 [==============================] - 6s 130ms/step - loss: 0.0011
# Epoch 14/100
# 48/48 [==============================] - 7s 142ms/step - loss: 0.0011
# Epoch 15/100
# 48/48 [==============================] - 6s 135ms/step - loss: 0.0011
# Epoch 16/100
# 48/48 [==============================] - 7s 138ms/step - loss: 0.0012
# Epoch 17/100
# 48/48 [==============================] - 7s 143ms/step - loss: 0.0010
# Epoch 18/100
# 48/48 [==============================] - 6s 132ms/step - loss: 9.7058e-04
# Epoch 19/100
# 48/48 [==============================] - 7s 149ms/step - loss: 0.0010
# Epoch 20/100
# 48/48 [==============================] - 6s 126ms/step - loss: 0.0010
# Epoch 21/100
# 48/48 [==============================] - 7s 151ms/step - loss: 8.9657e-04
# Epoch 22/100
# 48/48 [==============================] - 6s 128ms/step - loss: 8.5110e-04
# Epoch 23/100
# 48/48 [==============================] - 7s 150ms/step - loss: 9.1377e-04
# Epoch 24/100
# 48/48 [==============================] - 6s 127ms/step - loss: 9.8493e-04
# Epoch 25/100
# 48/48 [==============================] - 7s 151ms/step - loss: 9.0040e-04
# Epoch 26/100
# 48/48 [==============================] - 6s 130ms/step - loss: 7.8990e-04
# Epoch 27/100
# 48/48 [==============================] - 7s 152ms/step - loss: 8.1181e-04
# Epoch 28/100
# 48/48 [==============================] - 6s 128ms/step - loss: 8.5069e-04
# Epoch 29/100
# 48/48 [==============================] - 7s 150ms/step - loss: 7.7010e-04
# Epoch 30/100
# 48/48 [==============================] - 6s 129ms/step - loss: 8.2625e-04
# Epoch 31/100
# 48/48 [==============================] - 9s 179ms/step - loss: 7.4932e-04
# Epoch 32/100
# 48/48 [==============================] - 6s 129ms/step - loss: 7.0911e-04
# Epoch 33/100
# 48/48 [==============================] - 7s 150ms/step - loss: 7.0531e-04
# Epoch 34/100
# 48/48 [==============================] - 6s 128ms/step - loss: 7.5958e-04
# Epoch 35/100
# 48/48 [==============================] - 7s 150ms/step - loss: 7.4211e-04
# Epoch 36/100
# 48/48 [==============================] - 7s 137ms/step - loss: 6.9409e-04
# Epoch 37/100
# 48/48 [==============================] - 7s 141ms/step - loss: 8.0441e-04
# Epoch 38/100
# 48/48 [==============================] - 7s 143ms/step - loss: 7.1311e-04
# Epoch 39/100
# 48/48 [==============================] - 6s 133ms/step - loss: 7.1431e-04
# Epoch 40/100
# 48/48 [==============================] - 7s 151ms/step - loss: 6.5253e-04
# Epoch 41/100
# 48/48 [==============================] - 6s 129ms/step - loss: 6.4800e-04
# Epoch 42/100
# 48/48 [==============================] - 7s 152ms/step - loss: 6.4353e-04
# Epoch 43/100
# 48/48 [==============================] - 6s 129ms/step - loss: 6.9891e-04
# Epoch 44/100
# 48/48 [==============================] - 7s 151ms/step - loss: 6.1342e-04
# Epoch 45/100
# 48/48 [==============================] - 6s 129ms/step - loss: 6.4393e-04
# Epoch 46/100
# 48/48 [==============================] - 7s 150ms/step - loss: 6.7803e-04
# Epoch 47/100
# 48/48 [==============================] - 6s 129ms/step - loss: 6.4401e-04
# Epoch 48/100
# 48/48 [==============================] - 7s 152ms/step - loss: 5.7291e-04
# Epoch 49/100
# 48/48 [==============================] - 6s 129ms/step - loss: 6.1170e-04
# Epoch 50/100
# 48/48 [==============================] - 7s 150ms/step - loss: 5.9689e-04
# Epoch 51/100
# 48/48 [==============================] - 6s 132ms/step - loss: 6.3320e-04
# Epoch 52/100
# 48/48 [==============================] - 7s 146ms/step - loss: 5.4150e-04
# Epoch 53/100
# 48/48 [==============================] - 7s 141ms/step - loss: 5.7123e-04
# Epoch 54/100
# 48/48 [==============================] - 7s 136ms/step - loss: 5.5982e-04
# Epoch 55/100
# 48/48 [==============================] - 7s 147ms/step - loss: 5.2998e-04
# Epoch 56/100
# 48/48 [==============================] - 6s 127ms/step - loss: 5.1419e-04
# Epoch 57/100
# 48/48 [==============================] - 7s 150ms/step - loss: 4.9667e-04
# Epoch 58/100
# 48/48 [==============================] - 6s 129ms/step - loss: 5.4704e-04
# Epoch 59/100
# 48/48 [==============================] - 8s 175ms/step - loss: 5.2230e-04
# Epoch 60/100
# 48/48 [==============================] - 6s 130ms/step - loss: 5.4485e-04
# Epoch 61/100
# 48/48 [==============================] - 7s 151ms/step - loss: 5.5230e-04
# Epoch 62/100
# 48/48 [==============================] - 6s 129ms/step - loss: 4.9355e-04
# Epoch 63/100
# 48/48 [==============================] - 7s 152ms/step - loss: 4.7920e-04
# Epoch 64/100
# 48/48 [==============================] - 6s 131ms/step - loss: 5.1762e-04
# Epoch 65/100
# 48/48 [==============================] - 7s 151ms/step - loss: 4.4888e-04
# Epoch 66/100
# 48/48 [==============================] - 6s 129ms/step - loss: 4.8473e-04
# Epoch 67/100
# 48/48 [==============================] - 7s 151ms/step - loss: 4.4597e-04
# Epoch 68/100
# 48/48 [==============================] - 6s 129ms/step - loss: 4.6172e-04
# Epoch 69/100
# 48/48 [==============================] - 7s 150ms/step - loss: 4.8564e-04
# Epoch 70/100
# 48/48 [==============================] - 6s 133ms/step - loss: 4.4441e-04
# Epoch 71/100
# 48/48 [==============================] - 7s 145ms/step - loss: 4.4574e-04
# Epoch 72/100
# 48/48 [==============================] - 7s 144ms/step - loss: 5.0165e-04
# Epoch 73/100
# 48/48 [==============================] - 7s 136ms/step - loss: 4.1149e-04
# Epoch 74/100
# 48/48 [==============================] - 7s 152ms/step - loss: 4.2876e-04
# Epoch 75/100
# 48/48 [==============================] - 6s 130ms/step - loss: 4.1748e-04
# Epoch 76/100
# 48/48 [==============================] - 7s 151ms/step - loss: 4.9180e-04
# Epoch 77/100
# 48/48 [==============================] - 6s 129ms/step - loss: 4.4053e-04
# Epoch 78/100
# 48/48 [==============================] - 7s 151ms/step - loss: 4.3981e-04
# Epoch 79/100
# 48/48 [==============================] - 6s 129ms/step - loss: 4.5364e-04
# Epoch 80/100
# 48/48 [==============================] - 7s 151ms/step - loss: 3.6356e-04
# Epoch 81/100
# 48/48 [==============================] - 6s 130ms/step - loss: 4.1015e-04
# Epoch 82/100
# 48/48 [==============================] - 7s 152ms/step - loss: 4.3671e-04
# Epoch 83/100
# 48/48 [==============================] - 6s 130ms/step - loss: 3.9050e-04
# Epoch 84/100
# 48/48 [==============================] - 7s 151ms/step - loss: 4.2177e-04
# Epoch 85/100
# 48/48 [==============================] - 6s 134ms/step - loss: 3.5620e-04
# Epoch 86/100
# 48/48 [==============================] - 7s 146ms/step - loss: 3.9013e-04
# Epoch 87/100
# 48/48 [==============================] - 8s 160ms/step - loss: 4.0138e-04
# Epoch 88/100
# 48/48 [==============================] - 7s 143ms/step - loss: 4.6352e-04
# Epoch 89/100
# 48/48 [==============================] - 7s 148ms/step - loss: 4.1930e-04
# Epoch 90/100
# 48/48 [==============================] - 6s 131ms/step - loss: 3.8912e-04
# Epoch 91/100
# 48/48 [==============================] - 7s 151ms/step - loss: 3.7882e-04
# Epoch 92/100
# 48/48 [==============================] - 6s 131ms/step - loss: 3.9179e-04
# Epoch 93/100
# 48/48 [==============================] - 7s 152ms/step - loss: 3.8544e-04
# Epoch 94/100
# 48/48 [==============================] - 6s 130ms/step - loss: 3.8435e-04
# Epoch 95/100
# 48/48 [==============================] - 7s 152ms/step - loss: 3.5892e-04
# Epoch 96/100
# 48/48 [==============================] - 6s 131ms/step - loss: 3.8102e-04
# Epoch 97/100
# 48/48 [==============================] - 7s 152ms/step - loss: 3.8324e-04
# Epoch 98/100
# 48/48 [==============================] - 6s 129ms/step - loss: 3.9494e-04
# Epoch 99/100
# 48/48 [==============================] - 7s 151ms/step - loss: 3.7260e-04
# Epoch 100/100
# 48/48 [==============================] - 6s 132ms/step - loss: 3.5624e-04

# %% [markdown]
# #### Make predictions

# %%
# Get n (number of timesteps) previous stock prices for predicting
inputs = dataset[len(dataset)-len(dataset_test) - timesteps:]
# Reshape input values
inputs = inputs.reshape(-1, 1)
# Scale input values, directly apply transformations (already fitted)
inputs = sc.transform(inputs)

# Define test set structure
X_test = []
# For the entire test set:
for i in range(timesteps, timesteps + len(dataset_test)):
  # Range of values from i-60 to i, first column
  X_test.append(inputs[i-timesteps:i, 0])
# Convert to NumPy array
X_test = np.array(X_test)

# Obtain 3D structure of the test set
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Predict the test set results
predicted_stock_price = reg.predict(X_test)
# Apply inverse transformations
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
real_stock_price = sc.inverse_transform(dataset_test)

# Print predicted and real stock prices side-by-side (if required)
# print(np.concatenate((predicted_stock_price.reshape(len(predicted_stock_price), 1), 
#                       real_stock_price.reshape(len(real_stock_price), 1)), 1 ))

# Print Scores
print('')
print('--- Prediction Scores ---')
print('')
# Mean Absolute Error (MAE)
print('MAE: %.3f' % (mean_absolute_error(real_stock_price, predicted_stock_price)))
# Mean Squared Error (MSE)
print('MSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price)))
# Root Mean Squared Error (RMSE)
print('RMSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price, squared=False)))
# R^2 Score (Goodness-of-Fit)
print('R^2 Score: %.3f%%' % (r2_score(real_stock_price, predicted_stock_price) * 100))
# Out:
# 13/13 [==============================] - 3s 33ms/step
#
# --- Prediction Scores ---
#
# MAE: 1.103
# MSE: 1.918
# RMSE: 1.385
# R^2 Score: 95.614%

# %% [markdown]
# #### Visualize Prediction Results

# %%
# Define results figure
td_results = plt.figure(figsize=(12,6))

# Plot results
td_results = plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
td_results = plt.plot(real_stock_price, color = 'red', label = 'Real Stock Price')
# Adjust Y-Axis range
plt.yticks(np.arange(70, 130, 5))
# Plot title and labels
plt.xlabel('Days')
plt.ylabel('Stock Price ($)')
plt.title('TD Bank Stock Price Prediction')
# Plot legend and grid
plt.legend()
plt.grid()

# Show plot
plt.show()

# %%
# Combined box plot distributions
box_plots_comb = plt.figure(figsize=(8, 6))

# Box plot for lr_pred
ax1 = box_plots_comb.add_subplot(1, 2, 1)
ax1 = sns.boxplot(y=predicted_stock_price, color='blue', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(60, 130, 10))
# Plot title and labels
plt.xlabel('Predicted Stock Price', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Predicted Stock Price', fontsize=14)

# Box plot for linear_svr_pred
ax2 = box_plots_comb.add_subplot(1, 2, 2)
ax2 = sns.boxplot(y=real_stock_price, color='red', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(60, 130, 10))
# Plot title and label
plt.xlabel('Real Stock Price', fontsize=12)
plt.title('Real Stock Price', fontsize=14)

# Show subplot
plt.show()
