# %% [markdown]
# # CIBC - Stock Prices Prediction

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas_datareader as webreader
import pandas as pd
import tensorflow as tf
import time
import seaborn as sns
import datetime as dt

from datetime import date, timedelta, datetime
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from pandas_datareader import data
from tensorflow import keras

# %%
# Start run time
start_time = time.time()

# %% [markdown]
# ## 2. Data Preprocessing and Visualization

# %% [markdown]
# ### 2.1. Load Data

# %%
# Import dataset
try:
  # Load dataframe (df) into appropriate format
  df_old = pd.read_csv('CIBC-Stocks-2015-2023.csv')
  # Remove unnamed columns identified by (;)
  df_old = df_old.loc[:, ~df_old.columns.str.match('^Unnamed')]
except:
  # No data found
  print("Data not found. Please try again.")

# today = date.today()
# date_today = today.strftime("%Y-%m-%d")
# date_start = '2016-01-01'

# # Read stock quotes from Yahoo Finance
# df = webreader.DataReader('CM-PQ.TO', data_source='yahoo', start=date_start, end=date_today)

# %% [markdown]
# ### 2.2. Analyze Data

# %%
df_old
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2015-12-21  19.549999  19.549999  18.559999  19.330000  13.769021
# 1     2015-12-22  19.350000  19.610001  19.200001  19.600000  13.961345
# 2     2015-12-23  19.530001  20.750000  19.490000  19.840000  14.296420
# 3     2015-12-24  19.750000  20.639999  19.750000  20.000000  14.411710
# 4     2015-12-29  19.980000  20.500000  19.980000  20.500000  14.772001
# ...          ...        ...        ...        ...        ...        ...
# 2002  2023-12-13  18.080000  18.180000  18.080000  18.080000  18.080000
# 2003  2023-12-14  18.110001  18.150000  18.070000  18.120001  18.120001
# 2004  2023-12-15  18.240000  18.240000  18.230000  18.230000  18.230000
# 2005  2023-12-18  18.230000  18.230000  18.170000  18.180000  18.180000
# 2006  2023-12-19  18.240000  18.240000  18.230000  18.230000  18.230000
#
#       Volume
# 0      14580
# 1      47155
# 2      38380
# 3       7900
# 4       1950
# ...      ...
# 2002    4103
# 2003   16669
# 2004    2644
# 2005   47400
# 2006    1600
#
# [2007 rows x 7 columns]

# %%
# Brief info about dataframe - non-null values and datatype
df_old.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2007 entries, 0 to 2006
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2007 non-null   object
#  1   Open       2007 non-null   float64
#  2   High       2007 non-null   float64
#  3   Low        2007 non-null   float64
#  4   Close      2007 non-null   float64
#  5   Adj Close  2007 non-null   float64
#  6   Volume     2007 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 109.9+ KB

# %%
# Check for missing values
df_old.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Drop/impute missing values (if required)
df_old = df_old.dropna(how='any', axis=0)

# Check for missing values
df_old.isnull().sum()

# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# imputer.fit_transform(dataset)
# dataset = imputer.transform(dataset)
# df.dropna(inplace=True)
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Window size
win = 7

# %%
# Compute rolling averages and append to existing dataframe (df)

# Date
dates = []
# Get current date
current_date = pd.to_datetime(df_old['Date'].iloc[-1], format='%Y-%m-%d').date()
# Append next "win" days
for i in range(0, win):
  current_date += timedelta(days=1)
  dates.append(current_date)
# Convert to Pandas DataFrame
dates = pd.to_datetime(dates, format='%Y-%m-%d')
next_days = pd.DataFrame(dates)
# Append to new dataframe
df_date = pd.concat([df_old['Date'], next_days], ignore_index=True)

# Open stock price
rolling_open = df_old['Open'].rolling(window=win).mean()[(-win-1):-1]
# rolling_open = pd.DataFrame(rolling_open)
# Append to new dataframe
df_open = pd.concat([df_old['Open'], rolling_open], ignore_index=True)

# High stock price
rolling_high = df_old['High'].rolling(window=win).mean()[(-win-1):-1]
# Append to new dataframe
df_high = pd.concat([df_old['High'], rolling_high], ignore_index=True)

# Low stock price
rolling_low = df_old['Low'].rolling(window=win).mean()[(-win-1):-1]
# Append to new dataframe
df_low = pd.concat([df_old['Low'], rolling_low], ignore_index=True)

# Closing stock price (dependent variable)
rolling_close = df_old['Close'].rolling(window=win).mean()[(-win-1):-1]
# Append to new dataframe
df_close = pd.concat([df_old['Close'], rolling_close], ignore_index=True)

# Adjusted closing stock price
rolling_adj_close = df_old['Adj Close'].rolling(window=win).mean()[(-win-1):-1]
# Append to new dataframe
df_adj_close = pd.concat([df_old['Adj Close'], rolling_adj_close], ignore_index=True)

# Volume of stocks
rolling_volume = df_old['Volume'].rolling(window=win).mean()[(-win-1):-1]
# Append to new dataframe
df_volume = pd.concat([df_old['Volume'], rolling_volume], ignore_index=True)

# New dataframe
df = pd.concat([df_date, df_open, df_high, df_low, df_close, df_adj_close, df_volume], axis=1)
# Rename first column
# [0, 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
df = df.rename(columns={df.columns[0]: "Date", df.columns[1]: "Open", df.columns[2]: "High",
                        df.columns[3]: "Low", df.columns[4]: "Close", df.columns[5]: "Adj Close",
                        df.columns[6]: "Volume"})

# %%
# Dataframe statistics on quantitative (numerical) values
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2014.000000  2014.000000  2014.000000  2014.000000  2014.000000
# mean     20.982739    21.078035    20.904436    20.998598    17.896547
# std       2.932683     2.908148     2.945087     2.923942     2.711175
# min      10.180000    11.110000    10.180000    10.600000     9.067697
# 25%      18.690001    18.822500    18.592500    18.752500    16.082331
# 50%      20.959999    21.049999    20.850000    20.995000    17.787923
# 75%      23.879999    23.967499    23.827500    23.900000    19.505388
# max      25.000000    25.090000    25.000000    25.090000    23.296822
#
#               Volume
# count    2014.000000
# mean     8911.650305
# std     21138.103947
# min         0.000000
# 25%      1755.000000
# 50%      4300.000000
# 75%      8800.000000
# max    523600.000000

# %%
# Input data of np array - Closing price
dataset = df.iloc[:, 4:5].values

# Dataset shape
print(dataset.shape)
# Out:
# (2014, 1)

# %% [markdown]
# ### 2.3. Visualize Data

# %% [markdown]
# #### Pariwise relationship between features

# %%
# Pairwise distributions
sns.pairplot(df)

# Show figure
plt.show()

# %% [markdown]
# #### Correlation Map

# %%
# Define figure
plt.figure(figsize=(9,9))

# Correlation Map
sns.heatmap(df.corr(method='pearson'), annot=True, cmap='YlOrRd', fmt='.2f')
# Adjust X and Y-Axes
plt.xticks(rotation=0)
plt.yticks(rotation=0)
# Plot title
plt.title('Correlation Map')

# Show figure
plt.show()
# Out:
# <ipython-input-13-0cd6b37c2a91>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method='pearson'), annot=True, cmap='YlOrRd', fmt='.2f')

# %% [markdown]
# #### Individual stock prices and volume distribution

# %%
# Define stock prices figure
cibc_stock_prices = plt.figure(figsize=(10,24))

# Open Stock Price
ax1 = cibc_stock_prices.add_subplot(6, 1, 1)
ax1 = plt.plot(df['Open'], color = 'violet')
# Rolling Average
ax1 = plt.plot(df['Open'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(0, 55, 5))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# High Stock Price
ax2 = cibc_stock_prices.add_subplot(6, 1, 2)
ax2 = plt.plot(df['High'], color = 'blue')
# Rolling Average
ax2 = plt.plot(df['High'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(0, 55, 5))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Low Stock Price
ax3 = cibc_stock_prices.add_subplot(6, 1, 3)
ax3 = plt.plot(df['Low'], color = 'turquoise')
# Rolling Average
ax3 = plt.plot(df['Low'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(0, 55, 5))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Closing Stock Price (target variable)
ax4 = cibc_stock_prices.add_subplot(6, 1, 4)
ax4 = plt.plot(df['Close'], color = 'green')
# Rolling Average
ax4 = plt.plot(df['Close'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(0, 55, 5))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Adjusting Closing Stock Price
ax5 = cibc_stock_prices.add_subplot(6, 1, 5)
ax5 = plt.plot(df['Adj Close'], color = 'lime')
# Rolling Average
ax5 = plt.plot(df['Adj Close'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks(np.arange(0, 2250, 250))
plt.yticks(np.arange(0, 55, 5))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Volume (number of stocks)
ax6 = cibc_stock_prices.add_subplot(6, 1, 6)
ax6 = plt.plot(df['Volume'], color = 'orange')
# Rolling Average
ax6 = plt.plot(df['Volume'].rolling(window=7).mean(), "--", color = 'red', label = 'Rolling Average')
# Adjust axes range(s)
# plt.xticks()
plt.yticks(np.arange(0, 600000, 100000))
# Adjust spacing
plt.tight_layout()
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Stock Volume', fontsize=14)
# Plot legend and grid
plt.legend(loc = 'upper left')
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Combined distributions

# %%
# Define figure
cibc_stock_prices_comb = plt.figure(figsize=(12,6))

# Open Stock Price
cibc_stock_prices_comb = plt.plot(df['Open'], color = 'violet', label = 'Open')
# High Stock Price
cibc_stock_prices_comb = plt.plot(df['High'], color = 'blue', label = 'High')
# Low Stock Price
cibc_stock_prices_comb = plt.plot(df['Low'], color = 'turquoise', label = 'Low')
# Closing Stock Price
cibc_stock_prices_comb = plt.plot(df['Close'], color = 'green', label = 'Closing')
# Adjusted Closing Stock Price
cibc_stock_prices_comb = plt.plot(df['Adj Close'], color = 'lime',
                                 label = 'Adj. Closing')
# Adjust X and Y-Axes ranges
plt.xticks(np.arange(0, 2200, 200))
plt.yticks(np.arange(0, 55, 5))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Combined Stock Prices Distribution', fontsize=14)
# Plot legend and grid
plt.legend(title="Stock Prices", bbox_to_anchor=(1, 0.7))
plt.grid(True)

# Show plot
plt.show()

# %%
# Define figure - Last 21 days
cibc_comb_last_21 = plt.figure(figsize=(12,6))

# Open Stock Price
cibc_comb_last_21 = plt.plot(df['Open'].iloc[-21:], color = 'violet', label = 'Open')
# High Stock Price
cibc_comb_last_21 = plt.plot(df['High'].iloc[-21:], color = 'blue', label = 'High')
# Low Stock Price
cibc_comb_last_21 = plt.plot(df['Low'].iloc[-21:], color = 'turquoise', label = 'Low')
# Closing Stock Price
cibc_comb_last_21 = plt.plot(df['Close'].iloc[-21:], color = 'green', label = 'Closing')
# Adjusted Closing Stock Price
cibc_comb_last_21 = plt.plot(df['Adj Close'].iloc[-21:], color = 'lime',
                            label = 'Adj. Closing')
# Next 7 days (rolling average region)
cibc_results_last_21 = plt.axvline(x=(len(df)-(win+1)), color='red', label='Reporting Day')
cibc_results_last_21 = plt.axvspan(len(df)-8, len(df)-1, facecolor='lightgrey', label='Next 7 Days')

# Adjust X and Y-Axes ranges
# plt.xticks(np.arange(0, 22, 1))
plt.xticks(np.arange(len(df)-22, len(df), 1))
plt.yticks(np.arange(16, 24, 1))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Combined Stock Prices Distribution - Last 21 Days', fontsize=14)
# Plot legend and grid
plt.legend(title="Stock Prices", bbox_to_anchor=(1, 0.7))
plt.grid(True)

# Show plot
plt.show()

# %%
# Define figure
cibc_comb_dist = plt.figure(figsize=(11, 36))

# -- Open Stock Prices --

# Histogram
ax1 = cibc_comb_dist.add_subplot(6, 2, 1)
ax1 = plt.hist(x=df['Open'], color='violet', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 45, 5))
plt.yticks(np.arange(0, 800, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax2 = cibc_comb_dist.add_subplot(6, 2, 2)
ax2 = sns.boxplot(x=df['Open'], color='violet')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 45, 5))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Open Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- High Stock Prices --

# Histogram
ax3 = cibc_comb_dist.add_subplot(6, 2, 3)
ax3 = plt.hist(x=df['High'], color='blue', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 45, 5))
plt.yticks(np.arange(0, 800, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax4 = cibc_comb_dist.add_subplot(6, 2, 4)
ax4 = sns.boxplot(x=df['High'], color='blue')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 45, 5))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('High Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Low Stock Prices --

# Histogram
ax5 = cibc_comb_dist.add_subplot(6, 2, 5)
ax5 = plt.hist(x=df['Low'], color='turquoise', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 45, 5))
plt.yticks(np.arange(0, 800, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax6 = cibc_comb_dist.add_subplot(6, 2, 6)
ax6 = sns.boxplot(x=df['Low'], color='turquoise')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 45, 5))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Low Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Closing Stock Prices --

# Histogram
ax7 = cibc_comb_dist.add_subplot(6, 2, 7)
ax7 = plt.hist(x=df['Close'], color='green', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 45, 5))
plt.yticks(np.arange(0, 800, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax8 = cibc_comb_dist.add_subplot(6, 2, 8)
ax8 = sns.boxplot(x=df['Close'], color='green')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 45, 5))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Adjusted Closing Stock Prices --

# Histogram
ax9 = cibc_comb_dist.add_subplot(6, 2, 9)
ax9 = plt.hist(x=df['Adj Close'], color='lime', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 45, 5))
plt.yticks(np.arange(0, 800, 40))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax10 = cibc_comb_dist.add_subplot(6, 2, 10)
ax10 = sns.boxplot(x=df['Adj Close'], color='lime')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 45, 5))
# Plot title and label(s)
plt.xlabel('Value ($)', fontsize=12)
plt.title('Adjusted Closing Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# -- Volume of Stocks --

# Histogram
ax11 = cibc_comb_dist.add_subplot(6, 2, 11)
ax11 = plt.hist(x=df['Volume'], color='orange', edgecolor='black')
# Adjust axes range(s)
plt.xticks(np.arange(0, 600000, 100000))
plt.yticks(np.arange(0, 2400, 200))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.ylabel('Number of Stocks', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)
# Plot grid
plt.grid(True)

# Box Plot
ax12 = cibc_comb_dist.add_subplot(6, 2, 12)
ax12 = sns.boxplot(x=df['Volume'], color='orange')
# Adjust X-Axis range(s)
plt.xticks(np.arange(0, 600000, 100000))
# Plot title and label(s)
plt.xlabel('Volume', fontsize=12)
plt.title('Volume of Stocks', fontsize=14)
# Plot grid
plt.grid(True)

# Show subplot
plt.show()

# %% [markdown]
# ### 2.4. Feature Engineering

# %%
# Normalize data
sc = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = sc.fit_transform(dataset)

# %%
dataset_scaled
# Out:
# array([[0.60248447],
#        [0.62111801],
#        [0.63768116],
#        ...,
#        [0.52361234],
#        [0.5221335 ],
#        [0.52144337]])

# %%
# Split dataset into training set and test set (80/20 split)
training_size = int(len(df)*0.8)
dataset_train = dataset_scaled[:training_size]
dataset_test = dataset_scaled[training_size:]

print('Training set shape: ' + str(dataset_train.shape))
print('Test set shape: ' + str(dataset_test.shape))
# Out:
# Training set shape: (1611, 1)
# Test set shape: (403, 1)

# %%
# Define number of timesteps (number of business days)
timesteps = 60

# %%
# Predict stock price results using n timesteps
def define_training_data(timesteps, dataset):
  """
  timesteps - number of timesteps (business days)
  dataset   - stock prices (training) dataset
  """

  # X - number of timesteps, y - indicators (features) used for training
  X, y = [], []
  for i in range(timesteps, dataset.shape[0]):
    # Get number of timesteps (business days)
    X.append(dataset[i-timesteps:i, 0])
    # Starting date of reporting (increments during model training)
    y.append(dataset[i, 0])
  # Convert to NumPy array
  X, y = np.array(X), np.array(y)
  return X, y

X_train, y_train = define_training_data(timesteps, dataset_train)
print(X_train.shape, y_train.shape)
# Out:
# (1551, 60) (1551,)

# %%
# Reshape (number of rows, number of timesteps (columns), number of predictors)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# %%
X_train
# Out:
# array([[[0.60248447],
#         [0.62111801],
#         [0.63768116],
#         ...,
#         [0.56452733],
#         [0.57971014],
#         [0.57556943]],
#
#        [[0.62111801],
#         [0.63768116],
#         [0.64872326],
#         ...,
#         [0.57971014],
#         [0.57556943],
#         [0.59006211]],
#
#        [[0.63768116],
#         [0.64872326],
#         [0.68322981],
#         ...,
#         [0.57556943],
#         [0.59006211],
#         [0.58523119]],
#
#        ...,
#
#        [[0.93236722],
#         [0.9275363 ],
#         [0.9489303 ],
#         ...,
#         [0.77846784],
#         [0.7694962 ],
#         [0.78674948]],
#
#        [[0.9275363 ],
#         [0.9489303 ],
#         [0.95583168],
#         ...,
#         [0.7694962 ],
#         [0.78674948],
#         [0.79434099]],
#
#        [[0.9489303 ],
#         [0.95583168],
#         [0.93995852],
#         ...,
#         [0.78674948],
#         [0.79434099],
#         [0.79434099]]])

# %%
# X_train: (number of rows, number of columns, number of predictors)
X_train.shape
# Out:
# (1551, 60, 1)

# %% [markdown]
# ## 3. Define and Evaluate LSTM model

# %% [markdown]
# ###### **NOTE:** LSTM - Long Short-Term Memory

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define model
reg = Sequential()

# -- LSTM layers --

# Input and first (hidden) layer (with dropout regularization)
reg.add(LSTM(units=60, return_sequences=True,
             input_shape=(X_train.shape[1], X_train.shape[2])))
reg.add(Dropout(0.1))

# Additional hidden layers
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=60, return_sequences=True))
reg.add(Dropout(0.1))
reg.add(LSTM(units=50, return_sequences=False))
reg.add(Dropout(0.1))

# Output layer
reg.add(Dense(units=X_train.shape[2]))

# Compile model
reg.compile(optimizer='adam', loss='mean_squared_error')

# Train (fit) model
history = reg.fit(X_train, y_train, batch_size=32, epochs=100)

# Summarize LSTM model
reg.summary()

# Plot loss during training (Mean Squared Error - MSE)
plt.plot(history.history['loss'], 'g', label='loss')
# Plot title and labels
plt.title('Training Curve', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('MSE', fontsize=12)
# Plot legend and grid
plt.legend()
plt.grid(True)

# Show loss results
plt.show()
# Out:
# Epoch 1/100
# 49/49 [==============================] - 10s 92ms/step - loss: 0.0493
# Epoch 2/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0072
# Epoch 3/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0060
# Epoch 4/100
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0059
# Epoch 5/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0058
# Epoch 6/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0051
# Epoch 7/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0054
# Epoch 8/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0050
# Epoch 9/100
# 49/49 [==============================] - 4s 92ms/step - loss: 0.0044
# Epoch 10/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0042
# Epoch 11/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0043
# Epoch 12/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0043
# Epoch 13/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0040
# Epoch 14/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0039
# Epoch 15/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0038
# Epoch 16/100
# 49/49 [==============================] - 5s 99ms/step - loss: 0.0036
# Epoch 17/100
# 49/49 [==============================] - 5s 91ms/step - loss: 0.0033
# Epoch 18/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0045
# Epoch 19/100
# 49/49 [==============================] - 4s 86ms/step - loss: 0.0033
# Epoch 20/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0033
# Epoch 21/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0032
# Epoch 22/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0037
# Epoch 23/100
# 49/49 [==============================] - 5s 101ms/step - loss: 0.0034
# Epoch 24/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0030
# Epoch 25/100
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0027
# Epoch 26/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0031
# Epoch 27/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0028
# Epoch 28/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0027
# Epoch 29/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0027
# Epoch 30/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0030
# Epoch 31/100
# 49/49 [==============================] - 4s 86ms/step - loss: 0.0028
# Epoch 32/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0027
# Epoch 33/100
# 49/49 [==============================] - 4s 89ms/step - loss: 0.0024
# Epoch 34/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0024
# Epoch 35/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0026
# Epoch 36/100
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0023
# Epoch 37/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0022
# Epoch 38/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0024
# Epoch 39/100
# 49/49 [==============================] - 4s 89ms/step - loss: 0.0021
# Epoch 40/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0022
# Epoch 41/100
# 49/49 [==============================] - 4s 92ms/step - loss: 0.0022
# Epoch 42/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0022
# Epoch 43/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0022
# Epoch 44/100
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0020
# Epoch 45/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0021
# Epoch 46/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0020
# Epoch 47/100
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0019
# Epoch 48/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0018
# Epoch 49/100
# 49/49 [==============================] - 4s 86ms/step - loss: 0.0019
# Epoch 50/100
# 49/49 [==============================] - 4s 88ms/step - loss: 0.0020
# Epoch 51/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0019
# Epoch 52/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0018
# Epoch 53/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0019
# Epoch 54/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0018
# Epoch 55/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0019
# Epoch 56/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0018
# Epoch 57/100
# 49/49 [==============================] - 4s 87ms/step - loss: 0.0018
# Epoch 58/100
# 49/49 [==============================] - 4s 88ms/step - loss: 0.0019
# Epoch 59/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0017
# Epoch 60/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0017
# Epoch 61/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0017
# Epoch 62/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0016
# Epoch 63/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0018
# Epoch 64/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0015
# Epoch 65/100
# 49/49 [==============================] - 4s 86ms/step - loss: 0.0015
# Epoch 66/100
# 49/49 [==============================] - 4s 89ms/step - loss: 0.0015
# Epoch 67/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0015
# Epoch 68/100
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0015
# Epoch 69/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0015
# Epoch 70/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0015
# Epoch 71/100
# 49/49 [==============================] - 4s 92ms/step - loss: 0.0015
# Epoch 72/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0014
# Epoch 73/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0015
# Epoch 74/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0014
# Epoch 75/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0013
# Epoch 76/100
# 49/49 [==============================] - 4s 92ms/step - loss: 0.0014
# Epoch 77/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0015
# Epoch 78/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0013
# Epoch 79/100
# 49/49 [==============================] - 4s 92ms/step - loss: 0.0013
# Epoch 80/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0013
# Epoch 81/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0014
# Epoch 82/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0013
# Epoch 83/100
# 49/49 [==============================] - 4s 82ms/step - loss: 0.0012
# Epoch 84/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0012
# Epoch 85/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0013
# Epoch 86/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0012
# Epoch 87/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0012
# Epoch 88/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0011
# Epoch 89/100
# 49/49 [==============================] - 4s 83ms/step - loss: 0.0011
# Epoch 90/100
# 49/49 [==============================] - 4s 90ms/step - loss: 0.0011
# Epoch 91/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0011
# Epoch 92/100
# 49/49 [==============================] - 4s 88ms/step - loss: 0.0011
# Epoch 93/100
# 49/49 [==============================] - 4s 86ms/step - loss: 0.0010
# Epoch 94/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0011
# Epoch 95/100
# 49/49 [==============================] - 4s 91ms/step - loss: 0.0011
# Epoch 96/100
# 49/49 [==============================] - 4s 85ms/step - loss: 0.0010
# Epoch 97/100
# 49/49 [==============================] - 4s 84ms/step - loss: 0.0011
# Epoch 98/100
# 49/49 [==============================] - 5s 92ms/step - loss: 0.0010
# Epoch 99/100
# 49/49 [==============================] - 4s 85ms/step - loss: 9.1182e-04
# Epoch 100/100
# 49/49 [==============================] - 4s 88ms/step - loss: 9.4966e-04
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 60)            14880
#
#  dropout (Dropout)           (None, 60, 60)            0
#
#  lstm_1 (LSTM)               (None, 60, 60)            29040
#
#  dropout_1 (Dropout)         (None, 60, 60)            0
#
#  lstm_2 (LSTM)               (None, 60, 60)            29040
#
#  dropout_2 (Dropout)         (None, 60, 60)            0
#
#  lstm_3 (LSTM)               (None, 50)                22200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 95211 (371.92 KB)
# Trainable params: 95211 (371.92 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Make predictions

# %%
# Get n (number of timesteps) previous stock prices for predicting
inputs = dataset[len(dataset)-len(dataset_test) - timesteps:]
# Reshape input values
inputs = inputs.reshape(-1, 1)
# Scale input values, directly apply transformations (already fitted)
inputs = sc.transform(inputs)

# Define test set structure
X_test = []
# For the entire test set
for i in range(timesteps, timesteps + len(dataset_test)):
  # Range of values from i-60 to i, first column
  X_test.append(inputs[i-timesteps:i, 0])
# Convert to NumPy array
X_test = np.array(X_test)

# Obtain 3D structure of the test set
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Predict the test set results
predicted_stock_price = reg.predict(X_test)
# Apply inverse transformations
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
real_stock_price = sc.inverse_transform(dataset_test)

# Print predicted and real stock prices side-by-side (if required)
# print(np.concatenate((predicted_stock_price.reshape(len(predicted_stock_price), 1),
#                       real_stock_price.reshape(len(real_stock_price), 1)), 1 ))

# Print Scores
print('')
print('--- Prediction Scores ---')
print('')
# Mean Absolute Error (MAE)
print('MAE: %.3f' % (mean_absolute_error(real_stock_price, predicted_stock_price)))
# Mean Squared Error (MSE)
print('MSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price)))
# Root Mean Squared Error (RMSE)
print('RMSE: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price, squared=False)))
# R^2 Score (Goodness-of-Fit)
print('R^2 Score: %.3f%%' % (r2_score(real_stock_price, predicted_stock_price) * 100))
# Out:
# 13/13 [==============================] - 1s 24ms/step
#
# --- Prediction Scores ---
#
# MAE: 0.209
# MSE: 0.081
# RMSE: 0.285
# R^2 Score: 97.084%

# %% [markdown]
# #### Visualize Prediction Results

# %%
# Define figure
cibc_pred_results = plt.figure(figsize=(10,6))

# Plot results
cibc_pred_results = plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
# Plot rolling average
df_real = pd.DataFrame(predicted_stock_price)
rolling_avg_pred = df_real.rolling(window = 7).mean()
cibc_pred_results = plt.plot(rolling_avg_pred, "--", color = 'red', label = 'Rolling Average')

# Adjust Y-Axis range
plt.yticks(np.arange(10, 40, 2))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Stock Price ($)', fontsize=12)
plt.title('Predicted Stock Price', fontsize=14)
# Plot legend and grid
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
# Define figure
cibc_real_results = plt.figure(figsize=(10,6))

# Plot results
cibc_real_results = plt.plot(real_stock_price, color = 'blue', label = 'Real Stock Price')
# Plot rolling average (over 7 days)
df_real = pd.DataFrame(real_stock_price)
rolling_avg_real = df_real.rolling(window = 7).mean()
cibc_real_results = plt.plot(rolling_avg_real, "--", color = 'red', label = 'Rolling Average')

# Adjust Y-Axis range
plt.yticks(np.arange(10, 40, 2))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Stock Price ($)', fontsize=12)
plt.title('Real Stock Price', fontsize=14)
# Plot legend and grid
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
# Define results figure
cibc_results = plt.figure(figsize=(12,6))

# Plot results
cibc_results = plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
cibc_results = plt.plot(real_stock_price, color = 'red', label = 'Real Stock Price')
# Adjust Y-Axis range
plt.yticks(np.arange(10, 40, 2))
# Plot title and labels
plt.xlabel('Days', fontsize=12)
plt.ylabel('Stock Price ($)', fontsize=12)
plt.title('CIBC Stock Price Prediction', fontsize=14)
# Plot legend and grid
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
# Define results figure - Last 21 days
cibc_results_last_21 = plt.figure(figsize=(10,6))

# Plot results
# Predicted stock price
cibc_results_last_21 = plt.plot(predicted_stock_price[-21:], color = 'blue',
                              label = 'Predicted Stock Price')
# Real stock price
cibc_results_last_21 = plt.plot(real_stock_price[-21:], color = 'red',
                              label = 'Real Stock Price')
# (Current) reporting date
cibc_results_last_21 = plt.axvline(x=(len(real_stock_price[-21:])-(win+1)),
                                 color='orange', label = 'Reporting Day')
# Next 7 days (win)
cibc_results_last_21 = plt.axvspan(13, 20, facecolor='lightgrey', label='Next 7 Days')

# Adjust Y-Axis range
plt.xticks(np.arange(0, 21, 1))
plt.yticks(np.arange(16, 24, 1))
# Plot title and labels
plt.xlabel('Days')
plt.ylabel('Stock Price ($)')
plt.title('CIBC Stock Price Prediction - Last 21 Days')
# Plot legend and grid
plt.legend(loc='upper right')
plt.grid(True)

# Show plot
plt.show()

# %%
# Combined box plot distributions
box_plots_comb = plt.figure(figsize=(8, 6))

# Box plot for lr_pred
ax1 = box_plots_comb.add_subplot(1, 2, 1)
ax1 = sns.boxplot(y=predicted_stock_price, color='blue', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(10, 40, 5))
# Plot title and labels
plt.xlabel('Predicted Stock Price', fontsize=12)
plt.ylabel('Value ($)', fontsize=12)
plt.title('Predicted Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Box plot for linear_svr_pred
ax2 = box_plots_comb.add_subplot(1, 2, 2)
ax2 = sns.boxplot(y=real_stock_price, color='red', orient='v')
# Adjust Y-Axis Range
plt.yticks(np.arange(10, 40, 5))
# Plot title and label
plt.xlabel('Real Stock Price', fontsize=12)
plt.title('Real Stock Price', fontsize=14)
# Plot grid
plt.grid(True)

# Show subplot
plt.show()

# %%
# Calculate run time
run_time = time.time() - start_time
run_time_min = int(run_time / 60)
run_time_sec = int(run_time % 60)
print("Run Time: " + str(np.round(run_time_min, 0)) + ":" + str(np.round(run_time_sec, 2)))
# Out:
# Run Time: 7:51
